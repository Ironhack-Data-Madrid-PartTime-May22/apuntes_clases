# %% [markdown]
# # Librerias

# %%
# importamos librerias necesarias
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px
# opcion de pandas para ver todas las columnas de un dataframe sin puntos suspensivos
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Carga de datos

# %%
df = pd.read_csv("data/finanzas-hotel-bookings-limpio.csv")
df
# Out:
#               hotel market_segment distribution_channel  agent  company  \
# 0      Resort Hotel         Direct               Direct  250.0      NaN
# 1      Resort Hotel         Direct               Direct  250.0      NaN
# 2      Resort Hotel  Offline TA/TO                TA/TO    5.0      NaN
# 3      Resort Hotel  Offline TA/TO                TA/TO    8.0      NaN
# 4      Resort Hotel      Online TA                TA/TO  240.0      NaN
# ...             ...            ...                  ...    ...      ...
# 71197    City Hotel         Direct               Direct    NaN      NaN
# 71198    City Hotel      Corporate            Corporate    NaN    219.0
# 71199    City Hotel      Corporate            Corporate    NaN    219.0
# 71200    City Hotel       Aviation            Corporate    NaN    153.0
# 71201    City Hotel      Corporate            Corporate    NaN     40.0
#
#        previous_cancellations  previous_bookings_not_canceled  \
# ...

# %%
df['is_canceled'].value_counts()
# Out:
# 0    52173
# 1    19029
# Name: is_canceled, dtype: int64

# %%
# transformampos la columna chuildren a int
df['children'].value_counts()
# Out:
# 0.0    64385
# 1.0     3837
# 2.0     2917
# 3.0       60
# Name: children, dtype: int64

# %%
df['children'].astype(str).str.split('.')[0][0]
# Out:
# '0'

# %%
dftt = df.copy()
dftt['children'] = dftt['children'].astype(int, errors='raise')
dftt['children'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /Users/jeancharlesyamada/horno/streamlit_ejemplo/streamlit/analisis.ipynb Celda 6 in 2
#       <a href='vscode-notebook-cell:/Users/jeancharlesyamada/horno/streamlit_ejemplo/streamlit/analisis.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> dftt = df.copy()
# ----> <a href='vscode-notebook-cell:/Users/jeancharlesyamada/horno/streamlit_ejemplo/streamlit/analisis.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> dftt['children'] = dftt['children'].astype(int, errors='raise')
#       <a href='vscode-notebook-cell:/Users/jeancharlesyamada/horno/streamlit_ejemplo/streamlit/analisis.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> dftt['children'].value_counts()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/streamlit2/lib/python3.10/site-packages/pandas/core/generic.py:6245, in NDFrame.astype(self, dtype, copy, errors)
#    6238     results = [
# ...
