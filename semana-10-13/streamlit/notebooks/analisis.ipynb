# %% [markdown]
# # 1-Librerias

# %%
# importamos librerias necesarias
import pandas as pd
import numpy as np


import datetime
import time


import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px
# opcion de pandas para ver todas las columnas de un dataframe sin puntos suspensivos
pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2-Carga de datos

# %%
df = pd.read_csv("../data/finanzas-hotel-bookings-limpio.csv")
df
# Out:
#               hotel market_segment distribution_channel            agent  \
# 0      Resort Hotel         Direct               Direct              250
# 1      Resort Hotel         Direct               Direct              250
# 2      Resort Hotel  Offline TA/TO                TA/TO                5
# 3      Resort Hotel  Offline TA/TO                TA/TO                8
# 4      Resort Hotel      Online TA                TA/TO              240
# ...             ...            ...                  ...              ...
# 71197    City Hotel         Direct               Direct  sin identificar
# 71198    City Hotel      Corporate            Corporate  sin identificar
# 71199    City Hotel      Corporate            Corporate  sin identificar
# 71200    City Hotel       Aviation            Corporate  sin identificar
# 71201    City Hotel      Corporate            Corporate  sin identificar
#
#                company  previous_cancellations  \
# ...

# %% [markdown]
# # 3-Analisis descriptivo

# %%
# describe solo para las columnas numericas 
df_descriptivo = df.describe().T 
df_descriptivo.style.background_gradient()
# Out:
# <style type="text/css">
# #T_a86c1_row0_col0, #T_a86c1_row0_col3, #T_a86c1_row1_col0, #T_a86c1_row1_col3, #T_a86c1_row2_col0, #T_a86c1_row2_col3, #T_a86c1_row3_col0, #T_a86c1_row3_col3, #T_a86c1_row4_col0, #T_a86c1_row4_col2, #T_a86c1_row5_col0, #T_a86c1_row5_col3, #T_a86c1_row6_col0, #T_a86c1_row6_col3, #T_a86c1_row7_col0, #T_a86c1_row7_col3, #T_a86c1_row10_col0, #T_a86c1_row10_col3, #T_a86c1_row11_col0, #T_a86c1_row11_col3, #T_a86c1_row12_col0, #T_a86c1_row12_col3, #T_a86c1_row13_col0, #T_a86c1_row13_col3, #T_a86c1_row14_col0, #T_a86c1_row14_col3, #T_a86c1_row15_col0, #T_a86c1_row15_col3, #T_a86c1_row16_col0, #T_a86c1_row16_col3, #T_a86c1_row17_col0, #T_a86c1_row17_col3, #T_a86c1_row18_col0, #T_a86c1_row18_col3, #T_a86c1_row19_col0, #T_a86c1_row19_col1, #T_a86c1_row19_col4, #T_a86c1_row19_col5, #T_a86c1_row19_col6, #T_a86c1_row19_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# ...

# %%
# describe las variables categoricas 
df.describe(include="object").T
# Out:
#                          count unique              top   freq
# hotel                    71202      2       City Hotel  43471
# market_segment           71202      8        Online TA  42064
# distribution_channel     71202      5            TA/TO  56405
# agent                    71202    320                9  23416
# company                  71202    331  sin identificar  66830
# is_canceled              71202      2     Not Canceled  52173
# reservation_status       71202      3        Check-Out  52173
# reservation_status_date  71202    901       2016-02-14    205
# arrival_date             71202    793       2017-07-15    202
# country                  69955    169         Portugal  22265
# customer_type            71202      4        Transient  58462
# reserved_room_type       71202     10                A  46177
# assigned_room_type       71202     11                A  37856
# meal                     71202      5               BB  55302

# %%
# selecionamos las columnas de tipo object
df_categoricas = df[df.select_dtypes(include="object").columns.tolist()]
df_categoricas.head(3)
# Out:
#           hotel market_segment distribution_channel agent          company  \
# 0  Resort Hotel         Direct               Direct   250  sin identificar
# 1  Resort Hotel         Direct               Direct   250  sin identificar
# 2  Resort Hotel  Offline TA/TO                TA/TO     5  sin identificar
#
#     is_canceled reservation_status reservation_status_date arrival_date  \
# 0  Not Canceled          Check-Out              2015-07-07   2015-07-01
# 1  Not Canceled          Check-Out              2015-07-07   2015-07-01
# 2  Not Canceled          Check-Out              2015-08-07   2015-07-01
#
#     country customer_type reserved_room_type assigned_room_type meal
# 0  Portugal     Transient                  A                  A   BB
# 1  Portugal     Transient                  D                  D   BB
# 2  Portugal     Transient                  D                  D   BB

# %%
# usando px para graficar 
df_sucio = df_categoricas.copy()    
df_sucio["room_modification"] = np.where(df_sucio["reserved_room_type"] == df_sucio["assigned_room_type"], "Si", "No")
df_sucio
# Out:
#               hotel market_segment distribution_channel            agent  \
# 0      Resort Hotel         Direct               Direct              250
# 1      Resort Hotel         Direct               Direct              250
# 2      Resort Hotel  Offline TA/TO                TA/TO                5
# 3      Resort Hotel  Offline TA/TO                TA/TO                8
# 4      Resort Hotel      Online TA                TA/TO              240
# ...             ...            ...                  ...              ...
# 71197    City Hotel         Direct               Direct  sin identificar
# 71198    City Hotel      Corporate            Corporate  sin identificar
# 71199    City Hotel      Corporate            Corporate  sin identificar
# 71200    City Hotel       Aviation            Corporate  sin identificar
# 71201    City Hotel      Corporate            Corporate  sin identificar
#
#                company   is_canceled reservation_status  \
# ...

# %%
# emoezamos con el analisis de cancelaciones de hoteles
