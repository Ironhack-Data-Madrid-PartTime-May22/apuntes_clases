# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#¿Qué-es-Mongo-DB?" data-toc-modified-id="¿Qué-es-Mongo-DB?-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>¿Qué es Mongo DB?</a></span></li><li><span><a href="#¿Cómo-nos-conectamos-con-MongoDB?" data-toc-modified-id="¿Cómo-nos-conectamos-con-MongoDB?-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>¿Cómo nos conectamos con MongoDB?</a></span></li><li><span><a href="#Insertar-datos-en-Mongo-DB" data-toc-modified-id="Insertar-datos-en-Mongo-DB-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Insertar datos en Mongo DB</a></span></li><li><span><a href="#Buscar-datos-en-nuestra-BBDD." data-toc-modified-id="Buscar-datos-en-nuestra-BBDD.-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Buscar datos en nuestra BBDD.</a></span><ul class="toc-item"><li><span><a href="#find()" data-toc-modified-id="find()-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span><code>find()</code></a></span><ul class="toc-item"><li><span><a href="#Búsqueda-de-campos-de-tipo-string" data-toc-modified-id="Búsqueda-de-campos-de-tipo-string-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Búsqueda de campos de tipo string</a></span></li><li><span><a href="#Búsqueda-de-campos-de-tipo-numérico" data-toc-modified-id="Búsqueda-de-campos-de-tipo-numérico-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Búsqueda de campos de tipo numérico</a></span></li></ul></li><li><span><a href="#Operadores-and-y-or" data-toc-modified-id="Operadores-and-y-or-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Operadores <code>and</code> y <code>or</code></a></span></li><li><span><a href="#Proyecciones" data-toc-modified-id="Proyecciones-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Proyecciones</a></span></li></ul></li><li><span><a href="#Otros-métodos-interesantes" data-toc-modified-id="Otros-métodos-interesantes-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Otros métodos interesantes</a></span><ul class="toc-item"><li><span><a href="#exists()" data-toc-modified-id="exists()-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span><code>exists()</code></a></span></li><li><span><a href="#limit()" data-toc-modified-id="limit()-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span><code>limit()</code></a></span></li><li><span><a href="#sort()" data-toc-modified-id="sort()-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span><code>sort()</code></a></span></li><li><span><a href="#type()" data-toc-modified-id="type()-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span><code>type()</code></a></span></li></ul></li><li><span><a href="#update()" data-toc-modified-id="update()-6"><span class="toc-item-num">6&nbsp;&nbsp;</span><code>update()</code></a></span></li><li><span><a href="#delete()" data-toc-modified-id="delete()-7"><span class="toc-item-num">7&nbsp;&nbsp;</span><code>delete()</code></a></span></li><li><span><a href="#Geoqueries" data-toc-modified-id="Geoqueries-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Geoqueries</a></span><ul class="toc-item"><li><span><a href="#Antes-de-empezar" data-toc-modified-id="Antes-de-empezar-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Antes de empezar</a></span></li><li><span><a href="#Tipos-de-geoqueries" data-toc-modified-id="Tipos-de-geoqueries-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Tipos de geoqueries</a></span><ul class="toc-item"><li><span><a href="#near()" data-toc-modified-id="near()-8.2.1"><span class="toc-item-num">8.2.1&nbsp;&nbsp;</span><code>near()</code></a></span></li></ul></li><li><span><a href="#geonear()" data-toc-modified-id="geonear()-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span><code>geonear()</code></a></span></li></ul></li><li><span><a href="#Ploteemos-los-resultados" data-toc-modified-id="Ploteemos-los-resultados-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Ploteemos los resultados</a></span><ul class="toc-item"><li><span><a href="#Guardar-el-mapa" data-toc-modified-id="Guardar-el-mapa-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Guardar el mapa</a></span></li></ul></li></ul></div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # ¿Qué es Mongo DB?

# %% [markdown]
# MongoDB es la base de datos no relacional, que nos permite:
#
# - Aprovechar los datos y la tecnología para maximizar la ventaja competitiva
#
#
# - Reducir el riesgo de implementaciones de misión crítica
#
#
# - Acelerar el tiempo de valor drásticamente, menor costo total de propiedad
#
# A diferencia de las bases de datos relacionales, donde se almacenan los registros como filas de una tabla, con MongoDB estos registros son almacenados en documentos BSON (un derivado de los documentos JSON).
#
# Veámos los conceptos básicos presentes en MongoDB:
#
# - Los `documentos`: cada una de las entradas de nuestra colección.
#
#
# - Las `colecciones`: es un conjunto de documentos y podría identificarse con una tabla con la particularidad de que no existe un esquema fijo (es decir, el número de campos y sus nombres pueden variar)
#
#
# - Las `bases de datos`: conjunto de colecciones

# %% [markdown]
# # ¿Cómo nos conectamos con MongoDB?

# %% [markdown]
# Pymongo es un driver de Python para MongoDB que permite interactuar con las bases de datos Mongo usando Python. Primero necesitas tener instalado MongoDB en tu sistema.

# %%
# lo primero que tenemos que hacer es instalar pymongo

# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /opt/homebrew/Caskroom/miniconda/base/envs/apis/lib/python3.11/site-packages (4.3.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /opt/homebrew/Caskroom/miniconda/base/envs/apis/lib/python3.11/site-packages (from pymongo) (2.3.0)

# %%
# importamos la librería

import pymongo

# %%
# nos conectamos con Mongo
cliente = pymongo.MongoClient()
cliente
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
# vamos a chequear que bases de datos tenemos 

cliente.list_database_names()
# Out:
# ['admin', 'alojamientos', 'companies', 'config', 'local', 'prueba']

# %%
# accedemos y/o crear la bbdd objetivo 
mydb = cliente["companies"]

# %%
cliente["toto"]
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'toto')

# %%
# creamos una coleccion dentro de la BBDD
coleccion = mydb.detalle
coleccion
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'companies'), 'detalle')

# %% [markdown]
# # Insertar datos en Mongo DB
#
# Tenemos dos métodos para hacer esto:
#
# - `insert_one()`
#
#
# - `insert_many()`

# %% [markdown]
# **insert_one()** lo utilizamos para insertar un único documento en nuestra colección

# %%
dicc = {"niombre":"juan"}
coleccion.insert_one(dicc)

# %% [markdown]
# **insert_many()** lo utilizamos para insertar más de un documento en nuestra colección

# %%
varios = [{"nombre": "Maria", "apellidos": "López", "edad": 43, 
           "dirección": "Calle de Arenas", "provincia": "Madrid"},
          
          {'nombre':"Lorenzo", 'apellidos': "Hernández", "edad": 23, 
           "direccion": "Calle de Arenas de San Pedro", "provicia": "madrid" }]

# %%
coleccion.insert_many(varios)

# %% [markdown]
# También podemos insertar datos desde un *dataframe*. Vamos a cargar un csv donde tenemos los datos que queremos insertar

# %%
import pandas as pd
pd.options.display.max_columns = None

# %%
df = pd.read_csv("data/alojamientos.csv")
df.head()
# Out:
#    fid                                 etiqueta  granularidad cod_tipocat  \
# 0    0  HOTEL RIU CLUB PARAISO LANZAROTE RESORT  ALOJAMIENTOS          H4
# 1    1               OCCIDENTAL LANZAROTE PLAYA  ALOJAMIENTOS          H4
# 2    2                      HOTEL PARADISE PARK  ALOJAMIENTOS          H4
# 3    3            HOTEL CATALONIA PUNTA DEL REY  ALOJAMIENTOS          H4
# 4    4                             HOTEL MEDANO  ALOJAMIENTOS          H3
#
#   cod_tipo nom_tipo  cod_categor  nom_categor gcd_isla   nom_isla gcd_entitur  \
# 0  5510_L1    Hotel            4  4 Estrellas    ES708  Lanzarote     ES708B2
# 1  5510_L1    Hotel            4  4 Estrellas    ES708  Lanzarote     ES708B1
# 2  5510_L1    Hotel            4  4 Estrellas    ES709   Tenerife     ES709B2
# 3  5510_L1    Hotel            4  4 Estrellas    ES709   Tenerife     ES709B9
# 4  5510_L1    Hotel            3  3 Estrellas    ES709   Tenerife     ES709B3
#
#                      nom_entitur gcd_nucltur  \
# 0              Puerto del Carmen    ES708B23
# 1                  Costa Teguise    ES708B12
# 2  Las Américas - Los Cristianos    ES709B23
# 3              Resto de Tenerife     ES709B9
# 4                          Abona    ES709B32
#
#                                    nom_nucltur  gcd_municipio  \
# 0  Puerto del Carmen: Matagorda - Los Pocillos          35028
# 1                       Costa Teguise: Litoral          35024
# 2                               Los Cristianos          38006
# 3                            Resto de Tenerife          38011
# 4                                    El Médano          38017
#
#          nom_municipio                              direccion  \
# 0                 Tías  CALLE SUIZA , 4.PLAYA DE LOS POCILLOS
# 1              Teguise                     AVENIDA DEL MAR, 6
# 2                Arona             URBANIZACIÓN OASIS DEL SUR
# 3           Candelaria              AVENIDA GENERALISIMO, 165
# 4  Granadilla de Abona                       PASEO PICACHO, 2
#
#                  prc_habita           prc_plazas   longitud    latitud  \
# 0    300 o más habitaciones     650 o más plazas -13.639328  28.926763
# 1    300 o más habitaciones     650 o más plazas -13.509783  28.987312
# 2    300 o más habitaciones     650 o más plazas -16.706284  28.053429
# 3    300 o más habitaciones     650 o más plazas -16.362112  28.377362
# 4  De 50 a 149 habitaciones  De 100 a 349 plazas -16.538002  28.044017
#
#       geohash      utm_x       utm_y
# 0  etnk99unse  632629.37  3200633.49
# 1  etnkusfrr4  645173.54  3207494.99
# 2  esupeffz56  332302.78  3104295.54
# 3  eth37tvqp5  366536.23  3139759.91
# 4  esupx9m2hx  348831.06  3103032.41

# %%
# creamos una lista de diccionarios
df.to_dict("records")
# Out:
# [{'fid': 0,
#   'etiqueta': 'HOTEL RIU CLUB PARAISO LANZAROTE RESORT',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B2',
#   'nom_entitur': 'Puerto del Carmen',
#   'gcd_nucltur': 'ES708B23',
#   'nom_nucltur': 'Puerto del Carmen: Matagorda - Los Pocillos',
#   'gcd_municipio': 35028,
#   'nom_municipio': 'Tías',
#   'direccion': 'CALLE SUIZA , 4.PLAYA DE LOS POCILLOS',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -13.63932784,
#   'latitud': 28.926763238,
#   'geohash': 'etnk99unse',
#   'utm_x': 632629.37,
#   'utm_y': 3200633.49},
#  {'fid': 1,
#   'etiqueta': 'OCCIDENTAL LANZAROTE PLAYA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B1',
#   'nom_entitur': 'Costa Teguise',
#   'gcd_nucltur': 'ES708B12',
#   'nom_nucltur': 'Costa Teguise: Litoral',
#   'gcd_municipio': 35024,
#   'nom_municipio': 'Teguise',
#   'direccion': 'AVENIDA DEL MAR, 6',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -13.50978259,
#   'latitud': 28.987312399,
#   'geohash': 'etnkusfrr4',
#   'utm_x': 645173.54,
#   'utm_y': 3207494.99},
#  {'fid': 2,
#   'etiqueta': 'HOTEL PARADISE PARK',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B23',
#   'nom_nucltur': 'Los Cristianos',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'URBANIZACIÓN OASIS DEL SUR',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.70628369,
#   'latitud': 28.053428781,
#   'geohash': 'esupeffz56',
#   'utm_x': 332302.78,
#   'utm_y': 3104295.54},
#  {'fid': 3,
#   'etiqueta': 'HOTEL CATALONIA PUNTA DEL REY',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38011,
#   'nom_municipio': 'Candelaria',
#   'direccion': 'AVENIDA GENERALISIMO, 165',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.36211189,
#   'latitud': 28.377361794,
#   'geohash': 'eth37tvqp5',
#   'utm_x': 366536.23,
#   'utm_y': 3139759.91},
#  {'fid': 4,
#   'etiqueta': 'HOTEL MEDANO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B3',
#   'nom_entitur': 'Abona',
#   'gcd_nucltur': 'ES709B32',
#   'nom_nucltur': 'El Médano',
#   'gcd_municipio': 38017,
#   'nom_municipio': 'Granadilla de Abona',
#   'direccion': 'PASEO PICACHO, 2',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.53800193,
#   'latitud': 28.044016879,
#   'geohash': 'esupx9m2hx',
#   'utm_x': 348831.06,
#   'utm_y': 3103032.41},
#  {'fid': 5,
#   'etiqueta': 'HOTEL PLAYA SUR TENERIFE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B3',
#   'nom_entitur': 'Abona',
#   'gcd_nucltur': 'ES709B32',
#   'nom_nucltur': 'El Médano',
#   'gcd_municipio': 38017,
#   'nom_municipio': 'Granadilla de Abona',
#   'direccion': 'PLAYA DEL MÉDANO, S/N',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.54282447,
#   'latitud': 28.041107416,
#   'geohash': 'esupx89zk3',
#   'utm_x': 348352.91,
#   'utm_y': 3102716.04},
#  {'fid': 6,
#   'etiqueta': 'PARADOR TURISMO LAS CAÑADAS DEL TEIDE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H2',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 2,
#   'nom_categor': '2 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38026,
#   'nom_municipio': 'La Orotava',
#   'direccion': 'CALLE LAS CAÑADAS DEL TEIDE',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.62713435,
#   'latitud': 28.224399963,
#   'geohash': 'eth0tdh7p9',
#   'utm_x': 340336.74,
#   'utm_y': 3123133.08},
#  {'fid': 7,
#   'etiqueta': 'HOTEL SUN HOLIDAYS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H1',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 1,
#   'nom_categor': '1 Estrella',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE LA PEÑITA, 6',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.55375492,
#   'latitud': 28.416832449,
#   'geohash': 'eth1xm1uj9',
#   'utm_x': 347812.51,
#   'utm_y': 3144360.59},
#  {'fid': 8,
#   'etiqueta': 'HOTEL TAORO GARDEN',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B53',
#   'nom_nucltur': 'Taoro - La Paz',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE DINAMARCA, 3 (PARQUE TAORO)',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.54642938,
#   'latitud': 28.410945403,
#   'geohash': 'eth1xkp3b2',
#   'utm_x': 348521.75,
#   'utm_y': 3143699.04},
#  {'fid': 9,
#   'etiqueta': 'APARTAMENTOS BAMBI',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A1',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 1,
#   'nom_categor': '1 Estrella',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE ENRIQUE TALG, 15',
#   'prc_habita': 'De 40 a 79 apartamentos',
#   'prc_plazas': 'De 50 a 119 plazas',
#   'longitud': -16.54528665,
#   'latitud': 28.416492741,
#   'geohash': 'eth1xt044f',
#   'utm_x': 348641.59,
#   'utm_y': 3144312.27},
#  {'fid': 10,
#   'etiqueta': 'HC HOTEL MAGEC',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE CUPIDO, 11',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.55222297,
#   'latitud': 28.414682317,
#   'geohash': 'eth1xkep90',
#   'utm_x': 347959.51,
#   'utm_y': 3144120.41},
#  {'fid': 11,
#   'etiqueta': 'HOTEL DON CANDIDO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H1',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 1,
#   'nom_categor': '1 Estrella',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B53',
#   'nom_nucltur': 'Taoro - La Paz',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE PORTUGAL, 10. (URBANIZACIÓN. SAN FERNANDO)',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.54591798,
#   'latitud': 28.410362151,
#   'geohash': 'eth1x7zwk5',
#   'utm_x': 348571.02,
#   'utm_y': 3143633.77},
#  {'fid': 12,
#   'etiqueta': 'APARTAMENTOS EL TREBOL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B1',
#   'nom_entitur': 'Costa Teguise',
#   'gcd_nucltur': 'ES708B12',
#   'nom_nucltur': 'Costa Teguise: Litoral',
#   'gcd_municipio': 35024,
#   'nom_municipio': 'Teguise',
#   'direccion': 'AVENIDA LAS PALMERAS, 10',
#   'prc_habita': '80 o más apartamentos',
#   'prc_plazas': '260 o más plazas',
#   'longitud': -13.48608255,
#   'latitud': 29.005413837,
#   'geohash': 'etnmj078z9',
#   'utm_x': 647456.93,
#   'utm_y': 3209530.19},
#  {'fid': 13,
#   'etiqueta': 'HOTEL INTERPALACE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B53',
#   'nom_nucltur': 'Taoro - La Paz',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE ACEVIÑO, 21',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.53579714,
#   'latitud': 28.415682546,
#   'geohash': 'eth1xsyvrg',
#   'utm_x': 349570.05,
#   'utm_y': 3144210.6},
#  {'fid': 14,
#   'etiqueta': 'SMY HOTEL PUERTO DE LA CRUZ',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B53',
#   'nom_nucltur': 'Taoro - La Paz',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE MARQUES VILLANUEVA DEL PRADO, S/N.',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.54199841,
#   'latitud': 28.414125234,
#   'geohash': 'eth1xsdkr2',
#   'utm_x': 348960.35,
#   'utm_y': 3144045.81},
#  {'fid': 15,
#   'etiqueta': 'HOTEL ELEGANCE MIRAMAR',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B53',
#   'nom_nucltur': 'Taoro - La Paz',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'PARQUE DE TAORO, Nº 23',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.54734603,
#   'latitud': 28.411936216,
#   'geohash': 'eth1xknxdb',
#   'utm_x': 348433.36,
#   'utm_y': 3143809.98},
#  {'fid': 16,
#   'etiqueta': 'HOTEL MONOPOL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE QUINTANA, 15',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.54848929,
#   'latitud': 28.417324372,
#   'geohash': 'eth1xmjybm',
#   'utm_x': 348329.04,
#   'utm_y': 3144408.45},
#  {'fid': 17,
#   'etiqueta': 'HOTEL NOPAL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE SAN JUAN, 15',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.54944003,
#   'latitud': 28.41584195,
#   'geohash': 'eth1xkvn60',
#   'utm_x': 348233.79,
#   'utm_y': 3144245.39},
#  {'fid': 18,
#   'etiqueta': 'HOTEL PUERTO PALACE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B51',
#   'nom_nucltur': 'Playa Jardín - Maritim',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE DOCTOR COBIELLA ZAERA, 2',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.55050638,
#   'latitud': 28.408142735,
#   'geohash': 'eth1x7s33j',
#   'utm_x': 348118.34,
#   'utm_y': 3143393.63},
#  {'fid': 19,
#   'etiqueta': 'HOTEL SAN BORONDON',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE AGUSTIN DE ESPINOSA, 2',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.5555382,
#   'latitud': 28.414927593,
#   'geohash': 'eth1xkb8gy',
#   'utm_x': 347635.09,
#   'utm_y': 3144151.78},
#  {'fid': 20,
#   'etiqueta': 'HOTEL H10 TENERIFE PLAYA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B54',
#   'nom_nucltur': 'Martiánez',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'AVENIDA COLON, 12',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.542701,
#   'latitud': 28.418856184,
#   'geohash': 'eth1xt3zz4',
#   'utm_x': 348898.24,
#   'utm_y': 3144570.9},
#  {'fid': 21,
#   'etiqueta': 'HOTEL EL TOPE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B53',
#   'nom_nucltur': 'Taoro - La Paz',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALZADA DE MARTIANEZ, 2',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.54370429,
#   'latitud': 28.414635127,
#   'geohash': 'eth1xs9ppx',
#   'utm_x': 348793.96,
#   'utm_y': 3144104.45},
#  {'fid': 22,
#   'etiqueta': 'HOTEL TROPICAL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE PUERTO VIEJO, 1',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.55123592,
#   'latitud': 28.416177895,
#   'geohash': 'eth1xm5b0p',
#   'utm_x': 348058.34,
#   'utm_y': 3144284.88},
#  {'fid': 23,
#   'etiqueta': 'HOTEL MELIA FUERTEVENTURA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES704',
#   'nom_isla': 'Fuerteventura',
#   'gcd_entitur': 'ES704B9',
#   'nom_entitur': 'Resto de Fuerteventura',
#   'gcd_nucltur': 'ES704B9',
#   'nom_nucltur': 'Resto de Fuerteventura',
#   'gcd_municipio': 35015,
#   'nom_municipio': 'Pájara',
#   'direccion': 'PLAYA BARCA S/N.',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -14.24543937,
#   'latitud': 28.136811843,
#   'geohash': 'etjb5f4uc1',
#   'utm_x': 574097.59,
#   'utm_y': 3112587.97},
#  {'fid': 24,
#   'etiqueta': 'HOTEL APART. PANORAMICA GARDEN',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38031,
#   'nom_municipio': 'Los Realejos',
#   'direccion': 'CALLE LA LONGUERA, S/N',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.58136253,
#   'latitud': 28.397469054,
#   'geohash': 'eth1w9tg4p',
#   'utm_x': 345079.84,
#   'utm_y': 3142250.25},
#  {'fid': 25,
#   'etiqueta': 'HOTEL MARITIM',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B51',
#   'nom_nucltur': 'Playa Jardín - Maritim',
#   'gcd_municipio': 38031,
#   'nom_municipio': 'Los Realejos',
#   'direccion': 'CALLE EL BURGADO S/N',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.57059077,
#   'latitud': 28.406585643,
#   'geohash': 'eth1wgm8m5',
#   'utm_x': 346148.43,
#   'utm_y': 3143246.6},
#  {'fid': 26,
#   'etiqueta': 'URBAN ANAGA HOTEL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38038,
#   'nom_municipio': 'Santa Cruz de Tenerife',
#   'direccion': 'CALLE IMELDO SERIS NUMERO 19',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.24949709,
#   'latitud': 28.465761761,
#   'geohash': 'eth3ynp3p6',
#   'utm_x': 377673.25,
#   'utm_y': 3149434.76},
#  {'fid': 27,
#   'etiqueta': 'HOTEL COLON RAMBLA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38038,
#   'nom_municipio': 'Santa Cruz de Tenerife',
#   'direccion': 'CALLE VIERA Y CLAVIJO, 49',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.25690102,
#   'latitud': 28.471322646,
#   'geohash': 'eth3yp416z',
#   'utm_x': 376954.78,
#   'utm_y': 3150058.45},
#  {'fid': 28,
#   'etiqueta': 'HOTEL BARCELÓ SANTA CRUZ CONTEMPORANEO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38038,
#   'nom_municipio': 'Santa Cruz de Tenerife',
#   'direccion': 'AVENIDA RAMBLA DE SANTA CRUZ, 116',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.25313653,
#   'latitud': 28.474049419,
#   'geohash': 'eth3ypsc67',
#   'utm_x': 377326.49,
#   'utm_y': 3150356.72},
#  {'fid': 29,
#   'etiqueta': 'HOTEL HORIZONTE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H1',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 1,
#   'nom_categor': '1 Estrella',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38038,
#   'nom_municipio': 'Santa Cruz de Tenerife',
#   'direccion': 'CALLE SANTA ROSA DE LIMA, 11',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.2496682,
#   'latitud': 28.470009033,
#   'geohash': 'eth3ynz3g6',
#   'utm_x': 377661.39,
#   'utm_y': 3149905.52},
#  {'fid': 30,
#   'etiqueta': 'HOTEL ADONIS PLAZA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38038,
#   'nom_municipio': 'Santa Cruz de Tenerife',
#   'direccion': 'PLAZA DE LA CANDELARIA, 10',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.24859157,
#   'latitud': 28.467083197,
#   'geohash': 'eth3yq20u2',
#   'utm_x': 377763.43,
#   'utm_y': 3149580.25},
#  {'fid': 31,
#   'etiqueta': 'HOTEL TABURIENTE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38038,
#   'nom_municipio': 'Santa Cruz de Tenerife',
#   'direccion': 'CALLE JOSE NAVEIRAS 24',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.25310838,
#   'latitud': 28.473421054,
#   'geohash': 'eth3ypkven',
#   'utm_x': 377328.52,
#   'utm_y': 3150287.07},
#  {'fid': 32,
#   'etiqueta': 'HOTEL AEROPUERTO SUR',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38017,
#   'nom_municipio': 'Granadilla de Abona',
#   'direccion': 'CALLE BENCHIJIGUA, 4',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.5557725,
#   'latitud': 28.073056047,
#   'geohash': 'esupxq83qs',
#   'utm_x': 347125.27,
#   'utm_y': 3106272.1},
#  {'fid': 33,
#   'etiqueta': 'HOTEL PRINCIPE PAZ',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38038,
#   'nom_municipio': 'Santa Cruz de Tenerife',
#   'direccion': 'CALLE VALENTIN SANZ, 33-35 ESQ. ADELANTADO',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.25083049,
#   'latitud': 28.46876366,
#   'geohash': 'eth3ynwd84',
#   'utm_x': 377546.16,
#   'utm_y': 3149768.72},
#  {'fid': 34,
#   'etiqueta': 'HOTEL ROBINSON CLUB JANDIA PLAYA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES704',
#   'nom_isla': 'Fuerteventura',
#   'gcd_entitur': 'ES704B4',
#   'nom_entitur': 'Morro Jable',
#   'gcd_nucltur': 'ES704B41',
#   'nom_nucltur': 'Morro Jable: Morro Jable',
#   'gcd_municipio': 35015,
#   'nom_municipio': 'Pájara',
#   'direccion': 'PLAYA DEL MATORRAL',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -14.34249039,
#   'latitud': 28.048471697,
#   'geohash': 'esvz9dh45y',
#   'utm_x': 564619.85,
#   'utm_y': 3102746.2},
#  {'fid': 35,
#   'etiqueta': 'HOTEL BARCELO SANTIAGO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B4',
#   'nom_entitur': 'Isora',
#   'gcd_nucltur': 'ES709B42',
#   'nom_nucltur': 'Puerto Santiago',
#   'gcd_municipio': 38040,
#   'nom_municipio': 'Santiago del Teide',
#   'direccion': 'CALLE LA HONDURA, N 8',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.84473264,
#   'latitud': 28.239184946,
#   'geohash': 'eth08sy11m',
#   'utm_x': 319005.91,
#   'utm_y': 3125077.51},
#  {'fid': 36,
#   'etiqueta': 'SUNPRIME CORAL SUITES & SPA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B22',
#   'nom_nucltur': 'Las Américas - Arona',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'AVENIDA NOELIA AFONSO, 10',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.73003197,
#   'latitud': 28.058281185,
#   'geohash': 'esupe7ce3f',
#   'utm_x': 329975.99,
#   'utm_y': 3104866.14},
#  {'fid': 37,
#   'etiqueta': 'GRAN HOTEL BAHIA DEL DUQUE RESORT',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H5',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 5,
#   'nom_categor': '5 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B13',
#   'nom_nucltur': 'Playa de El Duque',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'AVENIDA DE BRUSELAS,S/N',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.74219916,
#   'latitud': 28.093618184,
#   'geohash': 'esupg429nq',
#   'utm_x': 328836.07,
#   'utm_y': 3108798.71},
#  {'fid': 38,
#   'etiqueta': 'HOTEL PERLA TENERIFE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B53',
#   'nom_nucltur': 'Taoro - La Paz',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE ISLA DE LA GOMERA, S/N.',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.54118302,
#   'latitud': 28.408218247,
#   'geohash': 'eth1xee1f7',
#   'utm_x': 349031.85,
#   'utm_y': 3143390.27},
#  {'fid': 39,
#   'etiqueta': 'HOTEL LA QUINTA PARK SUITES & SPA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38039,
#   'nom_municipio': 'Santa Úrsula',
#   'direccion': 'CALLE BICACARERA 21, URBANIZACIÓN LA QUINTA',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.49521518,
#   'latitud': 28.429040885,
#   'geohash': 'eth38xke1t',
#   'utm_x': 353563.91,
#   'utm_y': 3145640.69},
#  {'fid': 40,
#   'etiqueta': 'HOTEL ESCUELA SANTA CRUZ',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38038,
#   'nom_municipio': 'Santa Cruz de Tenerife',
#   'direccion': 'AVENIDA SAN SEBASTIAN, 152',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.2596338,
#   'latitud': 28.463944122,
#   'geohash': 'eth3yj8n7p',
#   'utm_x': 376678.66,
#   'utm_y': 3149243.73},
#  {'fid': 41,
#   'etiqueta': 'HOTEL APART. VILLA DE ADEJE BEACH',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B14',
#   'nom_nucltur': 'Costa Adeje',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'AVENIDA DE LOS PUEBLO , 41',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.73065458,
#   'latitud': 28.080859672,
#   'geohash': 'esupercng7',
#   'utm_x': 329950.36,
#   'utm_y': 3107368.81},
#  {'fid': 42,
#   'etiqueta': 'IBEROSTAR GRAN HOTEL ANTHELIA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H5',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 5,
#   'nom_categor': '5 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B13',
#   'nom_nucltur': 'Playa de El Duque',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'CALLE LONDRES, 15',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.73793908,
#   'latitud': 28.089425948,
#   'geohash': 'esupg1ebcb',
#   'utm_x': 329248.04,
#   'utm_y': 3108328.2},
#  {'fid': 43,
#   'etiqueta': 'HOTEL JARDINES DE NIVARIA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H5',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 5,
#   'nom_categor': '5 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B13',
#   'nom_nucltur': 'Playa de El Duque',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'CALLE PARIS, S/N',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.7363035,
#   'latitud': 28.088810499,
#   'geohash': 'esupg1kvpv',
#   'utm_x': 329407.79,
#   'utm_y': 3108257.71},
#  {'fid': 44,
#   'etiqueta': 'HOTEL TORRE DEL CONDE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES706',
#   'nom_isla': 'La Gomera',
#   'gcd_entitur': 'ES700B9',
#   'nom_entitur': 'Islas de Canarias sin entidades turísticas',
#   'gcd_nucltur': 'ES700B99',
#   'nom_nucltur': 'Islas de Canarias sin núcleos turísticos',
#   'gcd_municipio': 38036,
#   'nom_municipio': 'San Sebastián de La Gomera',
#   'direccion': 'CALLE RUIZ DE PADRON Nº 19',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -17.11139986,
#   'latitud': 28.091391315,
#   'geohash': 'esgzf9gu5q',
#   'utm_x': 292550.93,
#   'utm_y': 3109126.71},
#  {'fid': 45,
#   'etiqueta': 'HOTEL RIU PALACE JANDIA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES704',
#   'nom_isla': 'Fuerteventura',
#   'gcd_entitur': 'ES704B4',
#   'nom_entitur': 'Morro Jable',
#   'gcd_nucltur': 'ES704B41',
#   'nom_nucltur': 'Morro Jable: Morro Jable',
#   'gcd_municipio': 35015,
#   'nom_municipio': 'Pájara',
#   'direccion': 'CALLE ARENA, S/N',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -14.34567686,
#   'latitud': 28.049103995,
#   'geohash': 'esvz9d1vce',
#   'utm_x': 564306.3,
#   'utm_y': 3102814.56},
#  {'fid': 46,
#   'etiqueta': 'HOTEL JACARANDA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B14',
#   'nom_nucltur': 'Costa Adeje',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'CALLE BRUSELAS, 4',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.73208652,
#   'latitud': 28.088176568,
#   'geohash': 'esupg3216p',
#   'utm_x': 329821.18,
#   'utm_y': 3108181.56},
#  {'fid': 47,
#   'etiqueta': 'HOTEL RIU ARECAS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B13',
#   'nom_nucltur': 'Playa de El Duque',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'URBANIZACIÓN LA HERRADURA, PARCELA I',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.74570677,
#   'latitud': 28.09500077,
#   'geohash': 'esupffw1hz',
#   'utm_x': 328493.6,
#   'utm_y': 3108956.85},
#  {'fid': 48,
#   'etiqueta': 'HOTEL H10 COSTA ADEJE PALACE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B13',
#   'nom_nucltur': 'Playa de El Duque',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'PLAYA DE LA ENRAMADA, S/N',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.74912396,
#   'latitud': 28.09685109,
#   'geohash': 'esupffgsj0',
#   'utm_x': 328160.77,
#   'utm_y': 3109166.7},
#  {'fid': 49,
#   'etiqueta': 'HOTEL RIU PALACE TENERIFE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B13',
#   'nom_nucltur': 'Playa de El Duque',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'CALLE LA HERRADURA, PARECELA I. URBANIZACIÓN. LA CALETA',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.74736972,
#   'latitud': 28.094513371,
#   'geohash': 'esupffkyqh',
#   'utm_x': 328329.42,
#   'utm_y': 3108905.19},
#  {'fid': 50,
#   'etiqueta': 'HOTEL FLAMINGO SUITE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B14',
#   'nom_nucltur': 'Costa Adeje',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'AVENIDA DE ESPAÑA, 6',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.73339542,
#   'latitud': 28.0799178,
#   'geohash': 'esupepz17s',
#   'utm_x': 329679.52,
#   'utm_y': 3107268.28},
#  {'fid': 51,
#   'etiqueta': 'PENSION CASSANDRA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H1',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 1,
#   'nom_categor': '1 Estrella',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'CALLE ROSALEDA NUMERO 7',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.6546558,
#   'latitud': 28.068601621,
#   'geohash': 'esuptj8rqq',
#   'utm_x': 337400.53,
#   'utm_y': 3105906.7},
#  {'fid': 52,
#   'etiqueta': 'HOTEL CATALONIA ORO NEGRO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B22',
#   'nom_nucltur': 'Las Américas - Arona',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'CALLE ARQUITECTO GÓMEZ CUESTA, 14',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.72688301,
#   'latitud': 28.063062346,
#   'geohash': 'esupekez5m',
#   'utm_x': 330293.03,
#   'utm_y': 3105391.52},
#  {'fid': 53,
#   'etiqueta': 'HOTEL APART. ASTORIA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE LA HOYA, 60',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.54532122,
#   'latitud': 28.416455346,
#   'geohash': 'eth1xt01f5',
#   'utm_x': 348638.15,
#   'utm_y': 3144308.17},
#  {'fid': 54,
#   'etiqueta': 'HOTEL TURQUESA PLAYA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B51',
#   'nom_nucltur': 'Playa Jardín - Maritim',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'URBANIZACIÓN TURQUESA PLAYA',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.55787708,
#   'latitud': 28.410501929,
#   'geohash': 'eth1x5yzjm',
#   'utm_x': 347399.62,
#   'utm_y': 3143664.36},
#  {'fid': 55,
#   'etiqueta': 'HOTEL CATALONIA LAS VEGAS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B54',
#   'nom_nucltur': 'Martiánez',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'AVENIDA COLÓN, 2',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.54495442,
#   'latitud': 28.417438083,
#   'geohash': 'eth1xt0rdd',
#   'utm_x': 348675.48,
#   'utm_y': 3144416.6},
#  {'fid': 56,
#   'etiqueta': 'HOTEL RIU PALACE TRES ISLAS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES704',
#   'nom_isla': 'Fuerteventura',
#   'gcd_entitur': 'ES704B2',
#   'nom_entitur': 'Corralejo - El Cotillo',
#   'gcd_nucltur': 'ES704B21',
#   'nom_nucltur': 'Corralejo',
#   'gcd_municipio': 35014,
#   'nom_municipio': 'La Oliva',
#   'direccion': 'PLAYA DE CORRALEJO',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -13.83878228,
#   'latitud': 28.712015673,
#   'geohash': 'etn5m4fgt5',
#   'utm_x': 613418.81,
#   'utm_y': 3176632.3},
#  {'fid': 57,
#   'etiqueta': 'HOTEL ATLANTIDA SANTA CRUZ',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38038,
#   'nom_municipio': 'Santa Cruz de Tenerife',
#   'direccion': 'CALLE 3 DE MAYO, ESQ. AUREA DÍAZ FLORES',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.25718645,
#   'latitud': 28.458711941,
#   'geohash': 'eth3yhcbh0',
#   'utm_x': 376912.22,
#   'utm_y': 3148661.51},
#  {'fid': 58,
#   'etiqueta': 'HOTEL APART. DRAGOS DEL SUR',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B4',
#   'nom_entitur': 'Isora',
#   'gcd_nucltur': 'ES709B42',
#   'nom_nucltur': 'Puerto Santiago',
#   'gcd_municipio': 38040,
#   'nom_municipio': 'Santiago del Teide',
#   'direccion': 'AVENIDA MARÍTIMA, ESQ. CALETA DEL JURADO',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.84152604,
#   'latitud': 28.235647485,
#   'geohash': 'eth08u0kef',
#   'utm_x': 319314.62,
#   'utm_y': 3124680.73},
#  {'fid': 59,
#   'etiqueta': 'HOTEL THE MIRADOR PAPAGAYO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B3',
#   'nom_entitur': 'Playa Blanca - Puerto Calero',
#   'gcd_nucltur': 'ES708B33',
#   'nom_nucltur': 'Playa Blanca: Rubicón - Papagayo',
#   'gcd_municipio': 35034,
#   'nom_municipio': 'Yaiza',
#   'direccion': 'CALLE LAS PALMAS, 5 - SAN MARCIAL DEL RUBICON',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -13.80427359,
#   'latitud': 28.858568483,
#   'geohash': 'etnhjvs135',
#   'utm_x': 616626.41,
#   'utm_y': 3192903.8},
#  {'fid': 60,
#   'etiqueta': 'PENSION RESIDENCIA EL DRAGO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H1',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 1,
#   'nom_categor': '1 Estrella',
#   'gcd_isla': 'ES707',
#   'nom_isla': 'La Palma',
#   'gcd_entitur': 'ES700B9',
#   'nom_entitur': 'Islas de Canarias sin entidades turísticas',
#   'gcd_nucltur': 'ES700B99',
#   'nom_nucltur': 'Islas de Canarias sin núcleos turísticos',
#   'gcd_municipio': 38033,
#   'nom_municipio': 'San Andrés y Sauces',
#   'direccion': 'AVENIDA LOS SAUCES, 36',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -17.77290143,
#   'latitud': 28.801339115,
#   'geohash': 'et57ge45vq',
#   'utm_x': 229347.78,
#   'utm_y': 3189132.87},
#  {'fid': 61,
#   'etiqueta': 'HOTEL ALISIOS CANTERAS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES705',
#   'nom_isla': 'Gran Canaria',
#   'gcd_entitur': 'ES705B2',
#   'nom_entitur': 'Las Canteras',
#   'gcd_nucltur': 'ES705B21',
#   'nom_nucltur': 'Las Canteras',
#   'gcd_municipio': 35016,
#   'nom_municipio': 'Las Palmas de Gran Canaria',
#   'direccion': 'CALLE COLOMBIA, 12',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -15.43917327,
#   'latitud': 28.13531531,
#   'geohash': 'etj009vs14',
#   'utm_x': 456873.2,
#   'utm_y': 3112270.03},
#  {'fid': 62,
#   'etiqueta': 'PENSION LAS LONJAS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H1',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 1,
#   'nom_categor': '1 Estrella',
#   'gcd_isla': 'ES707',
#   'nom_isla': 'La Palma',
#   'gcd_entitur': 'ES700B9',
#   'nom_entitur': 'Islas de Canarias sin entidades turísticas',
#   'gcd_nucltur': 'ES700B99',
#   'nom_nucltur': 'Islas de Canarias sin núcleos turísticos',
#   'gcd_municipio': 38033,
#   'nom_municipio': 'San Andrés y Sauces',
#   'direccion': 'SAN SEBASTIÁN, 16',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -17.76086387,
#   'latitud': 28.798554447,
#   'geohash': 'et57gfdgtz',
#   'utm_x': 230516.04,
#   'utm_y': 3188796.8},
#  {'fid': 63,
#   'etiqueta': 'PENSION CARIBE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H1',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 1,
#   'nom_categor': '1 Estrella',
#   'gcd_isla': 'ES703',
#   'nom_isla': 'El Hierro',
#   'gcd_entitur': 'ES700B9',
#   'nom_entitur': 'Islas de Canarias sin entidades turísticas',
#   'gcd_nucltur': 'ES700B99',
#   'nom_nucltur': 'Islas de Canarias sin núcleos turísticos',
#   'gcd_municipio': 38013,
#   'nom_municipio': 'Frontera',
#   'direccion': 'PUNTA GRANDE, 1',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -17.99066516,
#   'latitud': 27.796579285,
#   'geohash': 'esgnns5wg1',
#   'utm_x': 205323.77,
#   'utm_y': 3078257.25},
#  {'fid': 64,
#   'etiqueta': 'PENSION EL GUANCHE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H1',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 1,
#   'nom_categor': '1 Estrella',
#   'gcd_isla': 'ES703',
#   'nom_isla': 'El Hierro',
#   'gcd_entitur': 'ES700B9',
#   'nom_entitur': 'Islas de Canarias sin entidades turísticas',
#   'gcd_nucltur': 'ES700B99',
#   'nom_nucltur': 'Islas de Canarias sin núcleos turísticos',
#   'gcd_municipio': 38013,
#   'nom_municipio': 'Frontera',
#   'direccion': 'CALLE CRUZ ALTA, 1',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -18.01630244,
#   'latitud': 27.752541969,
#   'geohash': 'esgjyh0ym8',
#   'utm_x': 202676.48,
#   'utm_y': 3073437.16},
#  {'fid': 65,
#   'etiqueta': 'PENSION CASAÑAS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H2',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 2,
#   'nom_categor': '2 Estrellas',
#   'gcd_isla': 'ES703',
#   'nom_isla': 'El Hierro',
#   'gcd_entitur': 'ES700B9',
#   'nom_entitur': 'Islas de Canarias sin entidades turísticas',
#   'gcd_nucltur': 'ES700B99',
#   'nom_nucltur': 'Islas de Canarias sin núcleos turísticos',
#   'gcd_municipio': 38048,
#   'nom_municipio': 'Valverde',
#   'direccion': 'CALLE SAN FRANCISCO, 9',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -17.91468782,
#   'latitud': 27.806200537,
#   'geohash': 'esgq0mfyve',
#   'utm_x': 212839.02,
#   'utm_y': 3079143.64},
#  {'fid': 66,
#   'etiqueta': 'PENSION CENTRAL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H1',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 1,
#   'nom_categor': '1 Estrella',
#   'gcd_isla': 'ES707',
#   'nom_isla': 'La Palma',
#   'gcd_entitur': 'ES700B9',
#   'nom_entitur': 'Islas de Canarias sin entidades turísticas',
#   'gcd_nucltur': 'ES700B99',
#   'nom_nucltur': 'Islas de Canarias sin núcleos turísticos',
#   'gcd_municipio': 38014,
#   'nom_municipio': 'Fuencaliente',
#   'direccion': 'CALLE YAIZA, 1',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -17.84439717,
#   'latitud': 28.494632562,
#   'geohash': 'et561gq172',
#   'utm_x': 221556.37,
#   'utm_y': 3155296.41},
#  {'fid': 67,
#   'etiqueta': 'HOTEL R2 BAHIA PLAYA',
# ...
#   'gcd_nucltur': 'ES704B21',
#   'nom_nucltur': 'Corralejo',
#   'gcd_municipio': 35014,
#   'nom_municipio': 'La Oliva',
#   'direccion': 'CALLE ANGUILA, 1',
#   'prc_habita': 'De 40 a 79 apartamentos',
#   'prc_plazas': 'De 120 a 259 plazas',
#   'longitud': -13.87074351,
#   'latitud': 28.733881506,
#   'geohash': 'etn5kqgdur',
#   'utm_x': 610273.91,
#   'utm_y': 3179025.02},
#  {'fid': 654,
#   'etiqueta': 'HOTEL LAS COSTAS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B2',
#   'nom_entitur': 'Puerto del Carmen',
#   'gcd_nucltur': 'ES708B23',
#   'nom_nucltur': 'Puerto del Carmen: Matagorda - Los Pocillos',
#   'gcd_municipio': 35028,
#   'nom_municipio': 'Tías',
#   'direccion': 'AVENIDA DE LAS PLAYAS, 88',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -13.64060999,
#   'latitud': 28.922762362,
#   'geohash': 'etnk995pq9',
#   'utm_x': 632509.47,
#   'utm_y': 3200188.73},
#  {'fid': 655,
#   'etiqueta': 'HOTEL BAJAMAR',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H2',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 2,
#   'nom_categor': '2 Estrellas',
#   'gcd_isla': 'ES705',
#   'nom_isla': 'Gran Canaria',
#   'gcd_entitur': 'ES705B2',
#   'nom_entitur': 'Las Canteras',
#   'gcd_nucltur': 'ES705B21',
#   'nom_nucltur': 'Las Canteras',
#   'gcd_municipio': 35016,
#   'nom_municipio': 'Las Palmas de Gran Canaria',
#   'direccion': 'CALLE VENEZUELA, 34',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -15.43848921,
#   'latitud': 28.134927083,
#   'geohash': 'etj009y1c4',
#   'utm_x': 456940.22,
#   'utm_y': 3112226.78},
#  {'fid': 656,
#   'etiqueta': 'HOTEL MASPALOMAS-TABAIBA PRINCESS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES705',
#   'nom_isla': 'Gran Canaria',
#   'gcd_entitur': 'ES705B3',
#   'nom_entitur': 'Maspalomas',
#   'gcd_nucltur': 'ES705B33',
#   'nom_nucltur': 'Campo Internacional',
#   'gcd_municipio': 35019,
#   'nom_municipio': 'San Bartolomé de Tirajana',
#   'direccion': 'AVENIDA TOUROPERADOR TUI, S/N. CAMPO INTERNACIONAL',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -15.59720631,
#   'latitud': 27.75230078,
#   'geohash': 'esuvvh4kyg',
#   'utm_x': 441146.84,
#   'utm_y': 3069906.78},
#  {'fid': 657,
#   'etiqueta': 'HOTEL BAHÍA DE LOBOS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES704',
#   'nom_isla': 'Fuerteventura',
#   'gcd_entitur': 'ES704B2',
#   'nom_entitur': 'Corralejo - El Cotillo',
#   'gcd_nucltur': 'ES704B21',
#   'nom_nucltur': 'Corralejo',
#   'gcd_municipio': 35014,
#   'nom_municipio': 'La Oliva',
#   'direccion': 'AVENIDA GRAN CANARIA, 2',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -13.87133359,
#   'latitud': 28.730692262,
#   'geohash': 'etn5kq70qt',
#   'utm_x': 610219.63,
#   'utm_y': 3178671.11},
#  {'fid': 658,
#   'etiqueta': 'HOTEL BARCELO CORRALEJO BAY',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES704',
#   'nom_isla': 'Fuerteventura',
#   'gcd_entitur': 'ES704B2',
#   'nom_entitur': 'Corralejo - El Cotillo',
#   'gcd_nucltur': 'ES704B21',
#   'nom_nucltur': 'Corralejo',
#   'gcd_municipio': 35014,
#   'nom_municipio': 'La Oliva',
#   'direccion': 'AVENIDA GRANDES PLAYAS, 12',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -13.86742707,
#   'latitud': 28.732608444,
#   'geohash': 'etn5kqw59d',
#   'utm_x': 610599.13,
#   'utm_y': 3178887.04},
#  {'fid': 659,
#   'etiqueta': 'SENTIDO BUGANVILLA HOTEL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES704',
#   'nom_isla': 'Fuerteventura',
#   'gcd_entitur': 'ES704B4',
#   'nom_entitur': 'Morro Jable',
#   'gcd_nucltur': 'ES704B41',
#   'nom_nucltur': 'Morro Jable: Morro Jable',
#   'gcd_municipio': 35015,
#   'nom_municipio': 'Pájara',
#   'direccion': 'AVDA. SALADAR, S/N',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -14.33736206,
#   'latitud': 28.049423398,
#   'geohash': 'esvz9dpzep',
#   'utm_x': 565123.3,
#   'utm_y': 3102854.36},
#  {'fid': 660,
#   'etiqueta': 'HOTEL FARO JANDÍA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES704',
#   'nom_isla': 'Fuerteventura',
#   'gcd_entitur': 'ES704B4',
#   'nom_entitur': 'Morro Jable',
#   'gcd_nucltur': 'ES704B41',
#   'nom_nucltur': 'Morro Jable: Morro Jable',
#   'gcd_municipio': 35015,
#   'nom_municipio': 'Pájara',
#   'direccion': 'AVENIDA SALADAR, 17',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -14.33351038,
#   'latitud': 28.049816206,
#   'geohash': 'esvz9f6dj0',
#   'utm_x': 565501.61,
#   'utm_y': 3102899.94},
#  {'fid': 661,
#   'etiqueta': 'HOTEL PLAYA ESMERALDA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES704',
#   'nom_isla': 'Fuerteventura',
#   'gcd_entitur': 'ES704B3',
#   'nom_entitur': 'Costa Calma',
#   'gcd_nucltur': 'ES704B31',
#   'nom_nucltur': 'Costa Calma',
#   'gcd_municipio': 35015,
#   'nom_municipio': 'Pájara',
#   'direccion': 'CALLE PUNTA DEL ROQUITO, 2',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -14.23507337,
#   'latitud': 28.14886906,
#   'geohash': 'etjbhh6749',
#   'utm_x': 575107.15,
#   'utm_y': 3113930.07},
#  {'fid': 662,
#   'etiqueta': 'ELBA VECINDARIO AEROPUERTO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES705',
#   'nom_isla': 'Gran Canaria',
#   'gcd_entitur': 'ES705B9',
#   'nom_entitur': 'Resto de Gran Canaria',
#   'gcd_nucltur': 'ES705B9',
#   'nom_nucltur': 'Resto de Gran Canaria',
#   'gcd_municipio': 35022,
#   'nom_municipio': 'Santa Lucía de Tirajana',
#   'direccion': 'AVENIDA DEL ATLÁNTICO, 353',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -15.44106564,
#   'latitud': 27.840543037,
#   'geohash': 'esvn2shnvj',
#   'utm_x': 456569.4,
#   'utm_y': 3079616.78},
#  {'fid': 663,
#   'etiqueta': 'GRAND HOTEL RESIDENCIA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H5',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 5,
#   'nom_categor': '5 Estrellas',
#   'gcd_isla': 'ES705',
#   'nom_isla': 'Gran Canaria',
#   'gcd_entitur': 'ES705B3',
#   'nom_entitur': 'Maspalomas',
#   'gcd_nucltur': 'ES705B31',
#   'nom_nucltur': 'Meloneras',
#   'gcd_municipio': 35019,
#   'nom_municipio': 'San Bartolomé de Tirajana',
#   'direccion': 'AVENIDA DEL OASIS, 32',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -15.59706685,
#   'latitud': 27.739491752,
#   'geohash': 'esuvv1fd60',
#   'utm_x': 441153.7,
#   'utm_y': 3068487.8},
#  {'fid': 664,
#   'etiqueta': 'HOTEL IBEROSTAR BOUGANVILLE PLAYA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B14',
#   'nom_nucltur': 'Costa Adeje',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'URBANIZACIÓN SAN EUGENIO',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.73211868,
#   'latitud': 28.074768172,
#   'geohash': 'esupeqb53k',
#   'utm_x': 329796.87,
#   'utm_y': 3106695.89},
#  {'fid': 665,
#   'etiqueta': 'HOTEL MIRAMAR',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B9',
#   'nom_entitur': 'Resto de Lanzarote',
#   'gcd_nucltur': 'ES708B9',
#   'nom_nucltur': 'Resto de Lanzarote',
#   'gcd_municipio': 35004,
#   'nom_municipio': 'Arrecife',
#   'direccion': 'CALLE COLL, 2',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -13.54779971,
#   'latitud': 28.958682146,
#   'geohash': 'etnkexyb93',
#   'utm_x': 641508.53,
#   'utm_y': 3204276.37},
#  {'fid': 666,
#   'etiqueta': 'HOTEL LOS HIBISCOS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B14',
#   'nom_nucltur': 'Costa Adeje',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'URBANIZACIÓN SAN EUGENIO',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.73240303,
#   'latitud': 28.075653263,
#   'geohash': 'esupeppbdc',
#   'utm_x': 329770.32,
#   'utm_y': 3106794.36},
#  {'fid': 667,
#   'etiqueta': 'HOTEL JARDIN TROPICAL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B14',
#   'nom_nucltur': 'Costa Adeje',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'CALLE GRAN BRETAÑA S/N',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.73401776,
#   'latitud': 28.075889986,
#   'geohash': 'esupepn9vj',
#   'utm_x': 329612.0,
#   'utm_y': 3106822.85},
#  {'fid': 668,
#   'etiqueta': 'HOTEL HARD ROCK HOTEL TENERIFE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H5',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 5,
#   'nom_categor': '5 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B12',
#   'nom_nucltur': 'Playa Paraíso',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'AVENIDA DE ADEJE 300, S/N. (URBANIZACIÓN PLAYA PARAISO)',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.77447081,
#   'latitud': 28.121356574,
#   'geohash': 'esupfr34y2',
#   'utm_x': 325709.81,
#   'utm_y': 3111918.15},
#  {'fid': 669,
#   'etiqueta': 'HOVIMA LA PINTA BEACHFRONT FAMILY HOTEL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B14',
#   'nom_nucltur': 'Costa Adeje',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'AVENIDA ESPAÑA , 5. SAN EUGENIO URBANIZACIÓN.',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.73438333,
#   'latitud': 28.080365674,
#   'geohash': 'esupepy7ux',
#   'utm_x': 329583.14,
#   'utm_y': 3107319.29},
#  {'fid': 670,
#   'etiqueta': 'HOTEL APART. COLUMBUS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B22',
#   'nom_nucltur': 'Las Américas - Arona',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'AVENIDA SANTIAGO PUIG 6',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.7277789,
#   'latitud': 28.060790151,
#   'geohash': 'esupek71yw',
#   'utm_x': 330201.4,
#   'utm_y': 3105141.0},
#  {'fid': 671,
#   'etiqueta': 'HOTEL CONQUISTADOR',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B22',
#   'nom_nucltur': 'Las Américas - Arona',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'AVENIDA MARITIMA',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.73512991,
#   'latitud': 28.05752797,
#   'geohash': 'esupe5tygn',
#   'utm_x': 329473.7,
#   'utm_y': 3104789.81},
#  {'fid': 672,
#   'etiqueta': 'HOTEL GALA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B22',
#   'nom_nucltur': 'Las Américas - Arona',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'CALLE ARQUITECTO GOMEZ CUESTA , 3',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.73027876,
#   'latitud': 28.06646583,
#   'geohash': 'esupem37h0',
#   'utm_x': 329964.62,
#   'utm_y': 3105773.38},
#  {'fid': 673,
#   'etiqueta': 'HOTEL TIGOTAN PLAYA DE LAS AMÉRICAS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B22',
#   'nom_nucltur': 'Las Américas - Arona',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'AVENIDA NOELIA ALFONSO CABRERA, 6',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.72945794,
#   'latitud': 28.059923823,
#   'geohash': 'esupek1uzk',
#   'utm_x': 330035.0,
#   'utm_y': 3105047.35},
#  {'fid': 674,
#   'etiqueta': 'HOTEL SOL TENERIFE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B22',
#   'nom_nucltur': 'Las Américas - Arona',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'AVENIDA RAFAEL PUIG LLUVINA, 12',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.73164454,
#   'latitud': 28.064358257,
#   'geohash': 'esupekbqsr',
#   'utm_x': 329827.06,
#   'utm_y': 3105541.76},
#  {'fid': 675,
#   'etiqueta': 'HOTEL VULCANO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B22',
#   'nom_nucltur': 'Las Américas - Arona',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'CALLE ANTONIO DOMINGUEZ ALFONSO, 8',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.73041823,
#   'latitud': 28.056557974,
#   'geohash': 'esupe7932c',
#   'utm_x': 329935.31,
#   'utm_y': 3104675.74}]

# %%
# insertamos los datos en la coleccion 
coleccion.insert_many(df.to_dict("records"))

# %% [markdown]
# Si volvemos a `MongoDB Compass` se nos actualiza la colección con todas las entradas de nuestro *dataframe*

# %% [markdown]
# # Buscar datos en nuestra BBDD.

# %% [markdown]
# ## `find()`
#
# El método `find()` devuelve todas las ocurrencias que coincidan con nuestra búsqueda.
#
# ```pyhton
# micoleccion.find({campo1: filtro, campo2: filtro ... })
# ```

# %%
# si pasamos el parámetro de consulta sin niguna especificación, nos devolverá todos los elementos de la BBDD
coleccion.find()

# %%
# nos devuelve el primer elemento de la coleccion hecha lista
list(coleccion.find())[0]
# Out:
# {'_id': ObjectId('648d5f6afbe58f6d29f2d999'), 'niombre': 'juan'}

# %% [markdown]
# Imaginemos ahora que queremos filtrar los alojamientos de una isla en concreto, pero no sabemos que valores tenemos en concreto en ese campo. Lo primero que haremos será evaluar los valores únicos que tenemos en ese campo. Para eso usaremos el método `distinct`
#
# ```python
# micoleccion.distinct( "nombredelcampo" )
# ```

# %%
# todos los elementos unicos de una etiqueta de la coleccion
coleccion.distinct("nom_isla")
# Out:
# ['El Hierro',
#  'Fuerteventura',
#  'Gran Canaria',
#  'La Gomera',
#  'La Palma',
#  'Lanzarote',
#  'Tenerife']

# %% [markdown]
# ### Búsqueda de campos de tipo string

# %% [markdown]
# Ahora ya lo tenemos claro, y queremos sacar todos los alojamientos de la isla de "El Hierro".

# %%
list(coleccion.find({"nom_isla":"Tenerife"}))
# Out:
# [{'_id': ObjectId('648d6191fbe58f6d29f2d99e'),
#   'fid': 2,
#   'etiqueta': 'HOTEL PARADISE PARK',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B23',
#   'nom_nucltur': 'Los Cristianos',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'URBANIZACIÓN OASIS DEL SUR',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.70628369,
#   'latitud': 28.053428781,
#   'geohash': 'esupeffz56',
#   'utm_x': 332302.78,
#   'utm_y': 3104295.54},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d99f'),
#   'fid': 3,
#   'etiqueta': 'HOTEL CATALONIA PUNTA DEL REY',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38011,
#   'nom_municipio': 'Candelaria',
#   'direccion': 'AVENIDA GENERALISIMO, 165',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.36211189,
#   'latitud': 28.377361794,
#   'geohash': 'eth37tvqp5',
#   'utm_x': 366536.23,
#   'utm_y': 3139759.91},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9a0'),
#   'fid': 4,
#   'etiqueta': 'HOTEL MEDANO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B3',
#   'nom_entitur': 'Abona',
#   'gcd_nucltur': 'ES709B32',
#   'nom_nucltur': 'El Médano',
#   'gcd_municipio': 38017,
#   'nom_municipio': 'Granadilla de Abona',
#   'direccion': 'PASEO PICACHO, 2',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.53800193,
#   'latitud': 28.044016879,
#   'geohash': 'esupx9m2hx',
#   'utm_x': 348831.06,
#   'utm_y': 3103032.41},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9a1'),
#   'fid': 5,
#   'etiqueta': 'HOTEL PLAYA SUR TENERIFE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B3',
#   'nom_entitur': 'Abona',
#   'gcd_nucltur': 'ES709B32',
#   'nom_nucltur': 'El Médano',
#   'gcd_municipio': 38017,
#   'nom_municipio': 'Granadilla de Abona',
#   'direccion': 'PLAYA DEL MÉDANO, S/N',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.54282447,
#   'latitud': 28.041107416,
#   'geohash': 'esupx89zk3',
#   'utm_x': 348352.91,
#   'utm_y': 3102716.04},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9a2'),
#   'fid': 6,
#   'etiqueta': 'PARADOR TURISMO LAS CAÑADAS DEL TEIDE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H2',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 2,
#   'nom_categor': '2 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38026,
#   'nom_municipio': 'La Orotava',
#   'direccion': 'CALLE LAS CAÑADAS DEL TEIDE',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.62713435,
#   'latitud': 28.224399963,
#   'geohash': 'eth0tdh7p9',
#   'utm_x': 340336.74,
#   'utm_y': 3123133.08},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9a3'),
#   'fid': 7,
#   'etiqueta': 'HOTEL SUN HOLIDAYS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H1',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 1,
#   'nom_categor': '1 Estrella',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE LA PEÑITA, 6',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.55375492,
#   'latitud': 28.416832449,
#   'geohash': 'eth1xm1uj9',
#   'utm_x': 347812.51,
#   'utm_y': 3144360.59},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9a4'),
#   'fid': 8,
#   'etiqueta': 'HOTEL TAORO GARDEN',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B53',
#   'nom_nucltur': 'Taoro - La Paz',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE DINAMARCA, 3 (PARQUE TAORO)',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.54642938,
#   'latitud': 28.410945403,
#   'geohash': 'eth1xkp3b2',
#   'utm_x': 348521.75,
#   'utm_y': 3143699.04},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9a5'),
#   'fid': 9,
#   'etiqueta': 'APARTAMENTOS BAMBI',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A1',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 1,
#   'nom_categor': '1 Estrella',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE ENRIQUE TALG, 15',
#   'prc_habita': 'De 40 a 79 apartamentos',
#   'prc_plazas': 'De 50 a 119 plazas',
#   'longitud': -16.54528665,
#   'latitud': 28.416492741,
#   'geohash': 'eth1xt044f',
#   'utm_x': 348641.59,
#   'utm_y': 3144312.27},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9a6'),
#   'fid': 10,
#   'etiqueta': 'HC HOTEL MAGEC',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE CUPIDO, 11',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.55222297,
#   'latitud': 28.414682317,
#   'geohash': 'eth1xkep90',
#   'utm_x': 347959.51,
#   'utm_y': 3144120.41},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9a7'),
#   'fid': 11,
#   'etiqueta': 'HOTEL DON CANDIDO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H1',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 1,
#   'nom_categor': '1 Estrella',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B53',
#   'nom_nucltur': 'Taoro - La Paz',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE PORTUGAL, 10. (URBANIZACIÓN. SAN FERNANDO)',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.54591798,
#   'latitud': 28.410362151,
#   'geohash': 'eth1x7zwk5',
#   'utm_x': 348571.02,
#   'utm_y': 3143633.77},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9a9'),
#   'fid': 13,
#   'etiqueta': 'HOTEL INTERPALACE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B53',
#   'nom_nucltur': 'Taoro - La Paz',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE ACEVIÑO, 21',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.53579714,
#   'latitud': 28.415682546,
#   'geohash': 'eth1xsyvrg',
#   'utm_x': 349570.05,
#   'utm_y': 3144210.6},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9aa'),
#   'fid': 14,
#   'etiqueta': 'SMY HOTEL PUERTO DE LA CRUZ',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B53',
#   'nom_nucltur': 'Taoro - La Paz',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE MARQUES VILLANUEVA DEL PRADO, S/N.',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.54199841,
#   'latitud': 28.414125234,
#   'geohash': 'eth1xsdkr2',
#   'utm_x': 348960.35,
#   'utm_y': 3144045.81},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9ab'),
#   'fid': 15,
#   'etiqueta': 'HOTEL ELEGANCE MIRAMAR',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B53',
#   'nom_nucltur': 'Taoro - La Paz',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'PARQUE DE TAORO, Nº 23',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.54734603,
#   'latitud': 28.411936216,
#   'geohash': 'eth1xknxdb',
#   'utm_x': 348433.36,
#   'utm_y': 3143809.98},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9ac'),
#   'fid': 16,
#   'etiqueta': 'HOTEL MONOPOL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE QUINTANA, 15',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.54848929,
#   'latitud': 28.417324372,
#   'geohash': 'eth1xmjybm',
#   'utm_x': 348329.04,
#   'utm_y': 3144408.45},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9ad'),
#   'fid': 17,
#   'etiqueta': 'HOTEL NOPAL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE SAN JUAN, 15',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.54944003,
#   'latitud': 28.41584195,
#   'geohash': 'eth1xkvn60',
#   'utm_x': 348233.79,
#   'utm_y': 3144245.39},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9ae'),
#   'fid': 18,
#   'etiqueta': 'HOTEL PUERTO PALACE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B51',
#   'nom_nucltur': 'Playa Jardín - Maritim',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE DOCTOR COBIELLA ZAERA, 2',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.55050638,
#   'latitud': 28.408142735,
#   'geohash': 'eth1x7s33j',
#   'utm_x': 348118.34,
#   'utm_y': 3143393.63},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9af'),
#   'fid': 19,
#   'etiqueta': 'HOTEL SAN BORONDON',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE AGUSTIN DE ESPINOSA, 2',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.5555382,
#   'latitud': 28.414927593,
#   'geohash': 'eth1xkb8gy',
#   'utm_x': 347635.09,
#   'utm_y': 3144151.78},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9b0'),
#   'fid': 20,
#   'etiqueta': 'HOTEL H10 TENERIFE PLAYA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B54',
#   'nom_nucltur': 'Martiánez',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'AVENIDA COLON, 12',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.542701,
#   'latitud': 28.418856184,
#   'geohash': 'eth1xt3zz4',
#   'utm_x': 348898.24,
#   'utm_y': 3144570.9},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9b1'),
#   'fid': 21,
#   'etiqueta': 'HOTEL EL TOPE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B53',
#   'nom_nucltur': 'Taoro - La Paz',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALZADA DE MARTIANEZ, 2',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.54370429,
#   'latitud': 28.414635127,
#   'geohash': 'eth1xs9ppx',
#   'utm_x': 348793.96,
#   'utm_y': 3144104.45},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9b2'),
#   'fid': 22,
#   'etiqueta': 'HOTEL TROPICAL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE PUERTO VIEJO, 1',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.55123592,
#   'latitud': 28.416177895,
#   'geohash': 'eth1xm5b0p',
#   'utm_x': 348058.34,
#   'utm_y': 3144284.88},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9b4'),
#   'fid': 24,
#   'etiqueta': 'HOTEL APART. PANORAMICA GARDEN',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38031,
#   'nom_municipio': 'Los Realejos',
#   'direccion': 'CALLE LA LONGUERA, S/N',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.58136253,
#   'latitud': 28.397469054,
#   'geohash': 'eth1w9tg4p',
#   'utm_x': 345079.84,
#   'utm_y': 3142250.25},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9b5'),
#   'fid': 25,
#   'etiqueta': 'HOTEL MARITIM',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B51',
#   'nom_nucltur': 'Playa Jardín - Maritim',
#   'gcd_municipio': 38031,
#   'nom_municipio': 'Los Realejos',
#   'direccion': 'CALLE EL BURGADO S/N',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.57059077,
#   'latitud': 28.406585643,
#   'geohash': 'eth1wgm8m5',
#   'utm_x': 346148.43,
#   'utm_y': 3143246.6},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9b6'),
#   'fid': 26,
#   'etiqueta': 'URBAN ANAGA HOTEL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38038,
#   'nom_municipio': 'Santa Cruz de Tenerife',
#   'direccion': 'CALLE IMELDO SERIS NUMERO 19',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.24949709,
#   'latitud': 28.465761761,
#   'geohash': 'eth3ynp3p6',
#   'utm_x': 377673.25,
#   'utm_y': 3149434.76},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9b7'),
#   'fid': 27,
#   'etiqueta': 'HOTEL COLON RAMBLA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38038,
#   'nom_municipio': 'Santa Cruz de Tenerife',
#   'direccion': 'CALLE VIERA Y CLAVIJO, 49',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.25690102,
#   'latitud': 28.471322646,
#   'geohash': 'eth3yp416z',
#   'utm_x': 376954.78,
#   'utm_y': 3150058.45},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9b8'),
#   'fid': 28,
#   'etiqueta': 'HOTEL BARCELÓ SANTA CRUZ CONTEMPORANEO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38038,
#   'nom_municipio': 'Santa Cruz de Tenerife',
#   'direccion': 'AVENIDA RAMBLA DE SANTA CRUZ, 116',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.25313653,
#   'latitud': 28.474049419,
#   'geohash': 'eth3ypsc67',
#   'utm_x': 377326.49,
#   'utm_y': 3150356.72},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9b9'),
#   'fid': 29,
#   'etiqueta': 'HOTEL HORIZONTE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H1',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 1,
#   'nom_categor': '1 Estrella',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38038,
#   'nom_municipio': 'Santa Cruz de Tenerife',
#   'direccion': 'CALLE SANTA ROSA DE LIMA, 11',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.2496682,
#   'latitud': 28.470009033,
#   'geohash': 'eth3ynz3g6',
#   'utm_x': 377661.39,
#   'utm_y': 3149905.52},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9ba'),
#   'fid': 30,
#   'etiqueta': 'HOTEL ADONIS PLAZA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38038,
#   'nom_municipio': 'Santa Cruz de Tenerife',
#   'direccion': 'PLAZA DE LA CANDELARIA, 10',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.24859157,
#   'latitud': 28.467083197,
#   'geohash': 'eth3yq20u2',
#   'utm_x': 377763.43,
#   'utm_y': 3149580.25},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9bb'),
#   'fid': 31,
#   'etiqueta': 'HOTEL TABURIENTE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38038,
#   'nom_municipio': 'Santa Cruz de Tenerife',
#   'direccion': 'CALLE JOSE NAVEIRAS 24',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.25310838,
#   'latitud': 28.473421054,
#   'geohash': 'eth3ypkven',
#   'utm_x': 377328.52,
#   'utm_y': 3150287.07},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9bc'),
#   'fid': 32,
#   'etiqueta': 'HOTEL AEROPUERTO SUR',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38017,
#   'nom_municipio': 'Granadilla de Abona',
#   'direccion': 'CALLE BENCHIJIGUA, 4',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.5557725,
#   'latitud': 28.073056047,
#   'geohash': 'esupxq83qs',
#   'utm_x': 347125.27,
#   'utm_y': 3106272.1},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9bd'),
#   'fid': 33,
#   'etiqueta': 'HOTEL PRINCIPE PAZ',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38038,
#   'nom_municipio': 'Santa Cruz de Tenerife',
#   'direccion': 'CALLE VALENTIN SANZ, 33-35 ESQ. ADELANTADO',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.25083049,
#   'latitud': 28.46876366,
#   'geohash': 'eth3ynwd84',
#   'utm_x': 377546.16,
#   'utm_y': 3149768.72},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9bf'),
#   'fid': 35,
#   'etiqueta': 'HOTEL BARCELO SANTIAGO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B4',
#   'nom_entitur': 'Isora',
#   'gcd_nucltur': 'ES709B42',
#   'nom_nucltur': 'Puerto Santiago',
#   'gcd_municipio': 38040,
#   'nom_municipio': 'Santiago del Teide',
#   'direccion': 'CALLE LA HONDURA, N 8',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.84473264,
#   'latitud': 28.239184946,
#   'geohash': 'eth08sy11m',
#   'utm_x': 319005.91,
#   'utm_y': 3125077.51},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9c0'),
#   'fid': 36,
#   'etiqueta': 'SUNPRIME CORAL SUITES & SPA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B22',
#   'nom_nucltur': 'Las Américas - Arona',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'AVENIDA NOELIA AFONSO, 10',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.73003197,
#   'latitud': 28.058281185,
#   'geohash': 'esupe7ce3f',
#   'utm_x': 329975.99,
#   'utm_y': 3104866.14},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9c1'),
#   'fid': 37,
#   'etiqueta': 'GRAN HOTEL BAHIA DEL DUQUE RESORT',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H5',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 5,
#   'nom_categor': '5 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B13',
#   'nom_nucltur': 'Playa de El Duque',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'AVENIDA DE BRUSELAS,S/N',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.74219916,
#   'latitud': 28.093618184,
#   'geohash': 'esupg429nq',
#   'utm_x': 328836.07,
#   'utm_y': 3108798.71},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9c2'),
#   'fid': 38,
#   'etiqueta': 'HOTEL PERLA TENERIFE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B53',
#   'nom_nucltur': 'Taoro - La Paz',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE ISLA DE LA GOMERA, S/N.',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.54118302,
#   'latitud': 28.408218247,
#   'geohash': 'eth1xee1f7',
#   'utm_x': 349031.85,
#   'utm_y': 3143390.27},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9c3'),
#   'fid': 39,
#   'etiqueta': 'HOTEL LA QUINTA PARK SUITES & SPA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38039,
#   'nom_municipio': 'Santa Úrsula',
#   'direccion': 'CALLE BICACARERA 21, URBANIZACIÓN LA QUINTA',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.49521518,
#   'latitud': 28.429040885,
#   'geohash': 'eth38xke1t',
#   'utm_x': 353563.91,
#   'utm_y': 3145640.69},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9c4'),
#   'fid': 40,
#   'etiqueta': 'HOTEL ESCUELA SANTA CRUZ',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38038,
#   'nom_municipio': 'Santa Cruz de Tenerife',
#   'direccion': 'AVENIDA SAN SEBASTIAN, 152',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.2596338,
#   'latitud': 28.463944122,
#   'geohash': 'eth3yj8n7p',
#   'utm_x': 376678.66,
#   'utm_y': 3149243.73},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9c5'),
#   'fid': 41,
#   'etiqueta': 'HOTEL APART. VILLA DE ADEJE BEACH',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B14',
#   'nom_nucltur': 'Costa Adeje',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'AVENIDA DE LOS PUEBLO , 41',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.73065458,
#   'latitud': 28.080859672,
#   'geohash': 'esupercng7',
#   'utm_x': 329950.36,
#   'utm_y': 3107368.81},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9c6'),
#   'fid': 42,
#   'etiqueta': 'IBEROSTAR GRAN HOTEL ANTHELIA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H5',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 5,
#   'nom_categor': '5 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B13',
#   'nom_nucltur': 'Playa de El Duque',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'CALLE LONDRES, 15',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.73793908,
#   'latitud': 28.089425948,
#   'geohash': 'esupg1ebcb',
#   'utm_x': 329248.04,
#   'utm_y': 3108328.2},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9c7'),
#   'fid': 43,
#   'etiqueta': 'HOTEL JARDINES DE NIVARIA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H5',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 5,
#   'nom_categor': '5 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B13',
#   'nom_nucltur': 'Playa de El Duque',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'CALLE PARIS, S/N',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.7363035,
#   'latitud': 28.088810499,
#   'geohash': 'esupg1kvpv',
#   'utm_x': 329407.79,
#   'utm_y': 3108257.71},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9ca'),
#   'fid': 46,
#   'etiqueta': 'HOTEL JACARANDA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B14',
#   'nom_nucltur': 'Costa Adeje',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'CALLE BRUSELAS, 4',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.73208652,
#   'latitud': 28.088176568,
#   'geohash': 'esupg3216p',
#   'utm_x': 329821.18,
#   'utm_y': 3108181.56},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9cb'),
#   'fid': 47,
#   'etiqueta': 'HOTEL RIU ARECAS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B13',
#   'nom_nucltur': 'Playa de El Duque',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'URBANIZACIÓN LA HERRADURA, PARCELA I',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.74570677,
#   'latitud': 28.09500077,
#   'geohash': 'esupffw1hz',
#   'utm_x': 328493.6,
#   'utm_y': 3108956.85},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9cc'),
#   'fid': 48,
#   'etiqueta': 'HOTEL H10 COSTA ADEJE PALACE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B13',
#   'nom_nucltur': 'Playa de El Duque',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'PLAYA DE LA ENRAMADA, S/N',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.74912396,
#   'latitud': 28.09685109,
#   'geohash': 'esupffgsj0',
#   'utm_x': 328160.77,
#   'utm_y': 3109166.7},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9cd'),
#   'fid': 49,
#   'etiqueta': 'HOTEL RIU PALACE TENERIFE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B13',
#   'nom_nucltur': 'Playa de El Duque',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'CALLE LA HERRADURA, PARECELA I. URBANIZACIÓN. LA CALETA',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.74736972,
#   'latitud': 28.094513371,
#   'geohash': 'esupffkyqh',
#   'utm_x': 328329.42,
#   'utm_y': 3108905.19},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9ce'),
#   'fid': 50,
#   'etiqueta': 'HOTEL FLAMINGO SUITE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B14',
#   'nom_nucltur': 'Costa Adeje',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'AVENIDA DE ESPAÑA, 6',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.73339542,
#   'latitud': 28.0799178,
#   'geohash': 'esupepz17s',
#   'utm_x': 329679.52,
#   'utm_y': 3107268.28},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9cf'),
#   'fid': 51,
#   'etiqueta': 'PENSION CASSANDRA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H1',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 1,
#   'nom_categor': '1 Estrella',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'CALLE ROSALEDA NUMERO 7',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.6546558,
#   'latitud': 28.068601621,
#   'geohash': 'esuptj8rqq',
#   'utm_x': 337400.53,
#   'utm_y': 3105906.7},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9d0'),
#   'fid': 52,
#   'etiqueta': 'HOTEL CATALONIA ORO NEGRO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B22',
#   'nom_nucltur': 'Las Américas - Arona',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'CALLE ARQUITECTO GÓMEZ CUESTA, 14',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.72688301,
#   'latitud': 28.063062346,
#   'geohash': 'esupekez5m',
#   'utm_x': 330293.03,
#   'utm_y': 3105391.52},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9d1'),
#   'fid': 53,
#   'etiqueta': 'HOTEL APART. ASTORIA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE LA HOYA, 60',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.54532122,
#   'latitud': 28.416455346,
#   'geohash': 'eth1xt01f5',
#   'utm_x': 348638.15,
#   'utm_y': 3144308.17},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9d2'),
#   'fid': 54,
#   'etiqueta': 'HOTEL TURQUESA PLAYA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B51',
#   'nom_nucltur': 'Playa Jardín - Maritim',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'URBANIZACIÓN TURQUESA PLAYA',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.55787708,
#   'latitud': 28.410501929,
#   'geohash': 'eth1x5yzjm',
#   'utm_x': 347399.62,
#   'utm_y': 3143664.36},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9d3'),
#   'fid': 55,
#   'etiqueta': 'HOTEL CATALONIA LAS VEGAS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B54',
#   'nom_nucltur': 'Martiánez',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'AVENIDA COLÓN, 2',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.54495442,
#   'latitud': 28.417438083,
#   'geohash': 'eth1xt0rdd',
#   'utm_x': 348675.48,
#   'utm_y': 3144416.6},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9d5'),
#   'fid': 57,
#   'etiqueta': 'HOTEL ATLANTIDA SANTA CRUZ',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38038,
#   'nom_municipio': 'Santa Cruz de Tenerife',
#   'direccion': 'CALLE 3 DE MAYO, ESQ. AUREA DÍAZ FLORES',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.25718645,
#   'latitud': 28.458711941,
#   'geohash': 'eth3yhcbh0',
#   'utm_x': 376912.22,
#   'utm_y': 3148661.51},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9d6'),
#   'fid': 58,
#   'etiqueta': 'HOTEL APART. DRAGOS DEL SUR',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B4',
#   'nom_entitur': 'Isora',
#   'gcd_nucltur': 'ES709B42',
#   'nom_nucltur': 'Puerto Santiago',
#   'gcd_municipio': 38040,
#   'nom_municipio': 'Santiago del Teide',
#   'direccion': 'AVENIDA MARÍTIMA, ESQ. CALETA DEL JURADO',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.84152604,
#   'latitud': 28.235647485,
#   'geohash': 'eth08u0kef',
#   'utm_x': 319314.62,
#   'utm_y': 3124680.73},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9f2'),
#   'fid': 86,
#   'etiqueta': 'HOSTAL BERLIN',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H1',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 1,
#   'nom_categor': '1 Estrella',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38023,
#   'nom_municipio': 'La Laguna',
#   'direccion': 'CALLE MARCELINO PERDOMO REYES, 1',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.32410105,
#   'latitud': 28.483911414,
#   'geohash': 'eth6h934uc',
#   'utm_x': 370390.93,
#   'utm_y': 3151523.93},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9fc'),
#   'fid': 96,
#   'etiqueta': 'HOTEL BE LIVE COSTA LOS GIGANTES',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B4',
#   'nom_entitur': 'Isora',
#   'gcd_nucltur': 'ES709B42',
#   'nom_nucltur': 'Puerto Santiago',
#   'gcd_municipio': 38040,
#   'nom_municipio': 'Santiago del Teide',
#   'direccion': 'CALLE JUAN MANUEL CAPDEVIELLE , 8',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.83699851,
#   'latitud': 28.233926893,
#   'geohash': 'eth08ggdt3',
#   'utm_x': 319756.04,
#   'utm_y': 3124483.32},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9fd'),
#   'fid': 97,
#   'etiqueta': 'HOTEL GRAN TACANDE COSTA ADEJE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H5',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 5,
#   'nom_categor': '5 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B13',
#   'nom_nucltur': 'Playa de El Duque',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'CALLE WALTER PAETZMANN S/N',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.73984344,
#   'latitud': 28.09185846,
#   'geohash': 'esupg1fqvm',
#   'utm_x': 329064.76,
#   'utm_y': 3108600.41},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9fe'),
#   'fid': 98,
#   'etiqueta': 'APARTHOTEL ISABEL FAMILY',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B14',
#   'nom_nucltur': 'Costa Adeje',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'AVENIDA DE MOSCU, 2',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.73419473,
#   'latitud': 28.091233456,
#   'geohash': 'esupg1ye31',
#   'utm_x': 329618.84,
#   'utm_y': 3108523.23},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da08'),
#   'fid': 108,
#   'etiqueta': 'HOTEL BE LIVE LA NIÑA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B14',
#   'nom_nucltur': 'Costa Adeje',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'AVENIDA DE ESPAÑA S/N - URBANIZACIÓN SAN EUGENIO',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.73222064,
#   'latitud': 28.080480989,
#   'geohash': 'esupepzuxj',
#   'utm_x': 329795.86,
#   'utm_y': 3107329.04},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da09'),
#   'fid': 109,
#   'etiqueta': 'HOTEL SHERATON LA CALETA RESORT & SPA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H5',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 5,
#   'nom_categor': '5 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B13',
#   'nom_nucltur': 'Playa de El Duque',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'CALLE LA ENRAMADA POLIGONO 9',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.74850161,
#   'latitud': 28.095701142,
#   'geohash': 'esupffsj7d',
#   'utm_x': 328220.09,
#   'utm_y': 3109038.4},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da0a'),
#   'fid': 110,
#   'etiqueta': 'HOTEL LAS MADRIGUERAS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H5',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 5,
#   'nom_categor': '5 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B22',
#   'nom_nucltur': 'Las Américas - Arona',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'GOLF LAS AMÉRICAS',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.71407814,
#   'latitud': 28.062323879,
#   'geohash': 'esupest4vu',
#   'utm_x': 331550.47,
#   'utm_y': 3105291.91},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da0d'),
#   'fid': 113,
#   'etiqueta': 'RITZ CARLTON ABAMA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H5',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 5,
#   'nom_categor': '5 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38019,
#   'nom_municipio': 'Guía de Isora',
#   'direccion': 'CARRETERA GENERAL TF-47 KM 9',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.79944751,
#   'latitud': 28.171036353,
#   'geohash': 'eth038rh0t',
#   'utm_x': 323337.71,
#   'utm_y': 3117459.15},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da0e'),
#   'fid': 114,
#   'etiqueta': 'HOTEL CHATUR PLAYA REAL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B14',
#   'nom_nucltur': 'Costa Adeje',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'AVENIDA MOSCU, 111',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.7313945,
#   'latitud': 28.09172567,
#   'geohash': 'esupg3bw4m',
#   'utm_x': 329894.78,
#   'utm_y': 3108573.85},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da0f'),
#   'fid': 115,
#   'etiqueta': 'HOTEL BAHIA FLAMINGO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B4',
#   'nom_entitur': 'Isora',
#   'gcd_nucltur': 'ES709B42',
#   'nom_nucltur': 'Puerto Santiago',
#   'gcd_municipio': 38019,
#   'nom_municipio': 'Guía de Isora',
#   'direccion': 'AVENIDA LA GAVIOTA, 3',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.83856488,
#   'latitud': 28.22670508,
#   'geohash': 'eth08fd82z',
#   'utm_x': 319590.17,
#   'utm_y': 3123685.4},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da12'),
#   'fid': 118,
#   'etiqueta': 'HOTEL OCEAN VIEW',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B21',
#   'nom_nucltur': 'Las Américas - Adeje',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'AVDA. LOS PUEBLOS, S/N.',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.72930779,
#   'latitud': 28.071005228,
#   'geohash': 'esupeq4j6y',
#   'utm_x': 330067.2,
#   'utm_y': 3106275.01},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da13'),
#   'fid': 119,
#   'etiqueta': 'HOTEL FLAMINGO BEACH MATE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B14',
#   'nom_nucltur': 'Costa Adeje',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'AVENIDA ESPAÑA 3',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.73409279,
#   'latitud': 28.079103698,
#   'geohash': 'esupepwsek',
#   'utm_x': 329609.7,
#   'utm_y': 3107179.05},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da14'),
#   'fid': 120,
#   'etiqueta': 'HOTEL TAGORO COSTA ADEJE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
# ...
#   'longitud': -16.83815,
#   'latitud': 28.245229996,
#   'geohash': 'eth08vfu6s',
#   'utm_x': 319662.06,
#   'utm_y': 3125737.54},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e145'),
#   'fid': 609,
#   'etiqueta': 'HOTEL BAOBAB SUITES',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H5',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 5,
#   'nom_categor': '5 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B13',
#   'nom_nucltur': 'Playa de El Duque',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'C/. ROQUES DEL SALMOR, Nº 5',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.74063,
#   'latitud': 28.095759999,
#   'geohash': 'esupg49vej',
#   'utm_x': 328993.66,
#   'utm_y': 3109033.83},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e14c'),
#   'fid': 616,
#   'etiqueta': 'HOTEL MC SAN AGUSTÍN',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H5',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 5,
#   'nom_categor': '5 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38023,
#   'nom_municipio': 'La Laguna',
#   'direccion': 'CALLE SAN AGUSTÍN, Nº 12',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.31422687,
#   'latitud': 28.489244546,
#   'geohash': 'eth6hf23fu',
#   'utm_x': 371364.02,
#   'utm_y': 3152104.22},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e14f'),
#   'fid': 619,
#   'etiqueta': 'HOTEL LA LAGUNA GRAN HOTEL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38023,
#   'nom_municipio': 'La Laguna',
#   'direccion': 'C/. NAVA Y GRIMÓN, Nº 18',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.31332598,
#   'latitud': 28.489131501,
#   'geohash': 'eth6hf2cpz',
#   'utm_x': 371452.07,
#   'utm_y': 3152090.73},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e151'),
#   'fid': 621,
#   'etiqueta': 'KLAYMAN DIAMOND APARTHOTEL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A1',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 1,
#   'nom_categor': '1 Estrella',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B4',
#   'nom_entitur': 'Isora',
#   'gcd_nucltur': 'ES709B41',
#   'nom_nucltur': 'Los Gigantes',
#   'gcd_municipio': 38040,
#   'nom_municipio': 'Santiago del Teide',
#   'direccion': 'C/ TABAIBA, 5',
#   'prc_habita': 'De 20 a 39 apartamentos',
#   'prc_plazas': 'De 50 a 119 plazas',
#   'longitud': -16.83873986,
#   'latitud': 28.245352645,
#   'geohash': 'eth08vfmhg',
#   'utm_x': 319604.38,
#   'utm_y': 3125752.01},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e153'),
#   'fid': 623,
#   'etiqueta': 'HOTEL LAS CAÑADAS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H1',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 1,
#   'nom_categor': '1 Estrella',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38032,
#   'nom_municipio': 'El Rosario',
#   'direccion': 'CARRETERA GENERAL LA ESPERANZA KM 7.5, NUMERO 73',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.36930851,
#   'latitud': 28.443046552,
#   'geohash': 'eth3g9bhz2',
#   'utm_x': 365913.78,
#   'utm_y': 3147045.72},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e154'),
#   'fid': 624,
#   'etiqueta': 'ROYAL HIDEAWAY CORALES RESORT',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H5',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 5,
#   'nom_categor': '5 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B13',
#   'nom_nucltur': 'Playa de El Duque',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'AVDA. VIRGEN DE GUADALUPE, 21',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.75213,
#   'latitud': 28.100208003,
#   'geohash': 'esupfg3rx4',
#   'utm_x': 327870.75,
#   'utm_y': 3109542.92},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e158'),
#   'fid': 628,
#   'etiqueta': 'HOTEL ISLA BAJA SUITES',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38015,
#   'nom_municipio': 'Garachico',
#   'direccion': 'C/. ESTEBAN DE PONTE, Nº 3',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.76562304,
#   'latitud': 28.372891012,
#   'geohash': 'eth16mpshd',
#   'utm_x': 326985.63,
#   'utm_y': 3139777.61},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e15b'),
#   'fid': 631,
#   'etiqueta': 'HOTEL GF VICTORIA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H5',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 5,
#   'nom_categor': '5 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B13',
#   'nom_nucltur': 'Playa de El Duque',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'C/. FERNANDO LÓPEZ ARVELO, Nº 1',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.739,
#   'latitud': 28.091839997,
#   'geohash': 'esupg1gnc4',
#   'utm_x': 329147.61,
#   'utm_y': 3108597.18},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e15f'),
#   'fid': 635,
#   'etiqueta': 'FANTASÍA BAHÍA PRÍNCIPE TENERIFE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H5',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 5,
#   'nom_categor': '5 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B3',
#   'nom_entitur': 'Abona',
#   'gcd_nucltur': 'ES709B33',
#   'nom_nucltur': 'Golf del Sur',
#   'gcd_municipio': 38035,
#   'nom_municipio': 'San Miguel de Abona',
#   'direccion': 'AVDA. JOSÉ MIGUEL GALVÁN BELLO, S/N',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.606289,
#   'latitud': 28.027067996,
#   'geohash': 'esupqn5tt2',
#   'utm_x': 342093.46,
#   'utm_y': 3101241.09},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e163'),
#   'fid': 639,
#   'etiqueta': 'LAS TERRAZAS DE ABAMA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A5',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 5,
#   'nom_categor': '5 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38019,
#   'nom_municipio': 'Guía de Isora',
#   'direccion': 'CARRETERA GENERAL DEL SUR, TF-47, KM 9',
#   'prc_habita': '80 o más apartamentos',
#   'prc_plazas': '260 o más plazas',
#   'longitud': -16.79185925,
#   'latitud': 28.169655212,
#   'geohash': 'eth03bhs1k',
#   'utm_x': 324080.57,
#   'utm_y': 3117295.08},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e17c'),
#   'fid': 664,
#   'etiqueta': 'HOTEL IBEROSTAR BOUGANVILLE PLAYA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B14',
#   'nom_nucltur': 'Costa Adeje',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'URBANIZACIÓN SAN EUGENIO',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.73211868,
#   'latitud': 28.074768172,
#   'geohash': 'esupeqb53k',
#   'utm_x': 329796.87,
#   'utm_y': 3106695.89},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e17e'),
#   'fid': 666,
#   'etiqueta': 'HOTEL LOS HIBISCOS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B14',
#   'nom_nucltur': 'Costa Adeje',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'URBANIZACIÓN SAN EUGENIO',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.73240303,
#   'latitud': 28.075653263,
#   'geohash': 'esupeppbdc',
#   'utm_x': 329770.32,
#   'utm_y': 3106794.36},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e17f'),
#   'fid': 667,
#   'etiqueta': 'HOTEL JARDIN TROPICAL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B14',
#   'nom_nucltur': 'Costa Adeje',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'CALLE GRAN BRETAÑA S/N',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.73401776,
#   'latitud': 28.075889986,
#   'geohash': 'esupepn9vj',
#   'utm_x': 329612.0,
#   'utm_y': 3106822.85},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e180'),
#   'fid': 668,
#   'etiqueta': 'HOTEL HARD ROCK HOTEL TENERIFE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H5',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 5,
#   'nom_categor': '5 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B12',
#   'nom_nucltur': 'Playa Paraíso',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'AVENIDA DE ADEJE 300, S/N. (URBANIZACIÓN PLAYA PARAISO)',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.77447081,
#   'latitud': 28.121356574,
#   'geohash': 'esupfr34y2',
#   'utm_x': 325709.81,
#   'utm_y': 3111918.15},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e181'),
#   'fid': 669,
#   'etiqueta': 'HOVIMA LA PINTA BEACHFRONT FAMILY HOTEL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B14',
#   'nom_nucltur': 'Costa Adeje',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'AVENIDA ESPAÑA , 5. SAN EUGENIO URBANIZACIÓN.',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.73438333,
#   'latitud': 28.080365674,
#   'geohash': 'esupepy7ux',
#   'utm_x': 329583.14,
#   'utm_y': 3107319.29},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e182'),
#   'fid': 670,
#   'etiqueta': 'HOTEL APART. COLUMBUS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B22',
#   'nom_nucltur': 'Las Américas - Arona',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'AVENIDA SANTIAGO PUIG 6',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.7277789,
#   'latitud': 28.060790151,
#   'geohash': 'esupek71yw',
#   'utm_x': 330201.4,
#   'utm_y': 3105141.0},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e183'),
#   'fid': 671,
#   'etiqueta': 'HOTEL CONQUISTADOR',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B22',
#   'nom_nucltur': 'Las Américas - Arona',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'AVENIDA MARITIMA',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.73512991,
#   'latitud': 28.05752797,
#   'geohash': 'esupe5tygn',
#   'utm_x': 329473.7,
#   'utm_y': 3104789.81},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e184'),
#   'fid': 672,
#   'etiqueta': 'HOTEL GALA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B22',
#   'nom_nucltur': 'Las Américas - Arona',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'CALLE ARQUITECTO GOMEZ CUESTA , 3',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.73027876,
#   'latitud': 28.06646583,
#   'geohash': 'esupem37h0',
#   'utm_x': 329964.62,
#   'utm_y': 3105773.38},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e185'),
#   'fid': 673,
#   'etiqueta': 'HOTEL TIGOTAN PLAYA DE LAS AMÉRICAS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B22',
#   'nom_nucltur': 'Las Américas - Arona',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'AVENIDA NOELIA ALFONSO CABRERA, 6',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.72945794,
#   'latitud': 28.059923823,
#   'geohash': 'esupek1uzk',
#   'utm_x': 330035.0,
#   'utm_y': 3105047.35},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e186'),
#   'fid': 674,
#   'etiqueta': 'HOTEL SOL TENERIFE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B22',
#   'nom_nucltur': 'Las Américas - Arona',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'AVENIDA RAFAEL PUIG LLUVINA, 12',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.73164454,
#   'latitud': 28.064358257,
#   'geohash': 'esupekbqsr',
#   'utm_x': 329827.06,
#   'utm_y': 3105541.76},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e187'),
#   'fid': 675,
#   'etiqueta': 'HOTEL VULCANO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H4',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 4,
#   'nom_categor': '4 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B22',
#   'nom_nucltur': 'Las Américas - Arona',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'CALLE ANTONIO DOMINGUEZ ALFONSO, 8',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.73041823,
#   'latitud': 28.056557974,
#   'geohash': 'esupe7932c',
#   'utm_x': 329935.31,
#   'utm_y': 3104675.74}]

# %%
pd.DataFrame(list(coleccion.find({"nom_isla":"Tenerife"})))
# Out:
#                           _id  fid                               etiqueta  \
# 0    648d6191fbe58f6d29f2d99e    2                    HOTEL PARADISE PARK
# 1    648d6191fbe58f6d29f2d99f    3          HOTEL CATALONIA PUNTA DEL REY
# 2    648d6191fbe58f6d29f2d9a0    4                           HOTEL MEDANO
# 3    648d6191fbe58f6d29f2d9a1    5               HOTEL PLAYA SUR TENERIFE
# 4    648d6191fbe58f6d29f2d9a2    6  PARADOR TURISMO LAS CAÑADAS DEL TEIDE
# ..                        ...  ...                                    ...
# 496  648d6250fbe58f6d29f2e183  671                     HOTEL CONQUISTADOR
# 497  648d6250fbe58f6d29f2e184  672                             HOTEL GALA
# 498  648d6250fbe58f6d29f2e185  673    HOTEL TIGOTAN PLAYA DE LAS AMÉRICAS
# 499  648d6250fbe58f6d29f2e186  674                     HOTEL SOL TENERIFE
# 500  648d6250fbe58f6d29f2e187  675                          HOTEL VULCANO
#
#      granularidad cod_tipocat cod_tipo nom_tipo  cod_categor  nom_categor  \
# 0    ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 1    ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 2    ALOJAMIENTOS          H3  5510_L1    Hotel            3  3 Estrellas
# 3    ALOJAMIENTOS          H3  5510_L1    Hotel            3  3 Estrellas
# 4    ALOJAMIENTOS          H2  5510_L1    Hotel            2  2 Estrellas
# ..            ...         ...      ...      ...          ...          ...
# 496  ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 497  ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 498  ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 499  ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 500  ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
#
#     gcd_isla  nom_isla gcd_entitur                    nom_entitur gcd_nucltur  \
# 0      ES709  Tenerife     ES709B2  Las Américas - Los Cristianos    ES709B23
# 1      ES709  Tenerife     ES709B9              Resto de Tenerife     ES709B9
# 2      ES709  Tenerife     ES709B3                          Abona    ES709B32
# 3      ES709  Tenerife     ES709B3                          Abona    ES709B32
# 4      ES709  Tenerife     ES709B9              Resto de Tenerife     ES709B9
# ..       ...       ...         ...                            ...         ...
# 496    ES709  Tenerife     ES709B2  Las Américas - Los Cristianos    ES709B22
# 497    ES709  Tenerife     ES709B2  Las Américas - Los Cristianos    ES709B22
# 498    ES709  Tenerife     ES709B2  Las Américas - Los Cristianos    ES709B22
# 499    ES709  Tenerife     ES709B2  Las Américas - Los Cristianos    ES709B22
# 500    ES709  Tenerife     ES709B2  Las Américas - Los Cristianos    ES709B22
#
#               nom_nucltur  gcd_municipio        nom_municipio  \
# 0          Los Cristianos          38006                Arona
# 1       Resto de Tenerife          38011           Candelaria
# 2               El Médano          38017  Granadilla de Abona
# 3               El Médano          38017  Granadilla de Abona
# 4       Resto de Tenerife          38026           La Orotava
# ..                    ...            ...                  ...
# 496  Las Américas - Arona          38006                Arona
# 497  Las Américas - Arona          38006                Arona
# 498  Las Américas - Arona          38006                Arona
# 499  Las Américas - Arona          38006                Arona
# 500  Las Américas - Arona          38006                Arona
#
#                               direccion                prc_habita  \
# 0            URBANIZACIÓN OASIS DEL SUR    300 o más habitaciones
# 1             AVENIDA GENERALISIMO, 165    300 o más habitaciones
# 2                      PASEO PICACHO, 2  De 50 a 149 habitaciones
# 3                 PLAYA DEL MÉDANO, S/N  De 50 a 149 habitaciones
# 4           CALLE LAS CAÑADAS DEL TEIDE  Menor de 50 habitaciones
# ..                                  ...                       ...
# 496                    AVENIDA MARITIMA    300 o más habitaciones
# 497   CALLE ARQUITECTO GOMEZ CUESTA , 3    300 o más habitaciones
# 498   AVENIDA NOELIA ALFONSO CABRERA, 6    300 o más habitaciones
# 499     AVENIDA RAFAEL PUIG LLUVINA, 12    300 o más habitaciones
# 500  CALLE ANTONIO DOMINGUEZ ALFONSO, 8    300 o más habitaciones
#
#               prc_plazas   longitud    latitud     geohash      utm_x  \
# 0       650 o más plazas -16.706284  28.053429  esupeffz56  332302.78
# 1       650 o más plazas -16.362112  28.377362  eth37tvqp5  366536.23
# 2    De 100 a 349 plazas -16.538002  28.044017  esupx9m2hx  348831.06
# 3    De 100 a 349 plazas -16.542824  28.041107  esupx89zk3  348352.91
# 4    Menor de 100 plazas -16.627134  28.224400  eth0tdh7p9  340336.74
# ..                   ...        ...        ...         ...        ...
# 496     650 o más plazas -16.735130  28.057528  esupe5tygn  329473.70
# 497  De 350 a 649 plazas -16.730279  28.066466  esupem37h0  329964.62
# 498     650 o más plazas -16.729458  28.059924  esupek1uzk  330035.00
# 499     650 o más plazas -16.731645  28.064358  esupekbqsr  329827.06
# 500     650 o más plazas -16.730418  28.056558  esupe7932c  329935.31
#
#           utm_y
# 0    3104295.54
# 1    3139759.91
# 2    3103032.41
# 3    3102716.04
# 4    3123133.08
# ..          ...
# 496  3104789.81
# 497  3105773.38
# 498  3105047.35
# 499  3105541.76
# 500  3104675.74
#
# [501 rows x 25 columns]

# %% [markdown]
# ### Búsqueda de campos de tipo numérico

# %% [markdown]
# Para hacer búsquedas con valores númericos tendremos que usar los operadores de comparación, que en Mongo son un poco diferentes:
#
# - `$eq`: igual a
#
#
# - `$gt`: mayor que
#
#
# - `$gte`: mayor o igual que
#
#
# - `$lt`: menor que
#
#
# - `$lte`: menor o igual que
#
#
# - `$in`: dentro de
#
#
# - `$nin`: no dentro de
#
#
# - `$ne`: distinto de

# %% [markdown]
# 1️⃣ `$eq`: igual a
#
# Busquemos aquellos alojamientos que tengan 3⭐️

# %%
list(coleccion.find({"cod_categor":{"$eq":3}}))
# Out:
# [{'_id': ObjectId('648d6191fbe58f6d29f2d9a0'),
#   'fid': 4,
#   'etiqueta': 'HOTEL MEDANO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B3',
#   'nom_entitur': 'Abona',
#   'gcd_nucltur': 'ES709B32',
#   'nom_nucltur': 'El Médano',
#   'gcd_municipio': 38017,
#   'nom_municipio': 'Granadilla de Abona',
#   'direccion': 'PASEO PICACHO, 2',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.53800193,
#   'latitud': 28.044016879,
#   'geohash': 'esupx9m2hx',
#   'utm_x': 348831.06,
#   'utm_y': 3103032.41},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9a1'),
#   'fid': 5,
#   'etiqueta': 'HOTEL PLAYA SUR TENERIFE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B3',
#   'nom_entitur': 'Abona',
#   'gcd_nucltur': 'ES709B32',
#   'nom_nucltur': 'El Médano',
#   'gcd_municipio': 38017,
#   'nom_municipio': 'Granadilla de Abona',
#   'direccion': 'PLAYA DEL MÉDANO, S/N',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.54282447,
#   'latitud': 28.041107416,
#   'geohash': 'esupx89zk3',
#   'utm_x': 348352.91,
#   'utm_y': 3102716.04},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9a8'),
#   'fid': 12,
#   'etiqueta': 'APARTAMENTOS EL TREBOL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B1',
#   'nom_entitur': 'Costa Teguise',
#   'gcd_nucltur': 'ES708B12',
#   'nom_nucltur': 'Costa Teguise: Litoral',
#   'gcd_municipio': 35024,
#   'nom_municipio': 'Teguise',
#   'direccion': 'AVENIDA LAS PALMERAS, 10',
#   'prc_habita': '80 o más apartamentos',
#   'prc_plazas': '260 o más plazas',
#   'longitud': -13.48608255,
#   'latitud': 29.005413837,
#   'geohash': 'etnmj078z9',
#   'utm_x': 647456.93,
#   'utm_y': 3209530.19},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9ab'),
#   'fid': 15,
#   'etiqueta': 'HOTEL ELEGANCE MIRAMAR',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B53',
#   'nom_nucltur': 'Taoro - La Paz',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'PARQUE DE TAORO, Nº 23',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.54734603,
#   'latitud': 28.411936216,
#   'geohash': 'eth1xknxdb',
#   'utm_x': 348433.36,
#   'utm_y': 3143809.98},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9ac'),
#   'fid': 16,
#   'etiqueta': 'HOTEL MONOPOL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE QUINTANA, 15',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.54848929,
#   'latitud': 28.417324372,
#   'geohash': 'eth1xmjybm',
#   'utm_x': 348329.04,
#   'utm_y': 3144408.45},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9ad'),
#   'fid': 17,
#   'etiqueta': 'HOTEL NOPAL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE SAN JUAN, 15',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.54944003,
#   'latitud': 28.41584195,
#   'geohash': 'eth1xkvn60',
#   'utm_x': 348233.79,
#   'utm_y': 3144245.39},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9af'),
#   'fid': 19,
#   'etiqueta': 'HOTEL SAN BORONDON',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE AGUSTIN DE ESPINOSA, 2',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.5555382,
#   'latitud': 28.414927593,
#   'geohash': 'eth1xkb8gy',
#   'utm_x': 347635.09,
#   'utm_y': 3144151.78},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9b2'),
#   'fid': 22,
#   'etiqueta': 'HOTEL TROPICAL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE PUERTO VIEJO, 1',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.55123592,
#   'latitud': 28.416177895,
#   'geohash': 'eth1xm5b0p',
#   'utm_x': 348058.34,
#   'utm_y': 3144284.88},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9b4'),
#   'fid': 24,
#   'etiqueta': 'HOTEL APART. PANORAMICA GARDEN',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38031,
#   'nom_municipio': 'Los Realejos',
#   'direccion': 'CALLE LA LONGUERA, S/N',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.58136253,
#   'latitud': 28.397469054,
#   'geohash': 'eth1w9tg4p',
#   'utm_x': 345079.84,
#   'utm_y': 3142250.25},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9b8'),
#   'fid': 28,
#   'etiqueta': 'HOTEL BARCELÓ SANTA CRUZ CONTEMPORANEO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38038,
#   'nom_municipio': 'Santa Cruz de Tenerife',
#   'direccion': 'AVENIDA RAMBLA DE SANTA CRUZ, 116',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.25313653,
#   'latitud': 28.474049419,
#   'geohash': 'eth3ypsc67',
#   'utm_x': 377326.49,
#   'utm_y': 3150356.72},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9ba'),
#   'fid': 30,
#   'etiqueta': 'HOTEL ADONIS PLAZA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38038,
#   'nom_municipio': 'Santa Cruz de Tenerife',
#   'direccion': 'PLAZA DE LA CANDELARIA, 10',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.24859157,
#   'latitud': 28.467083197,
#   'geohash': 'eth3yq20u2',
#   'utm_x': 377763.43,
#   'utm_y': 3149580.25},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9bc'),
#   'fid': 32,
#   'etiqueta': 'HOTEL AEROPUERTO SUR',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38017,
#   'nom_municipio': 'Granadilla de Abona',
#   'direccion': 'CALLE BENCHIJIGUA, 4',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.5557725,
#   'latitud': 28.073056047,
#   'geohash': 'esupxq83qs',
#   'utm_x': 347125.27,
#   'utm_y': 3106272.1},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9bd'),
#   'fid': 33,
#   'etiqueta': 'HOTEL PRINCIPE PAZ',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38038,
#   'nom_municipio': 'Santa Cruz de Tenerife',
#   'direccion': 'CALLE VALENTIN SANZ, 33-35 ESQ. ADELANTADO',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.25083049,
#   'latitud': 28.46876366,
#   'geohash': 'eth3ynwd84',
#   'utm_x': 377546.16,
#   'utm_y': 3149768.72},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9be'),
#   'fid': 34,
#   'etiqueta': 'HOTEL ROBINSON CLUB JANDIA PLAYA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES704',
#   'nom_isla': 'Fuerteventura',
#   'gcd_entitur': 'ES704B4',
#   'nom_entitur': 'Morro Jable',
#   'gcd_nucltur': 'ES704B41',
#   'nom_nucltur': 'Morro Jable: Morro Jable',
#   'gcd_municipio': 35015,
#   'nom_municipio': 'Pájara',
#   'direccion': 'PLAYA DEL MATORRAL',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -14.34249039,
#   'latitud': 28.048471697,
#   'geohash': 'esvz9dh45y',
#   'utm_x': 564619.85,
#   'utm_y': 3102746.2},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9c2'),
#   'fid': 38,
#   'etiqueta': 'HOTEL PERLA TENERIFE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B53',
#   'nom_nucltur': 'Taoro - La Paz',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE ISLA DE LA GOMERA, S/N.',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.54118302,
#   'latitud': 28.408218247,
#   'geohash': 'eth1xee1f7',
#   'utm_x': 349031.85,
#   'utm_y': 3143390.27},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9c5'),
#   'fid': 41,
#   'etiqueta': 'HOTEL APART. VILLA DE ADEJE BEACH',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B14',
#   'nom_nucltur': 'Costa Adeje',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'AVENIDA DE LOS PUEBLO , 41',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.73065458,
#   'latitud': 28.080859672,
#   'geohash': 'esupercng7',
#   'utm_x': 329950.36,
#   'utm_y': 3107368.81},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9c8'),
#   'fid': 44,
#   'etiqueta': 'HOTEL TORRE DEL CONDE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES706',
#   'nom_isla': 'La Gomera',
#   'gcd_entitur': 'ES700B9',
#   'nom_entitur': 'Islas de Canarias sin entidades turísticas',
#   'gcd_nucltur': 'ES700B99',
#   'nom_nucltur': 'Islas de Canarias sin núcleos turísticos',
#   'gcd_municipio': 38036,
#   'nom_municipio': 'San Sebastián de La Gomera',
#   'direccion': 'CALLE RUIZ DE PADRON Nº 19',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -17.11139986,
#   'latitud': 28.091391315,
#   'geohash': 'esgzf9gu5q',
#   'utm_x': 292550.93,
#   'utm_y': 3109126.71},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9d0'),
#   'fid': 52,
#   'etiqueta': 'HOTEL CATALONIA ORO NEGRO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B22',
#   'nom_nucltur': 'Las Américas - Arona',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'CALLE ARQUITECTO GÓMEZ CUESTA, 14',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.72688301,
#   'latitud': 28.063062346,
#   'geohash': 'esupekez5m',
#   'utm_x': 330293.03,
#   'utm_y': 3105391.52},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9d1'),
#   'fid': 53,
#   'etiqueta': 'HOTEL APART. ASTORIA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B5',
#   'nom_entitur': 'Puerto de la Cruz turístico',
#   'gcd_nucltur': 'ES709B52',
#   'nom_nucltur': 'Conjunto Histórico',
#   'gcd_municipio': 38028,
#   'nom_municipio': 'Puerto de la Cruz',
#   'direccion': 'CALLE LA HOYA, 60',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -16.54532122,
#   'latitud': 28.416455346,
#   'geohash': 'eth1xt01f5',
#   'utm_x': 348638.15,
#   'utm_y': 3144308.17},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9d6'),
#   'fid': 58,
#   'etiqueta': 'HOTEL APART. DRAGOS DEL SUR',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B4',
#   'nom_entitur': 'Isora',
#   'gcd_nucltur': 'ES709B42',
#   'nom_nucltur': 'Puerto Santiago',
#   'gcd_municipio': 38040,
#   'nom_municipio': 'Santiago del Teide',
#   'direccion': 'AVENIDA MARÍTIMA, ESQ. CALETA DEL JURADO',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.84152604,
#   'latitud': 28.235647485,
#   'geohash': 'eth08u0kef',
#   'utm_x': 319314.62,
#   'utm_y': 3124680.73},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9d9'),
#   'fid': 61,
#   'etiqueta': 'HOTEL ALISIOS CANTERAS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES705',
#   'nom_isla': 'Gran Canaria',
#   'gcd_entitur': 'ES705B2',
#   'nom_entitur': 'Las Canteras',
#   'gcd_nucltur': 'ES705B21',
#   'nom_nucltur': 'Las Canteras',
#   'gcd_municipio': 35016,
#   'nom_municipio': 'Las Palmas de Gran Canaria',
#   'direccion': 'CALLE COLOMBIA, 12',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -15.43917327,
#   'latitud': 28.13531531,
#   'geohash': 'etj009vs14',
#   'utm_x': 456873.2,
#   'utm_y': 3112270.03},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9ea'),
#   'fid': 78,
#   'etiqueta': 'HOTEL BARLOVENTO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES704',
#   'nom_isla': 'Fuerteventura',
#   'gcd_entitur': 'ES704B3',
#   'nom_entitur': 'Costa Calma',
#   'gcd_nucltur': 'ES704B31',
#   'nom_nucltur': 'Costa Calma',
#   'gcd_municipio': 35015,
#   'nom_municipio': 'Pájara',
#   'direccion': 'URBANIZACIÓN CAÑADA DEL RIO,COSTA-CALMA',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -14.22080506,
#   'latitud': 28.165808541,
#   'geohash': 'etjbhrktxp',
#   'utm_x': 576496.14,
#   'utm_y': 3115815.59},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9f1'),
#   'fid': 85,
#   'etiqueta': 'HL CLUB PLAYA BLANCA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B3',
#   'nom_entitur': 'Playa Blanca - Puerto Calero',
#   'gcd_nucltur': 'ES708B31',
#   'nom_nucltur': 'Playa Blanca: Montaña Roja',
#   'gcd_municipio': 35034,
#   'nom_municipio': 'Yaiza',
#   'direccion': 'CARRETERA FARO DE PECHIGUERA S/N',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -13.83459805,
#   'latitud': 28.867868904,
#   'geohash': 'etnhjpjzw8',
#   'utm_x': 613658.34,
#   'utm_y': 3193904.88},
#  {'_id': ObjectId('648d6191fbe58f6d29f2d9f5'),
#   'fid': 89,
#   'etiqueta': 'HOTEL ALDIANA FUERTEVENTURA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES704',
#   'nom_isla': 'Fuerteventura',
#   'gcd_entitur': 'ES704B4',
#   'nom_entitur': 'Morro Jable',
#   'gcd_nucltur': 'ES704B43',
#   'nom_nucltur': 'Morro Jable: Esquinzo - Butihondo',
#   'gcd_municipio': 35015,
#   'nom_municipio': 'Pájara',
#   'direccion': 'CARRETERA DEL SUR, KM. 50',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -14.31626714,
#   'latitud': 28.059521617,
#   'geohash': 'esvzdhp4wc',
#   'utm_x': 567190.26,
#   'utm_y': 3103984.5},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da00'),
#   'fid': 100,
#   'etiqueta': 'HOTEL ASTORIA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES705',
#   'nom_isla': 'Gran Canaria',
#   'gcd_entitur': 'ES705B2',
#   'nom_entitur': 'Las Canteras',
#   'gcd_nucltur': 'ES705B21',
#   'nom_nucltur': 'Las Canteras',
#   'gcd_municipio': 35016,
#   'nom_municipio': 'Las Palmas de Gran Canaria',
#   'direccion': 'CALLE FERNANDO GUANARTEME, 54',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -15.43780245,
#   'latitud': 28.135074793,
#   'geohash': 'etj009yd9n',
#   'utm_x': 457007.72,
#   'utm_y': 3112242.9},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da04'),
#   'fid': 104,
#   'etiqueta': 'APARTAMENTOS OASIS DUNA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES704',
#   'nom_isla': 'Fuerteventura',
#   'gcd_entitur': 'ES704B2',
#   'nom_entitur': 'Corralejo - El Cotillo',
#   'gcd_nucltur': 'ES704B21',
#   'nom_nucltur': 'Corralejo',
#   'gcd_municipio': 35014,
#   'nom_municipio': 'La Oliva',
#   'direccion': 'CALLE GRAN CANARIA 3 - AVENIDA MAXORATA 2',
#   'prc_habita': '80 o más apartamentos',
#   'prc_plazas': '260 o más plazas',
#   'longitud': -13.86904839,
#   'latitud': 28.729290389,
#   'geohash': 'etn5kqhb5x',
#   'utm_x': 610444.28,
#   'utm_y': 3178517.9},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da0f'),
#   'fid': 115,
#   'etiqueta': 'HOTEL BAHIA FLAMINGO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B4',
#   'nom_entitur': 'Isora',
#   'gcd_nucltur': 'ES709B42',
#   'nom_nucltur': 'Puerto Santiago',
#   'gcd_municipio': 38019,
#   'nom_municipio': 'Guía de Isora',
#   'direccion': 'AVENIDA LA GAVIOTA, 3',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.83856488,
#   'latitud': 28.22670508,
#   'geohash': 'eth08fd82z',
#   'utm_x': 319590.17,
#   'utm_y': 3123685.4},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da10'),
#   'fid': 116,
#   'etiqueta': 'ELBA CASTILLO SAN JORGE & ANTIGUA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES704',
#   'nom_isla': 'Fuerteventura',
#   'gcd_entitur': 'ES704B1',
#   'nom_entitur': 'Caleta de Fuste',
#   'gcd_nucltur': 'ES704B11',
#   'nom_nucltur': 'Caleta de Fuste',
#   'gcd_municipio': 35003,
#   'nom_municipio': 'Antigua',
#   'direccion': 'CALLE FRANCHY ROCA, S/N - URBANIZACIÓN EL CASTILLO',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -13.85330386,
#   'latitud': 28.399358111,
#   'geohash': 'etn1scbq68',
#   'utm_x': 612331.8,
#   'utm_y': 3141977.28},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da11'),
#   'fid': 117,
#   'etiqueta': 'APARTHOTEL TERRAZA MAR, SUN SUITE Y ROYAL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES705',
#   'nom_isla': 'Gran Canaria',
#   'gcd_entitur': 'ES705B1',
#   'nom_entitur': 'Mogán turístico',
#   'gcd_nucltur': 'ES705B15',
#   'nom_nucltur': 'Puerto Rico',
#   'gcd_municipio': 35012,
#   'nom_municipio': 'Mogán',
#   'direccion': 'AVENIDA DE LAS PALMERAS S/N',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -15.70856099,
#   'latitud': 27.794100229,
#   'geohash': 'esuy4ec27g',
#   'utm_x': 430199.51,
#   'utm_y': 3074595.4},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da18'),
#   'fid': 124,
#   'etiqueta': 'APARTAMENTOS VISTA HERMOSA I',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES707',
#   'nom_isla': 'La Palma',
#   'gcd_entitur': 'ES700B9',
#   'nom_entitur': 'Islas de Canarias sin entidades turísticas',
#   'gcd_nucltur': 'ES700B99',
#   'nom_nucltur': 'Islas de Canarias sin núcleos turísticos',
#   'gcd_municipio': 38045,
#   'nom_municipio': 'Tazacorte',
#   'direccion': 'CARRETERA LAS ANGUSTIAS',
#   'prc_habita': 'Menor de 20 apartamentos',
#   'prc_plazas': 'Menor de 50 plazas',
#   'longitud': -17.93407271,
#   'latitud': 28.666922653,
#   'geohash': 'et55pfsucv',
#   'utm_x': 213242.06,
#   'utm_y': 3174608.63},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da1e'),
#   'fid': 130,
#   'etiqueta': 'HOTEL PALM OASIS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES705',
#   'nom_isla': 'Gran Canaria',
#   'gcd_entitur': 'ES705B3',
#   'nom_entitur': 'Maspalomas',
#   'gcd_nucltur': 'ES705B32',
#   'nom_nucltur': 'Sonnenland',
#   'gcd_municipio': 35019,
#   'nom_municipio': 'San Bartolomé de Tirajana',
#   'direccion': 'CALLE EINSTEIN S/N - PARCELA 34',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -15.59960473,
#   'latitud': 27.765345639,
#   'geohash': 'esuvvn88yg',
#   'utm_x': 440917.52,
#   'utm_y': 3071352.97},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da1f'),
#   'fid': 131,
#   'etiqueta': 'HOTEL NH TENERIFE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38038,
#   'nom_municipio': 'Santa Cruz de Tenerife',
#   'direccion': 'CALLE CANDELARIA ESQUINA DOCTOR ALLART',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -16.24849635,
#   'latitud': 28.466220241,
#   'geohash': 'eth3yq05y8',
#   'utm_x': 377771.76,
#   'utm_y': 3149484.54},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da24'),
#   'fid': 136,
#   'etiqueta': 'HOTEL H10 TINDAYA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES704',
#   'nom_isla': 'Fuerteventura',
#   'gcd_entitur': 'ES704B3',
#   'nom_entitur': 'Costa Calma',
#   'gcd_nucltur': 'ES704B31',
#   'nom_nucltur': 'Costa Calma',
#   'gcd_municipio': 35015,
#   'nom_municipio': 'Pájara',
#   'direccion': 'CALLE PUNTA DEL ROQUITO, S/N',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -14.23049211,
#   'latitud': 28.152577279,
#   'geohash': 'etjbhjj8ts',
#   'utm_x': 575554.39,
#   'utm_y': 3114343.72},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da31'),
#   'fid': 149,
#   'etiqueta': 'MONTE FELIZ',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES705',
#   'nom_isla': 'Gran Canaria',
#   'gcd_entitur': 'ES705B4',
#   'nom_entitur': 'Playa del Inglés - San Agustín',
#   'gcd_nucltur': 'ES705B44',
#   'nom_nucltur': 'Bahía Feliz - Playa del Águila',
#   'gcd_municipio': 35019,
#   'nom_municipio': 'San Bartolomé de Tirajana',
#   'direccion': 'CALLE PASEO PABLO PICASO, S/N',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -15.51514683,
#   'latitud': 27.783813649,
#   'geohash': 'esuyncyhqy',
#   'utm_x': 449248.35,
#   'utm_y': 3073361.03},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da3a'),
#   'fid': 158,
#   'etiqueta': 'HOTEL APARTAMENTO EL GALEON',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES707',
#   'nom_isla': 'La Palma',
#   'gcd_entitur': 'ES700B9',
#   'nom_entitur': 'Islas de Canarias sin entidades turísticas',
#   'gcd_nucltur': 'ES700B99',
#   'nom_nucltur': 'Islas de Canarias sin núcleos turísticos',
#   'gcd_municipio': 38037,
#   'nom_municipio': 'Santa Cruz de La Palma',
#   'direccion': 'CALLE GALEÓN 10',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -17.77122777,
#   'latitud': 28.678523531,
#   'geohash': 'et575sg2s2',
#   'utm_x': 229194.32,
#   'utm_y': 3175514.05},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da3b'),
#   'fid': 159,
#   'etiqueta': 'APARTHOTEL CLUB MARAZUL DEL SUR',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B9',
#   'nom_entitur': 'Resto de Tenerife',
#   'gcd_nucltur': 'ES709B9',
#   'nom_nucltur': 'Resto de Tenerife',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'CARRETERA GRAL. ADEJE PLAYA SAN JUAN',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.79189422,
#   'latitud': 28.146478166,
#   'geohash': 'eth01gut0e',
#   'utm_x': 324039.22,
#   'utm_y': 3114726.93},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da3d'),
#   'fid': 161,
#   'etiqueta': 'HOTEL DIAMAR',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B9',
#   'nom_entitur': 'Resto de Lanzarote',
#   'gcd_nucltur': 'ES708B9',
#   'nom_nucltur': 'Resto de Lanzarote',
#   'gcd_municipio': 35004,
#   'nom_municipio': 'Arrecife',
#   'direccion': 'AVENIDA FRED OLSEN , 8',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -13.55784727,
#   'latitud': 28.95884664,
#   'geohash': 'etnkerz3x2',
#   'utm_x': 640529.12,
#   'utm_y': 3204282.62},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da41'),
#   'fid': 165,
#   'etiqueta': 'APARTAMENTOS CALAS I, LAS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B2',
#   'nom_entitur': 'Puerto del Carmen',
#   'gcd_nucltur': 'ES708B22',
#   'nom_nucltur': 'Puerto del Carmen: Playa Grande',
#   'gcd_municipio': 35028,
#   'nom_municipio': 'Tías',
#   'direccion': 'CALLE GUAYADEQUE, 3',
#   'prc_habita': 'Menor de 20 apartamentos',
#   'prc_plazas': 'Menor de 50 plazas',
#   'longitud': -13.66037985,
#   'latitud': 28.92417526,
#   'geohash': 'etnk91kzd1',
#   'utm_x': 630580.4,
#   'utm_y': 3200323.33},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da42'),
#   'fid': 166,
#   'etiqueta': 'APARTAMENTOS CALAS II, LAS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B2',
#   'nom_entitur': 'Puerto del Carmen',
#   'gcd_nucltur': 'ES708B22',
#   'nom_nucltur': 'Puerto del Carmen: Playa Grande',
#   'gcd_municipio': 35028,
#   'nom_municipio': 'Tías',
#   'direccion': 'CALLE GUAYADEQUE, 3',
#   'prc_habita': 'De 40 a 79 apartamentos',
#   'prc_plazas': 'De 120 a 259 plazas',
#   'longitud': -13.66038325,
#   'latitud': 28.924142534,
#   'geohash': 'etnk91kz3f',
#   'utm_x': 630580.11,
#   'utm_y': 3200319.7},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da43'),
#   'fid': 167,
#   'etiqueta': 'HOTEL APART. LAS LANZAS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES705',
#   'nom_isla': 'Gran Canaria',
#   'gcd_entitur': 'ES705B2',
#   'nom_entitur': 'Las Canteras',
#   'gcd_nucltur': 'ES705B21',
#   'nom_nucltur': 'Las Canteras',
#   'gcd_municipio': 35016,
#   'nom_municipio': 'Las Palmas de Gran Canaria',
#   'direccion': 'CALLE BERNARDO DE LA TORRE, 79',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -15.43476649,
#   'latitud': 28.140612484,
#   'geohash': 'etj00fbdzy',
#   'utm_x': 457308.05,
#   'utm_y': 3112855.29},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da4a'),
#   'fid': 174,
#   'etiqueta': 'APARTAMENTOS PRINCESA ICO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B2',
#   'nom_entitur': 'Puerto del Carmen',
#   'gcd_nucltur': 'ES708B22',
#   'nom_nucltur': 'Puerto del Carmen: Playa Grande',
#   'gcd_municipio': 35028,
#   'nom_municipio': 'Tías',
#   'direccion': 'CALLE PRINCESA ICO, 15',
#   'prc_habita': 'Menor de 20 apartamentos',
#   'prc_plazas': 'Menor de 50 plazas',
#   'longitud': -13.66055487,
#   'latitud': 28.923271909,
#   'geohash': 'etnk91kdq0',
#   'utm_x': 630564.47,
#   'utm_y': 3200223.04},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da4e'),
#   'fid': 178,
#   'etiqueta': 'HOTEL DOÑA LUISA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES705',
#   'nom_isla': 'Gran Canaria',
#   'gcd_entitur': 'ES705B2',
#   'nom_entitur': 'Las Canteras',
#   'gcd_nucltur': 'ES705B21',
#   'nom_nucltur': 'Las Canteras',
#   'gcd_municipio': 35016,
#   'nom_municipio': 'Las Palmas de Gran Canaria',
#   'direccion': 'CALLE ALFREDO L. JONES, 29 -  ESQ. C/. 29 DE ABRIL',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -15.43280931,
#   'latitud': 28.141985813,
#   'geohash': 'etj00g44vq',
#   'utm_x': 457500.78,
#   'utm_y': 3113006.74},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da4f'),
#   'fid': 179,
#   'etiqueta': 'APARTAMENTOS CLUB MARITIMA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B2',
#   'nom_entitur': 'Puerto del Carmen',
#   'gcd_nucltur': 'ES708B22',
#   'nom_nucltur': 'Puerto del Carmen: Playa Grande',
#   'gcd_municipio': 35028,
#   'nom_municipio': 'Tías',
#   'direccion': 'CALLE MIRAFONDO, 3',
#   'prc_habita': 'De 20 a 39 apartamentos',
#   'prc_plazas': 'De 50 a 119 plazas',
#   'longitud': -13.64638205,
#   'latitud': 28.923330958,
#   'geohash': 'etnk93r487',
#   'utm_x': 631946.05,
#   'utm_y': 3200245.29},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da50'),
#   'fid': 180,
#   'etiqueta': 'APARTAMENTOS VISTA MAR',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B2',
#   'nom_entitur': 'Puerto del Carmen',
#   'gcd_nucltur': 'ES708B22',
#   'nom_nucltur': 'Puerto del Carmen: Playa Grande',
#   'gcd_municipio': 35028,
#   'nom_municipio': 'Tías',
#   'direccion': 'CALLE LAS MAJADAS, 4',
#   'prc_habita': 'De 20 a 39 apartamentos',
#   'prc_plazas': 'Menor de 50 plazas',
#   'longitud': -13.66638063,
#   'latitud': 28.923400678,
#   'geohash': 'etnk9127n2',
#   'utm_x': 629996.38,
#   'utm_y': 3200230.9},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da54'),
#   'fid': 184,
#   'etiqueta': 'APARTAMENTOS GALEON PLAYA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B1',
#   'nom_entitur': 'Costa Teguise',
#   'gcd_nucltur': 'ES708B12',
#   'nom_nucltur': 'Costa Teguise: Litoral',
#   'gcd_municipio': 35024,
#   'nom_municipio': 'Teguise',
#   'direccion': 'AVENIDA LAS CONCHAS, 3',
#   'prc_habita': '80 o más apartamentos',
#   'prc_plazas': '260 o más plazas',
#   'longitud': -13.48792791,
#   'latitud': 28.994172208,
#   'geohash': 'etnkvn4rk9',
#   'utm_x': 647293.11,
#   'utm_y': 3208282.18},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da55'),
#   'fid': 185,
#   'etiqueta': 'SUITE HOTEL MONTANA CLUB',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B2',
#   'nom_entitur': 'Puerto del Carmen',
#   'gcd_nucltur': 'ES708B22',
#   'nom_nucltur': 'Puerto del Carmen: Playa Grande',
#   'gcd_municipio': 35028,
#   'nom_municipio': 'Tías',
#   'direccion': 'CALLE TIMON, 3',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -13.65022297,
#   'latitud': 28.923175308,
#   'geohash': 'etnk93k1wy',
#   'utm_x': 631571.81,
#   'utm_y': 3200223.77},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da58'),
#   'fid': 188,
#   'etiqueta': 'APARTAMENTOS GUARAPO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B1',
#   'nom_entitur': 'Costa Teguise',
#   'gcd_nucltur': 'ES708B12',
#   'nom_nucltur': 'Costa Teguise: Litoral',
#   'gcd_municipio': 35024,
#   'nom_municipio': 'Teguise',
#   'direccion': 'CALLE LAS TABAIBAS, 10',
#   'prc_habita': 'De 40 a 79 apartamentos',
#   'prc_plazas': 'De 120 a 259 plazas',
#   'longitud': -13.4953523,
#   'latitud': 28.995851922,
#   'geohash': 'etnkuyscp6',
#   'utm_x': 646567.43,
#   'utm_y': 3208459.08},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da5a'),
#   'fid': 190,
#   'etiqueta': 'APARTAMENTOS SOL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B1',
#   'nom_entitur': 'Costa Teguise',
#   'gcd_nucltur': 'ES708B12',
#   'nom_nucltur': 'Costa Teguise: Litoral',
#   'gcd_municipio': 35024,
#   'nom_municipio': 'Teguise',
#   'direccion': 'CALLE HERVIDEROS, S/N',
#   'prc_habita': 'De 40 a 79 apartamentos',
#   'prc_plazas': 'De 50 a 119 plazas',
#   'longitud': -13.48839996,
#   'latitud': 29.003921859,
#   'geohash': 'etnmj0401d',
#   'utm_x': 647233.3,
#   'utm_y': 3209361.97},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da5c'),
#   'fid': 192,
#   'etiqueta': 'APARTAMENTOS MORROMAR',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B2',
#   'nom_entitur': 'Puerto del Carmen',
#   'gcd_nucltur': 'ES708B23',
#   'nom_nucltur': 'Puerto del Carmen: Matagorda - Los Pocillos',
#   'gcd_municipio': 35028,
#   'nom_municipio': 'Tías',
#   'direccion': 'CALLE MATO, 13 - PARC.29,30,31',
#   'prc_habita': '80 o más apartamentos',
#   'prc_plazas': '260 o más plazas',
#   'longitud': -13.62158773,
#   'latitud': 28.935513836,
#   'geohash': 'etnkd591d4',
#   'utm_x': 634347.45,
#   'utm_y': 3201623.12},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da5d'),
#   'fid': 193,
#   'etiqueta': 'APARTAMENTOS THE LAS GAVIOTAS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B2',
#   'nom_entitur': 'Puerto del Carmen',
#   'gcd_nucltur': 'ES708B23',
#   'nom_nucltur': 'Puerto del Carmen: Matagorda - Los Pocillos',
#   'gcd_municipio': 35028,
#   'nom_municipio': 'Tías',
#   'direccion': 'CALLE MATO, 1',
#   'prc_habita': '80 o más apartamentos',
#   'prc_plazas': '260 o más plazas',
#   'longitud': -13.61878504,
#   'latitud': 28.932692516,
#   'geohash': 'etnkd5515k',
#   'utm_x': 634624.29,
#   'utm_y': 3201313.68},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da5e'),
#   'fid': 194,
#   'etiqueta': 'APARTAMENTOS CLUB OCEANO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B2',
#   'nom_entitur': 'Puerto del Carmen',
#   'gcd_nucltur': 'ES708B22',
#   'nom_nucltur': 'Puerto del Carmen: Playa Grande',
#   'gcd_municipio': 35028,
#   'nom_municipio': 'Tías',
#   'direccion': 'CALLE ALCORCE, 3',
#   'prc_habita': 'De 40 a 79 apartamentos',
#   'prc_plazas': 'De 120 a 259 plazas',
#   'longitud': -13.66105917,
#   'latitud': 28.92290294,
#   'geohash': 'etnk91k245',
#   'utm_x': 630515.77,
#   'utm_y': 3200181.6},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da61'),
#   'fid': 197,
#   'etiqueta': 'BLUE SEA LANZAROTE PALM',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B2',
#   'nom_entitur': 'Puerto del Carmen',
#   'gcd_nucltur': 'ES708B22',
#   'nom_nucltur': 'Puerto del Carmen: Playa Grande',
#   'gcd_municipio': 35028,
#   'nom_municipio': 'Tías',
#   'direccion': 'CALLE ANZUELO, 60',
#   'prc_habita': '80 o más apartamentos',
#   'prc_plazas': '260 o más plazas',
#   'longitud': -13.65411763,
#   'latitud': 28.92340066,
#   'geohash': 'etnk93375b',
#   'utm_x': 631191.85,
#   'utm_y': 3200244.42},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da62'),
#   'fid': 198,
#   'etiqueta': 'APARTAMENTOS PRINCESA GUAYADEQUE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B2',
#   'nom_entitur': 'Puerto del Carmen',
#   'gcd_nucltur': 'ES708B22',
#   'nom_nucltur': 'Puerto del Carmen: Playa Grande',
#   'gcd_municipio': 35028,
#   'nom_municipio': 'Tías',
#   'direccion': 'CALLE CESAR MANRIQUE, 13',
#   'prc_habita': 'De 20 a 39 apartamentos',
#   'prc_plazas': 'De 50 a 119 plazas',
#   'longitud': -13.65612387,
#   'latitud': 28.922358309,
#   'geohash': 'etnk91puvq',
#   'utm_x': 630997.58,
#   'utm_y': 3200126.7},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da64'),
#   'fid': 200,
#   'etiqueta': 'HOTEL FAYCAN',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES705',
#   'nom_isla': 'Gran Canaria',
#   'gcd_entitur': 'ES705B2',
#   'nom_entitur': 'Las Canteras',
#   'gcd_nucltur': 'ES705B21',
#   'nom_nucltur': 'Las Canteras',
#   'gcd_municipio': 35016,
#   'nom_municipio': 'Las Palmas de Gran Canaria',
#   'direccion': 'CALLE NICOLAS ESTEVANEZ, 61',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -15.43598177,
#   'latitud': 28.139166836,
#   'geohash': 'etj00dxfe8',
#   'utm_x': 457188.14,
#   'utm_y': 3112695.57},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da65'),
#   'fid': 201,
#   'etiqueta': 'APARTAMENTOS LAS BRISAS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B3',
#   'nom_entitur': 'Playa Blanca - Puerto Calero',
#   'gcd_nucltur': 'ES708B31',
#   'nom_nucltur': 'Playa Blanca: Montaña Roja',
#   'gcd_municipio': 35034,
#   'nom_municipio': 'Yaiza',
#   'direccion': 'C/ LA GOMERA, Nº 1',
#   'prc_habita': '80 o más apartamentos',
#   'prc_plazas': '260 o más plazas',
#   'longitud': -13.83247519,
#   'latitud': 28.864147067,
#   'geohash': 'etnhjnx3zf',
#   'utm_x': 613869.45,
#   'utm_y': 3193494.53},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da67'),
#   'fid': 203,
#   'etiqueta': 'APARTAMENTOS VIA BUGANVILLAS SOL Y PLAYA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B2',
#   'nom_entitur': 'Puerto del Carmen',
#   'gcd_nucltur': 'ES708B22',
#   'nom_nucltur': 'Puerto del Carmen: Playa Grande',
#   'gcd_municipio': 35028,
#   'nom_municipio': 'Tías',
#   'direccion': 'CALLE CESAR MANRIQUE, 10',
#   'prc_habita': 'Menor de 20 apartamentos',
#   'prc_plazas': 'Menor de 50 plazas',
#   'longitud': -13.65585564,
#   'latitud': 28.92193571,
#   'geohash': 'etnk93047x',
#   'utm_x': 631024.26,
#   'utm_y': 3200080.17},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da69'),
#   'fid': 205,
#   'etiqueta': 'APARTAMENTOS OCEANO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B1',
#   'nom_entitur': 'Costa Teguise',
#   'gcd_nucltur': 'ES708B12',
#   'nom_nucltur': 'Costa Teguise: Litoral',
#   'gcd_municipio': 35024,
#   'nom_municipio': 'Teguise',
#   'direccion': 'AVENIDA DEL JABLILLO, 12',
#   'prc_habita': 'De 40 a 79 apartamentos',
#   'prc_plazas': 'De 50 a 119 plazas',
#   'longitud': -13.49060168,
#   'latitud': 28.995812826,
#   'geohash': 'etnkvn82y5',
#   'utm_x': 647030.3,
#   'utm_y': 3208460.65},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da6e'),
#   'fid': 210,
#   'etiqueta': 'APARTAMENTOS AGUA MARINA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B2',
#   'nom_entitur': 'Puerto del Carmen',
#   'gcd_nucltur': 'ES708B21',
#   'nom_nucltur': 'Puerto del Carmen: Casco',
#   'gcd_municipio': 35028,
#   'nom_municipio': 'Tías',
#   'direccion': 'CALLE TEIDE, 41',
#   'prc_habita': 'De 20 a 39 apartamentos',
#   'prc_plazas': 'De 50 a 119 plazas',
#   'longitud': -13.67555087,
#   'latitud': 28.922216183,
#   'geohash': 'etnk8c1u0e',
#   'utm_x': 629103.88,
#   'utm_y': 3200089.62},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da6f'),
#   'fid': 211,
#   'etiqueta': 'HOTEL ALOE CANTERAS - TENESOYA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES705',
#   'nom_isla': 'Gran Canaria',
#   'gcd_entitur': 'ES705B2',
#   'nom_entitur': 'Las Canteras',
#   'gcd_nucltur': 'ES705B21',
#   'nom_nucltur': 'Las Canteras',
#   'gcd_municipio': 35016,
#   'nom_municipio': 'Las Palmas de Gran Canaria',
#   'direccion': 'CALLE SAGASTA, 98',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -15.42994211,
#   'latitud': 28.147815335,
#   'geohash': 'etj00uhkbm',
#   'utm_x': 457784.61,
#   'utm_y': 3113651.53},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da73'),
#   'fid': 215,
#   'etiqueta': 'APARTAMENTOS CALAS III, LAS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B2',
#   'nom_entitur': 'Puerto del Carmen',
#   'gcd_nucltur': 'ES708B22',
#   'nom_nucltur': 'Puerto del Carmen: Playa Grande',
#   'gcd_municipio': 35028,
#   'nom_municipio': 'Tías',
#   'direccion': 'CALLE GUAYADEQUE, 3',
#   'prc_habita': 'De 40 a 79 apartamentos',
#   'prc_plazas': 'De 120 a 259 plazas',
#   'longitud': -13.65958928,
#   'latitud': 28.924461778,
#   'geohash': 'etnk91t3hw',
#   'utm_x': 630657.11,
#   'utm_y': 3200355.95},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da7b'),
#   'fid': 223,
#   'etiqueta': 'HOTEL VEROL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES705',
#   'nom_isla': 'Gran Canaria',
#   'gcd_entitur': 'ES705B2',
#   'nom_entitur': 'Las Canteras',
#   'gcd_nucltur': 'ES705B21',
#   'nom_nucltur': 'Las Canteras',
#   'gcd_municipio': 35016,
#   'nom_municipio': 'Las Palmas de Gran Canaria',
#   'direccion': 'CALLE SAGASTA, 25',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -15.43152327,
#   'latitud': 28.14345314,
#   'geohash': 'etj00g757r',
#   'utm_x': 457627.64,
#   'utm_y': 3113168.84},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da7d'),
#   'fid': 225,
#   'etiqueta': 'HOTEL TBH FLORA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B2',
#   'nom_entitur': 'Puerto del Carmen',
#   'gcd_nucltur': 'ES708B21',
#   'nom_nucltur': 'Puerto del Carmen: Casco',
#   'gcd_municipio': 35028,
#   'nom_municipio': 'Tías',
#   'direccion': 'CALLE REINA SOFIA, 25',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -13.67466331,
#   'latitud': 28.924865607,
#   'geohash': 'etnk8cd7t1',
#   'utm_x': 629187.12,
#   'utm_y': 3200384.16},
#  {'_id': ObjectId('648d6191fbe58f6d29f2da83'),
#   'fid': 231,
#   'etiqueta': 'APARTAMENTOS BARCAROLA CLUB',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B2',
#   'nom_entitur': 'Puerto del Carmen',
#   'gcd_nucltur': 'ES708B22',
#   'nom_nucltur': 'Puerto del Carmen: Playa Grande',
#   'gcd_municipio': 35028,
#   'nom_municipio': 'Tías',
#   'direccion': 'AVENIDA LAS PLAYAS, 53',
#   'prc_habita': '80 o más apartamentos',
#   'prc_plazas': 'De 120 a 259 plazas',
# ...
#   'fid': 573,
#   'etiqueta': 'APARTAMENTOS LA FUENTE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES707',
#   'nom_isla': 'La Palma',
#   'gcd_entitur': 'ES700B9',
#   'nom_entitur': 'Islas de Canarias sin entidades turísticas',
#   'gcd_nucltur': 'ES700B99',
#   'nom_nucltur': 'Islas de Canarias sin núcleos turísticos',
#   'gcd_municipio': 38037,
#   'nom_municipio': 'Santa Cruz de La Palma',
#   'direccion': 'PÉREZ DE BRITO, 49',
#   'prc_habita': 'Menor de 20 apartamentos',
#   'prc_plazas': 'Menor de 50 plazas',
#   'longitud': -17.76264186,
#   'latitud': 28.685657892,
#   'geohash': 'et575y1dh6',
#   'utm_x': 230052.01,
#   'utm_y': 3176285.47},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e126'),
#   'fid': 578,
#   'etiqueta': 'HOTEL APART. CASTILLETE',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES707',
#   'nom_isla': 'La Palma',
#   'gcd_entitur': 'ES700B9',
#   'nom_entitur': 'Islas de Canarias sin entidades turísticas',
#   'gcd_nucltur': 'ES700B99',
#   'nom_nucltur': 'Islas de Canarias sin núcleos turísticos',
#   'gcd_municipio': 38037,
#   'nom_municipio': 'Santa Cruz de La Palma',
#   'direccion': 'AVENIDA MARITIMA, 75',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -17.75985391,
#   'latitud': 28.687378767,
#   'geohash': 'et575y7sj7',
#   'utm_x': 230328.96,
#   'utm_y': 3176469.93},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e135'),
#   'fid': 593,
#   'etiqueta': 'HOTEL SANTA BARBARA GOLF Y OCEAN CLUB',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B3',
#   'nom_entitur': 'Abona',
#   'gcd_nucltur': 'ES709B33',
#   'nom_nucltur': 'Golf del Sur',
#   'gcd_municipio': 38035,
#   'nom_municipio': 'San Miguel de Abona',
#   'direccion': 'AVDA. DEL ATLÁNTICO S/N., URBANIZACIÓN GOLF DEL SUR',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.60758237,
#   'latitud': 28.024393916,
#   'geohash': 'esupqjdtzm',
#   'utm_x': 341962.39,
#   'utm_y': 3100946.48},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e139'),
#   'fid': 597,
#   'etiqueta': 'CLUB MONTE ANFI',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES705',
#   'nom_isla': 'Gran Canaria',
#   'gcd_entitur': 'ES705B1',
#   'nom_entitur': 'Mogán turístico',
#   'gcd_nucltur': 'ES705B16',
#   'nom_nucltur': 'Patalavaca - Arguineguín',
#   'gcd_municipio': 35012,
#   'nom_municipio': 'Mogán',
#   'direccion': 'CALLE LA VERGA S/N',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -15.69791908,
#   'latitud': 27.773136728,
#   'geohash': 'esuvfzcn5z',
#   'utm_x': 431234.69,
#   'utm_y': 3072267.14},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e13c'),
#   'fid': 600,
#   'etiqueta': 'HOTEL BULL DORADO BEACH & SPA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES705',
#   'nom_isla': 'Gran Canaria',
#   'gcd_entitur': 'ES705B1',
#   'nom_entitur': 'Mogán turístico',
#   'gcd_nucltur': 'ES705B16',
#   'nom_nucltur': 'Patalavaca - Arguineguín',
#   'gcd_municipio': 35012,
#   'nom_municipio': 'Mogán',
#   'direccion': 'AVENIDA LOS CANARIOS , 1',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -15.68408844,
#   'latitud': 27.762431138,
#   'geohash': 'esuvgjgpyk',
#   'utm_x': 432590.85,
#   'utm_y': 3071073.56},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e13e'),
#   'fid': 602,
#   'etiqueta': 'HOTEL VIK CORAL BEACH',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B3',
#   'nom_entitur': 'Playa Blanca - Puerto Calero',
#   'gcd_nucltur': 'ES708B31',
#   'nom_nucltur': 'Playa Blanca: Montaña Roja',
#   'gcd_municipio': 35034,
#   'nom_municipio': 'Yaiza',
#   'direccion': 'CALLE AUSTRIA Nº 15',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -13.87494585,
#   'latitud': 28.862202159,
#   'geohash': 'etnhhq0wd2',
#   'utm_x': 609729.01,
#   'utm_y': 3193239.02},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e140'),
#   'fid': 604,
#   'etiqueta': 'APARTHOTEL MORASOL ATLANTICO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES704',
#   'nom_isla': 'Fuerteventura',
#   'gcd_entitur': 'ES704B3',
#   'nom_entitur': 'Costa Calma',
#   'gcd_nucltur': 'ES704B31',
#   'nom_nucltur': 'Costa Calma',
#   'gcd_municipio': 35015,
#   'nom_municipio': 'Pájara',
#   'direccion': 'BAJA DE LOS ERIZOS Nº2',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -14.22977484,
#   'latitud': 28.154765458,
#   'geohash': 'etjbhjqjqh',
#   'utm_x': 575623.28,
#   'utm_y': 3114586.58},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e14e'),
#   'fid': 618,
#   'etiqueta': 'HOTEL WAVIA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES705',
#   'nom_isla': 'Gran Canaria',
#   'gcd_entitur': 'ES705B2',
#   'nom_entitur': 'Las Canteras',
#   'gcd_nucltur': 'ES705B21',
#   'nom_nucltur': 'Las Canteras',
#   'gcd_municipio': 35016,
#   'nom_municipio': 'Las Palmas de Gran Canaria',
#   'direccion': 'CALLE PAJONALES, Nº 19',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -15.43196672,
#   'latitud': 28.149251024,
#   'geohash': 'etj00u6v30',
#   'utm_x': 457586.38,
#   'utm_y': 3113811.28},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e150'),
#   'fid': 620,
#   'etiqueta': 'IDYLL SUITES',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES705',
#   'nom_isla': 'Gran Canaria',
#   'gcd_entitur': 'ES705B1',
#   'nom_entitur': 'Mogán turístico',
#   'gcd_nucltur': 'ES705B13',
#   'nom_nucltur': 'Tauro - Playa El Cura',
#   'gcd_municipio': 35012,
#   'nom_municipio': 'Mogán',
#   'direccion': 'C/ PETREL , 1',
#   'prc_habita': 'De 40 a 79 apartamentos',
#   'prc_plazas': 'De 50 a 119 plazas',
#   'longitud': -15.73296668,
#   'latitud': 27.800641893,
#   'geohash': 'esuy1uzw7r',
#   'utm_x': 427799.55,
#   'utm_y': 3075334.17},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e152'),
#   'fid': 622,
#   'etiqueta': 'HOTEL ROBINSON CLUB ESQUINZO PLAYA',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES704',
#   'nom_isla': 'Fuerteventura',
#   'gcd_entitur': 'ES704B4',
#   'nom_entitur': 'Morro Jable',
#   'gcd_nucltur': 'ES704B43',
#   'nom_nucltur': 'Morro Jable: Esquinzo - Butihondo',
#   'gcd_municipio': 35015,
#   'nom_municipio': 'Pájara',
#   'direccion': 'BARRANCO DEL ESQUINZO',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -14.30219292,
#   'latitud': 28.076372419,
#   'geohash': 'esvzdx1kwz',
#   'utm_x': 568562.67,
#   'utm_y': 3105859.09},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e155'),
#   'fid': 625,
#   'etiqueta': 'HOTEL BOUTIQUE CASA MOZART',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES705',
#   'nom_isla': 'Gran Canaria',
#   'gcd_entitur': 'ES705B9',
#   'nom_entitur': 'Resto de Gran Canaria',
#   'gcd_nucltur': 'ES705B9',
#   'nom_nucltur': 'Resto de Gran Canaria',
#   'gcd_municipio': 35016,
#   'nom_municipio': 'Las Palmas de Gran Canaria',
#   'direccion': 'C/ MOZART, Nº 2',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -15.43419922,
#   'latitud': 28.127971371,
#   'geohash': 'etj00b91m1',
#   'utm_x': 457358.75,
#   'utm_y': 3111454.72},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e159'),
#   'fid': 629,
#   'etiqueta': 'HOTEL ARENA BEACH',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES704',
#   'nom_isla': 'Fuerteventura',
#   'gcd_entitur': 'ES704B2',
#   'nom_entitur': 'Corralejo - El Cotillo',
#   'gcd_nucltur': 'ES704B21',
#   'nom_nucltur': 'Corralejo',
#   'gcd_municipio': 35014,
#   'nom_municipio': 'La Oliva',
#   'direccion': 'C/. LA GOMERA, 5',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -13.86250159,
#   'latitud': 28.725593284,
#   'geohash': 'etn5kt3dsq',
#   'utm_x': 611087.57,
#   'utm_y': 3178114.35},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e15c'),
#   'fid': 632,
#   'etiqueta': 'MARESIA CANTERAS URBAN HOTEL',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES705',
#   'nom_isla': 'Gran Canaria',
#   'gcd_entitur': 'ES705B2',
#   'nom_entitur': 'Las Canteras',
#   'gcd_nucltur': 'ES705B21',
#   'nom_nucltur': 'Las Canteras',
#   'gcd_municipio': 35016,
#   'nom_municipio': 'Las Palmas de Gran Canaria',
#   'direccion': 'C/ LEON TOLSTOI, 1',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -15.43681,
#   'latitud': 28.13642,
#   'geohash': 'etj00dp682',
#   'utm_x': 457105.72,
#   'utm_y': 3112391.57},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e164'),
#   'fid': 640,
#   'etiqueta': 'HOTEL CORDIAL VISTA  ACUARIO',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES705',
#   'nom_isla': 'Gran Canaria',
#   'gcd_entitur': 'ES705B2',
#   'nom_entitur': 'Las Canteras',
#   'gcd_nucltur': 'ES705B21',
#   'nom_nucltur': 'Las Canteras',
#   'gcd_municipio': 35016,
#   'nom_municipio': 'Las Palmas de Gran Canaria',
#   'direccion': 'C/ JUAN REJÓN, 42',
#   'prc_habita': 'Menor de 50 habitaciones',
#   'prc_plazas': 'Menor de 100 plazas',
#   'longitud': -15.42687782,
#   'latitud': 28.148942092,
#   'geohash': 'etj00uq7rx',
#   'utm_x': 458085.93,
#   'utm_y': 3113775.29},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e16a'),
#   'fid': 646,
#   'etiqueta': 'HOTEL LANCELOT',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B9',
#   'nom_entitur': 'Resto de Lanzarote',
#   'gcd_nucltur': 'ES708B9',
#   'nom_nucltur': 'Resto de Lanzarote',
#   'gcd_municipio': 35004,
#   'nom_municipio': 'Arrecife',
#   'direccion': 'AVENIDA MANCOMUNIDAD, 9',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -13.55565714,
#   'latitud': 28.958342949,
#   'geohash': 'etnkex9nd6',
#   'utm_x': 640743.24,
#   'utm_y': 3204229.41},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e16d'),
#   'fid': 649,
#   'etiqueta': 'HOTEL GRAN REY',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES706',
#   'nom_isla': 'La Gomera',
#   'gcd_entitur': 'ES700B9',
#   'nom_entitur': 'Islas de Canarias sin entidades turísticas',
#   'gcd_nucltur': 'ES700B99',
#   'nom_nucltur': 'Islas de Canarias sin núcleos turísticos',
#   'gcd_municipio': 38049,
#   'nom_municipio': 'Valle Gran Rey',
#   'direccion': 'AVENIDA MARITIMA 1, LA PUNTILLA',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -17.33894231,
#   'latitud': 28.089159569,
#   'geohash': 'esgxv3qpjq',
#   'utm_x': 270183.07,
#   'utm_y': 3109288.54},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e170'),
#   'fid': 652,
#   'etiqueta': 'HL PARADISE ISLAND',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B3',
#   'nom_entitur': 'Playa Blanca - Puerto Calero',
#   'gcd_nucltur': 'ES708B31',
#   'nom_nucltur': 'Playa Blanca: Montaña Roja',
#   'gcd_municipio': 35034,
#   'nom_municipio': 'Yaiza',
#   'direccion': 'URBANIZACIÓN MONTAÑA ROJA, PARCELA 60',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -13.8436532,
#   'latitud': 28.868065927,
#   'geohash': 'etnhhzr2et',
#   'utm_x': 612774.94,
#   'utm_y': 3193918.07},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e171'),
#   'fid': 653,
#   'etiqueta': 'APARTAMENTOS FUENTEPARK',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'A3',
#   'cod_tipo': '5510_L6',
#   'nom_tipo': 'Apartamentos',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES704',
#   'nom_isla': 'Fuerteventura',
#   'gcd_entitur': 'ES704B2',
#   'nom_entitur': 'Corralejo - El Cotillo',
#   'gcd_nucltur': 'ES704B21',
#   'nom_nucltur': 'Corralejo',
#   'gcd_municipio': 35014,
#   'nom_municipio': 'La Oliva',
#   'direccion': 'CALLE ANGUILA, 1',
#   'prc_habita': 'De 40 a 79 apartamentos',
#   'prc_plazas': 'De 120 a 259 plazas',
#   'longitud': -13.87074351,
#   'latitud': 28.733881506,
#   'geohash': 'etn5kqgdur',
#   'utm_x': 610273.91,
#   'utm_y': 3179025.02},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e17d'),
#   'fid': 665,
#   'etiqueta': 'HOTEL MIRAMAR',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES708',
#   'nom_isla': 'Lanzarote',
#   'gcd_entitur': 'ES708B9',
#   'nom_entitur': 'Resto de Lanzarote',
#   'gcd_nucltur': 'ES708B9',
#   'nom_nucltur': 'Resto de Lanzarote',
#   'gcd_municipio': 35004,
#   'nom_municipio': 'Arrecife',
#   'direccion': 'CALLE COLL, 2',
#   'prc_habita': 'De 50 a 149 habitaciones',
#   'prc_plazas': 'De 100 a 349 plazas',
#   'longitud': -13.54779971,
#   'latitud': 28.958682146,
#   'geohash': 'etnkexyb93',
#   'utm_x': 641508.53,
#   'utm_y': 3204276.37},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e17e'),
#   'fid': 666,
#   'etiqueta': 'HOTEL LOS HIBISCOS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B1',
#   'nom_entitur': 'Adeje turístico',
#   'gcd_nucltur': 'ES709B14',
#   'nom_nucltur': 'Costa Adeje',
#   'gcd_municipio': 38001,
#   'nom_municipio': 'Adeje',
#   'direccion': 'URBANIZACIÓN SAN EUGENIO',
#   'prc_habita': 'De 150 a 299 habitaciones',
#   'prc_plazas': 'De 350 a 649 plazas',
#   'longitud': -16.73240303,
#   'latitud': 28.075653263,
#   'geohash': 'esupeppbdc',
#   'utm_x': 329770.32,
#   'utm_y': 3106794.36},
#  {'_id': ObjectId('648d6250fbe58f6d29f2e182'),
#   'fid': 670,
#   'etiqueta': 'HOTEL APART. COLUMBUS',
#   'granularidad': 'ALOJAMIENTOS',
#   'cod_tipocat': 'H3',
#   'cod_tipo': '5510_L1',
#   'nom_tipo': 'Hotel',
#   'cod_categor': 3,
#   'nom_categor': '3 Estrellas',
#   'gcd_isla': 'ES709',
#   'nom_isla': 'Tenerife',
#   'gcd_entitur': 'ES709B2',
#   'nom_entitur': 'Las Américas - Los Cristianos',
#   'gcd_nucltur': 'ES709B22',
#   'nom_nucltur': 'Las Américas - Arona',
#   'gcd_municipio': 38006,
#   'nom_municipio': 'Arona',
#   'direccion': 'AVENIDA SANTIAGO PUIG 6',
#   'prc_habita': '300 o más habitaciones',
#   'prc_plazas': '650 o más plazas',
#   'longitud': -16.7277789,
#   'latitud': 28.060790151,
#   'geohash': 'esupek71yw',
#   'utm_x': 330201.4,
#   'utm_y': 3105141.0}]

# %% [markdown]
# 2️⃣ `$gt`: mayor que
#
# Busquemos aquellos alojamientos que tengan mas de 3⭐️

# %%
mayorque = pd.DataFrame(list(coleccion.find({"cod_categor":{"$gt":3}})))
mayorque
# Out:
#                           _id  fid                                 etiqueta  \
# 0    648d6191fbe58f6d29f2d99c    0  HOTEL RIU CLUB PARAISO LANZAROTE RESORT
# 1    648d6191fbe58f6d29f2d99d    1               OCCIDENTAL LANZAROTE PLAYA
# 2    648d6191fbe58f6d29f2d99e    2                      HOTEL PARADISE PARK
# 3    648d6191fbe58f6d29f2d99f    3            HOTEL CATALONIA PUNTA DEL REY
# 4    648d6191fbe58f6d29f2d9a4    8                       HOTEL TAORO GARDEN
# ..                        ...  ...                                      ...
# 586  648d6250fbe58f6d29f2e183  671                       HOTEL CONQUISTADOR
# 587  648d6250fbe58f6d29f2e184  672                               HOTEL GALA
# 588  648d6250fbe58f6d29f2e185  673      HOTEL TIGOTAN PLAYA DE LAS AMÉRICAS
# 589  648d6250fbe58f6d29f2e186  674                       HOTEL SOL TENERIFE
# 590  648d6250fbe58f6d29f2e187  675                            HOTEL VULCANO
#
#      granularidad cod_tipocat cod_tipo nom_tipo  cod_categor  nom_categor  \
# 0    ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 1    ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 2    ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 3    ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 4    ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# ..            ...         ...      ...      ...          ...          ...
# 586  ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 587  ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 588  ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 589  ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 590  ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
#
#     gcd_isla   nom_isla gcd_entitur                    nom_entitur  \
# 0      ES708  Lanzarote     ES708B2              Puerto del Carmen
# 1      ES708  Lanzarote     ES708B1                  Costa Teguise
# 2      ES709   Tenerife     ES709B2  Las Américas - Los Cristianos
# 3      ES709   Tenerife     ES709B9              Resto de Tenerife
# 4      ES709   Tenerife     ES709B5    Puerto de la Cruz turístico
# ..       ...        ...         ...                            ...
# 586    ES709   Tenerife     ES709B2  Las Américas - Los Cristianos
# 587    ES709   Tenerife     ES709B2  Las Américas - Los Cristianos
# 588    ES709   Tenerife     ES709B2  Las Américas - Los Cristianos
# 589    ES709   Tenerife     ES709B2  Las Américas - Los Cristianos
# 590    ES709   Tenerife     ES709B2  Las Américas - Los Cristianos
#
#     gcd_nucltur                                  nom_nucltur  gcd_municipio  \
# 0      ES708B23  Puerto del Carmen: Matagorda - Los Pocillos          35028
# 1      ES708B12                       Costa Teguise: Litoral          35024
# 2      ES709B23                               Los Cristianos          38006
# 3       ES709B9                            Resto de Tenerife          38011
# 4      ES709B53                               Taoro - La Paz          38028
# ..          ...                                          ...            ...
# 586    ES709B22                         Las Américas - Arona          38006
# 587    ES709B22                         Las Américas - Arona          38006
# 588    ES709B22                         Las Américas - Arona          38006
# 589    ES709B22                         Las Américas - Arona          38006
# 590    ES709B22                         Las Américas - Arona          38006
#
#          nom_municipio                              direccion  \
# 0                 Tías  CALLE SUIZA , 4.PLAYA DE LOS POCILLOS
# 1              Teguise                     AVENIDA DEL MAR, 6
# 2                Arona             URBANIZACIÓN OASIS DEL SUR
# 3           Candelaria              AVENIDA GENERALISIMO, 165
# 4    Puerto de la Cruz      CALLE DINAMARCA, 3 (PARQUE TAORO)
# ..                 ...                                    ...
# 586              Arona                       AVENIDA MARITIMA
# 587              Arona      CALLE ARQUITECTO GOMEZ CUESTA , 3
# 588              Arona      AVENIDA NOELIA ALFONSO CABRERA, 6
# 589              Arona        AVENIDA RAFAEL PUIG LLUVINA, 12
# 590              Arona     CALLE ANTONIO DOMINGUEZ ALFONSO, 8
#
#                     prc_habita           prc_plazas   longitud    latitud  \
# 0       300 o más habitaciones     650 o más plazas -13.639328  28.926763
# 1       300 o más habitaciones     650 o más plazas -13.509783  28.987312
# 2       300 o más habitaciones     650 o más plazas -16.706284  28.053429
# 3       300 o más habitaciones     650 o más plazas -16.362112  28.377362
# 4    De 150 a 299 habitaciones  De 350 a 649 plazas -16.546429  28.410945
# ..                         ...                  ...        ...        ...
# 586     300 o más habitaciones     650 o más plazas -16.735130  28.057528
# 587     300 o más habitaciones  De 350 a 649 plazas -16.730279  28.066466
# 588     300 o más habitaciones     650 o más plazas -16.729458  28.059924
# 589     300 o más habitaciones     650 o más plazas -16.731645  28.064358
# 590     300 o más habitaciones     650 o más plazas -16.730418  28.056558
#
#         geohash      utm_x       utm_y
# 0    etnk99unse  632629.37  3200633.49
# 1    etnkusfrr4  645173.54  3207494.99
# 2    esupeffz56  332302.78  3104295.54
# 3    eth37tvqp5  366536.23  3139759.91
# 4    eth1xkp3b2  348521.75  3143699.04
# ..          ...        ...         ...
# 586  esupe5tygn  329473.70  3104789.81
# 587  esupem37h0  329964.62  3105773.38
# 588  esupek1uzk  330035.00  3105047.35
# 589  esupekbqsr  329827.06  3105541.76
# 590  esupe7932c  329935.31  3104675.74
#
# [591 rows x 25 columns]

# %%
mayorque.nom_categor.unique()
# Out:
# array(['4 Estrellas', '5 Estrellas'], dtype=object)

# %% [markdown]
# 3️⃣ `$gte`: mayor o igual que
#
# Busquemos aquellos alojamientos que tengan 3 o mas ⭐️

# %%
mayor_igual = pd.DataFrame(list(coleccion.find({"cod_categor":{"$gte":3}})))
mayor_igual
# Out:
#                            _id  fid                                 etiqueta  \
# 0     648d6191fbe58f6d29f2d99c    0  HOTEL RIU CLUB PARAISO LANZAROTE RESORT
# 1     648d6191fbe58f6d29f2d99d    1               OCCIDENTAL LANZAROTE PLAYA
# 2     648d6191fbe58f6d29f2d99e    2                      HOTEL PARADISE PARK
# 3     648d6191fbe58f6d29f2d99f    3            HOTEL CATALONIA PUNTA DEL REY
# 4     648d6191fbe58f6d29f2d9a0    4                             HOTEL MEDANO
# ...                        ...  ...                                      ...
# 1048  648d6250fbe58f6d29f2e183  671                       HOTEL CONQUISTADOR
# 1049  648d6250fbe58f6d29f2e184  672                               HOTEL GALA
# 1050  648d6250fbe58f6d29f2e185  673      HOTEL TIGOTAN PLAYA DE LAS AMÉRICAS
# 1051  648d6250fbe58f6d29f2e186  674                       HOTEL SOL TENERIFE
# 1052  648d6250fbe58f6d29f2e187  675                            HOTEL VULCANO
#
#       granularidad cod_tipocat cod_tipo nom_tipo  cod_categor  nom_categor  \
# 0     ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 1     ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 2     ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 3     ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 4     ALOJAMIENTOS          H3  5510_L1    Hotel            3  3 Estrellas
# ...            ...         ...      ...      ...          ...          ...
# 1048  ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 1049  ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 1050  ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 1051  ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
# 1052  ALOJAMIENTOS          H4  5510_L1    Hotel            4  4 Estrellas
#
#      gcd_isla   nom_isla gcd_entitur                    nom_entitur  \
# 0       ES708  Lanzarote     ES708B2              Puerto del Carmen
# 1       ES708  Lanzarote     ES708B1                  Costa Teguise
# 2       ES709   Tenerife     ES709B2  Las Américas - Los Cristianos
# 3       ES709   Tenerife     ES709B9              Resto de Tenerife
# 4       ES709   Tenerife     ES709B3                          Abona
# ...       ...        ...         ...                            ...
# 1048    ES709   Tenerife     ES709B2  Las Américas - Los Cristianos
# 1049    ES709   Tenerife     ES709B2  Las Américas - Los Cristianos
# 1050    ES709   Tenerife     ES709B2  Las Américas - Los Cristianos
# 1051    ES709   Tenerife     ES709B2  Las Américas - Los Cristianos
# 1052    ES709   Tenerife     ES709B2  Las Américas - Los Cristianos
#
#      gcd_nucltur                                  nom_nucltur  gcd_municipio  \
# 0       ES708B23  Puerto del Carmen: Matagorda - Los Pocillos          35028
# 1       ES708B12                       Costa Teguise: Litoral          35024
# 2       ES709B23                               Los Cristianos          38006
# 3        ES709B9                            Resto de Tenerife          38011
# 4       ES709B32                                    El Médano          38017
# ...          ...                                          ...            ...
# 1048    ES709B22                         Las Américas - Arona          38006
# 1049    ES709B22                         Las Américas - Arona          38006
# 1050    ES709B22                         Las Américas - Arona          38006
# 1051    ES709B22                         Las Américas - Arona          38006
# 1052    ES709B22                         Las Américas - Arona          38006
#
#             nom_municipio                              direccion  \
# 0                    Tías  CALLE SUIZA , 4.PLAYA DE LOS POCILLOS
# 1                 Teguise                     AVENIDA DEL MAR, 6
# 2                   Arona             URBANIZACIÓN OASIS DEL SUR
# 3              Candelaria              AVENIDA GENERALISIMO, 165
# 4     Granadilla de Abona                       PASEO PICACHO, 2
# ...                   ...                                    ...
# 1048                Arona                       AVENIDA MARITIMA
# 1049                Arona      CALLE ARQUITECTO GOMEZ CUESTA , 3
# 1050                Arona      AVENIDA NOELIA ALFONSO CABRERA, 6
# 1051                Arona        AVENIDA RAFAEL PUIG LLUVINA, 12
# 1052                Arona     CALLE ANTONIO DOMINGUEZ ALFONSO, 8
#
#                     prc_habita           prc_plazas   longitud    latitud  \
# 0       300 o más habitaciones     650 o más plazas -13.639328  28.926763
# 1       300 o más habitaciones     650 o más plazas -13.509783  28.987312
# 2       300 o más habitaciones     650 o más plazas -16.706284  28.053429
# 3       300 o más habitaciones     650 o más plazas -16.362112  28.377362
# 4     De 50 a 149 habitaciones  De 100 a 349 plazas -16.538002  28.044017
# ...                        ...                  ...        ...        ...
# 1048    300 o más habitaciones     650 o más plazas -16.735130  28.057528
# 1049    300 o más habitaciones  De 350 a 649 plazas -16.730279  28.066466
# 1050    300 o más habitaciones     650 o más plazas -16.729458  28.059924
# 1051    300 o más habitaciones     650 o más plazas -16.731645  28.064358
# 1052    300 o más habitaciones     650 o más plazas -16.730418  28.056558
#
#          geohash      utm_x       utm_y
# 0     etnk99unse  632629.37  3200633.49
# 1     etnkusfrr4  645173.54  3207494.99
# 2     esupeffz56  332302.78  3104295.54
# 3     eth37tvqp5  366536.23  3139759.91
# 4     esupx9m2hx  348831.06  3103032.41
# ...          ...        ...         ...
# 1048  esupe5tygn  329473.70  3104789.81
# 1049  esupem37h0  329964.62  3105773.38
# 1050  esupek1uzk  330035.00  3105047.35
# 1051  esupekbqsr  329827.06  3105541.76
# 1052  esupe7932c  329935.31  3104675.74
#
# [1053 rows x 25 columns]

# %%
mayor_igual.nom_categor.unique()
# Out:
# array(['4 Estrellas', '3 Estrellas', '5 Estrellas'], dtype=object)

# %% [markdown]
# 4️⃣ `$lt`: menor que
#
# Busquemos aquellos alojamientos que tengan menos de 3⭐️

# %% [markdown]
# 5️⃣ `$lte`: menor que
#
# Busquemos aquellos alojamientos que tengan 3 o menos ⭐️

# %% [markdown]
# 6️⃣ `in()`: dentro de
#
# Queremos sacar todos los alojamientos que están en Lanzarote y en El Hierro

# %%
# creamos una lista con las islas que queremos buscar.

# %% [markdown]
# 7️⃣ `nin()` no dentro de.
#
# Hace referencia a:
#
# - el valor del campo no está
#
#
# - el campo no existe
#
#
# Imaginemos que queremos buscar todas las islas. Podríamos hacer un `find` e indicar el nombre de todas las islas. También podemos usar `nin` y especificar solo el que no queremo

# %% [markdown]
# 8️⃣ `$ne`: distinto de
#
# Si quisieramos hacer una búsqueda como la anterior también podemos usar. Buscaremos todo lo que sea distinto de Lanzarote

# %% [markdown]
# ## Operadores `and` y `or`

# %% [markdown]
# Combinemos dos condiciones, aquí podemos usar dos operadores:
#
# - `$and`: se tienen que cumplir todas las condiciones que le pasamos
#
#
# - `$or`: que se cumpla una condición u otra

# %% [markdown]
# ## Proyecciones

# %% [markdown]
# Haremos proyecciones cuando no queramos que nos devuelvan todos los campos de nuestro documento.

# %% [markdown]
# # Otros métodos interesantes

# %% [markdown]
# ## `exists()`
#
# Si no quiero que me devuelva los que no tienen o no determinado campo
#
# En este caso queremos filtrar por aquellos campos que tienen el campo "nombre"

# %% [markdown]
# ## `limit()`

# %% [markdown]
# ## `sort()`
#
# El sentido del orden los especificaremos pasando un `1` o un `-1`.
#
# - `1`: orden ascendente.
#
#
# - `-1`: orden descendente.

# %% [markdown]
# ## `type()`
#
# Elige los documentos en los que el valor del campo es una instancia del tipo.
#
# Los tipos que hay en Mongo los tenéis [aquí](https://docs.mongodb.com/manual/reference/operator/query/type/)

# %%
# tenemos algún nulo en la campo "nom_tipo"?

# %%
# devuelveme todo lo que sea de tipo string del campo "nom_tipo"

# %% [markdown]
# # `update()`
#
#
# Nos va a ayudar a actualizar un entrada de nuestra colección.

# %%
# comprobemos si se hizo el cambio

# %% [markdown]
# # `delete()`
#
# Eliminamos una entrada de nuestra colección

# %%
# comprobemos si se hizo el cambio

# %% [markdown]
# # Geoqueries

# %% [markdown]
# ## Antes de empezar

# %% [markdown]
# Antes de ponernos a trabajar en geoqueries tenemos que hacer algunas cositas:
#
# - 1️⃣ Para poder hacer las geoqueries tenemos que tener una columna con las coordenadas con la siguiente estructura 👇🏽:
#
# ![image.png](attachment:image.png)
#
#
# - 2️⃣ Crear los índices

# %% [markdown]
# 1️⃣ Crear la geometría

# %% [markdown]
# **No se podrán hacer los índices más adelante si tenemos NaN, por lo que lo primero vamos a eliminar esos nulos**

# %% [markdown]
# Lo que vamos a hacer ahora es eliminar la colección y volver a meter los datos:

# %%
# creamos la base de datos

# %%
# creamos la coleccion

# %%
# volvemos a insertar los datos

# %% [markdown]
# 2️⃣ Crear el índice
#
# Lo podemos hacer de dos formas:
#
# - A través de código desde jupyter
#
#
# - A través de la interfaz de Mongo

# %%
# a través de jupyter

# %%
# a través de la interfaz

# %% [markdown]
# - Nos vamos a la pestaña de `Indexes` y pichamos en `CREATE INDEX`
# ![image.png](attachment:image.png)

# %% [markdown]
# - Seleccionamos el campo sobre el que queremos crear el índice. En nuestro caso: `geometria.coordinates`
# ![image.png](attachment:image.png)

# %% [markdown]
# - seleccionamos el tipo de geometria, normalmente haremos un `2d-sphere`
# ![image.png](attachment:image.png)

# %% [markdown]
# - Por último ponemos nombre al índice que hemos creado:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Tipos de geoqueries
#
# - `near`: especifica un punto para el que una consulta geoespacial devuelve los documentos desde el más cercano al más lejano. El operador `$near` puede especificar un punto GeoJSON o un punto de coordenadas heredado.
#
#
#
# - `geonear`: muestra los documentos en orden de más cercano a más lejano de un punto especificado. Además nos va a incluir una columna más indicando los metros de distancia que hay entre el punto de referencia y cada uno de los de nuestra colección

# %% [markdown]
# ### `near()`
#
# Necesitaremos:
#
# - Unas coordenadas de referencia (en nuestro ejemplo geopoint). Recordamos que tienen que estar en formato de geopunto
#
#
# - Unos metros máximos o mínimos de distancia (en nuestro ejemplo metros)

# %%
# definimos el punto sobre el que queremos hacer nuestra búsqueda

# %% [markdown]
# ## `geonear()`
#
# Es una query de agregación. ¿Qué significa esto?
#
# La agregación en MongoDB sigue una estructura tipo *pipeline*, es decir,  diferentes etapas, donde cada una toma la salida de la anterior. Los elementos del *pipeline* se incluyen en un array y se ejecutarán por orden.
# Necesitaremos:
#
# - Unas coordenadas de referencia (en nuestro ejemplo geopoint). Recordamos que tienen que estar en formato de geopunto
#
#
# - Unos metros máximos o mínimos de distancia (en nuestro ejemplo metros)

# %% [markdown]
# # Ploteemos los resultados

# %%
# !pip install folium

# %%
import folium

# %%
# crear mapa

# %% [markdown]
# ## Guardar el mapa

# %%
# guardamos el mapa, solo lo podremos hacer en html
