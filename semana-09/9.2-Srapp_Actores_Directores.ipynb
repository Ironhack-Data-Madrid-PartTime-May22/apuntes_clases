# %%
import pandas as pd
import numpy as np
import re
import pickle
from tqdm import tqdm

import time

import random 


from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options


# Ignoring the warnings.
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Actors

# %%
# abrimos el pickle de los actores más representado
with open('data/top_ten_actor.pkl', 'rb') as act:
    actors = pickle.load(act)
actors
# Out:
# ['Adam Sandler',
#  'Maya Rudolph',
#  'Andrew Bachelor',
#  'Lakeith Stanfield',
#  'Jacki Weaver',
#  'Ken Marino',
#  'Robbie Amell',
#  'Zachary Quinto',
#  'Nick Swardson',
#  'Rob Schneider']

# %%
actors_list = actors[:3]
# creamos un diccionario

# %%
list_ = actors_list



dicc = {"name": [], 
                "image": [], 
                "description": [], 
                "positions": [], 
                "known_for": [], 
                "creditos": []}


driver = webdriver.Chrome()
driver.implicitly_wait(10)

driver.get("https://www.imdb.com/")
    

for element in tqdm(list_): 

    # metemos el actor
    driver.find_element("css selector", "#suggestion-search").send_keys(element, Keys.ENTER)
    driver.implicitly_wait(10)
    
    
    # hacemos click en la actriz o actor
    driver.find_element("xpath", '//*[@id="__next"]/main/div[2]/div[3]/section/div/div[1]/section[2]/div[2]/ul/li[1]/div[2]/div/a').click()

    dicc["name"].append(element)

    time.sleep(random.randint(1, 2))

    #capturamos los creditos
    try:
        dicc["creditos"].append(driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/div[3]/section[2]/div[2]/div[2]').text)
    except:
        dicc["creditos"].append(np.nan)
    
    time.sleep(random.randint(1, 2))
    # capturamos la posición
    try:
        dicc["positions"].append(driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div/ul/li').text)
    except: 
        dicc["positions"].append(np.nan)
            
    time.sleep(random.randint(1, 2))        
    # capturamos conocido por
    try:
        dicc["known_for"].append(driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/div[3]/section[1]/div[2]/div/div[2]').text)
    except:
        dicc["known_for"].append(np.nan)
        
    
    

    # entramos en la biografía
    driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[1]/div/div[2]/ul/li[1]/a').click()
    driver.implicitly_wait(30)
    time.sleep(random.randint(1, 2))
    # capturamos la descripcion
    try:
        dicc["description"].append(driver.find_element("xpath", '//*[@id="mini_bio_0"]').text)
    except:
        dicc["description"].append(np.nan)
    time.sleep(random.randint(1, 2))    
    # capturamos la imagen
    try:
        dicc["image"].append(driver.find_element("xpath", '//*[@id="__next"]/main/div/section/section/div[3]/section/section/div[2]/div/div/div/img').get_attribute("src"))
    except:
        dicc["image"].append(np.nan)
        
    
driver.quit()
pd.DataFrame(dicc)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[31], line 27
#      23 driver.implicitly_wait(10)
#      26 # hacemos click en la actriz o actor
# ---> 27 driver.find_element("xpath", '//*[@id="__next"]/main/div[2]/div[3]/section/div/div[1]/section[2]/div[2]/ul/li[1]/div[2]/div/a').click()
#      29 dicc["name"].append(element)
#      31 time.sleep(random.randint(1, 2))
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/apis/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:740, in WebDriver.find_element(self, by, value)
#     737     by = By.CSS_SELECTOR
#     738     value = f'[name="{value}"]'
# --> 740 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/apis/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:346, in WebDriver.execute(self, driver_command, params)
#     344 response = self.command_executor.execute(driver_command, params)
#     345 if response:
# --> 346     self.error_handler.check_response(response)
#     347     response["value"] = self._unwrap_value(response.get("value", None))
#     348     return response
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/apis/lib/python3.11/site-packages/selenium/webdriver/remote/errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=114.0.5735.133)
# Stacktrace:
# 0   chromedriver                        0x0000000100e63f48 chromedriver + 4226888
# 1   chromedriver                        0x0000000100e5c4f4 chromedriver + 4195572
# 2   chromedriver                        0x0000000100aa0d68 chromedriver + 281960
# 3   chromedriver                        0x0000000100a7aef8 chromedriver + 126712
# 4   chromedriver                        0x0000000100affe88 chromedriver + 671368
# 5   chromedriver                        0x0000000100b1245c chromedriver + 746588
# 6   chromedriver                        0x0000000100acff1c chromedriver + 474908
# 7   chromedriver                        0x0000000100ad0ef4 chromedriver + 478964
# 8   chromedriver                        0x0000000100e2559c chromedriver + 3970460
# 9   chromedriver                        0x0000000100e296f0 chromedriver + 3987184
# 10  chromedriver                        0x0000000100e2f5b4 chromedriver + 4011444
# 11  chromedriver                        0x0000000100e2a2fc chromedriver + 3990268
# 12  chromedriver                        0x0000000100e021c0 chromedriver + 3826112
# 13  chromedriver                        0x0000000100e46088 chromedriver + 4104328
# 14  chromedriver                        0x0000000100e461e0 chromedriver + 4104672
# 15  chromedriver                        0x0000000100e55f28 chromedriver + 4169512
# 16  libsystem_pthread.dylib             0x000000019489bfa8 _pthread_start + 148
# 17  libsystem_pthread.dylib             0x0000000194896da0 thread_start + 8

# %% [markdown]
# # Funcion de scraping

# %%
def scraping_imbd(listado):

    dicc = {"name": [], 
            "image": [], 
            "description": [], 
            "positions": [], 
            "known_for": [], 
            "creditos": []}

# genera un time sleep random entre 0.5 seg y 1.5 seg con un randit  e importa la libreria necesaria 

    driver = webdriver.Chrome()
    driver.implicitly_wait(10)

    driver.get("https://www.imdb.com/")   

    for element in tqdm(listado): 

        # metemos el actor
        driver.find_element("css selector", "#suggestion-search").send_keys(element, Keys.ENTER)
        driver.implicitly_wait(10)
        
        
        # hacemos click en la actriz o actor
        driver.find_element("xpath", '//*[@id="__next"]/main/div[2]/div[3]/section/div/div[1]/section[2]/div[2]/ul/li[1]/div[2]/div/a').click()

        dicc["name"].append(element)

        time.sleep(random.randint(1, 2))
        #capturamos los creditos
        try:
            dicc["creditos"].append(driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/div[3]/section[2]/div[2]/div[2]').text)
        except:
            dicc["creditos"].append(np.nan)
        
        time.sleep(random.randint(1, 2))
        # capturamos la posición
        try:
            dicc["positions"].append(driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div/ul/li').text)
        except: 
            dicc["positions"].append(np.nan)
                
        time.sleep(random.randint(1, 2))       
        # capturamos conocido por
        try:
            dicc["known_for"].append(driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/div[3]/section[1]/div[2]/div/div[2]').text)
        except:
            dicc["known_for"].append(np.nan)
            
        
        # entramos en la biografía
        driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[1]/div/div[2]/ul/li[1]/a').click()
        driver.implicitly_wait(30)
        time.sleep(random.randint(1, 2))
        # capturamos la descripcion
        try:
            dicc["description"].append(driver.find_element("xpath", '//*[@id="mini_bio_0"]').text)
        except:
            dicc["description"].append(np.nan)
        time.sleep(random.randint(1, 2))    
        # capturamos la imagen
        try:
            dicc["image"].append(driver.find_element("xpath", '//*[@id="__next"]/main/div/section/section/div[3]/section/section/div[2]/div/div/div/img').get_attribute("src"))
        except:
            dicc["image"].append(np.nan)
    
    driver.quit()

    return pd.DataFrame(dicc)

# %%
df = scraping_imbd(actors_list)
df
# Out:
# 100%|██████████| 3/3 [00:32<00:00, 10.67s/it]
#               name                                              image  \
# 0     Adam Sandler  https://m.media-amazon.com/images/M/MV5BMjQyNz...
# 1     Maya Rudolph  https://m.media-amazon.com/images/M/MV5BMTMzOT...
# 2  Andrew Bachelor  https://m.media-amazon.com/images/M/MV5BOTUyMT...
#
#                                          description positions  \
# 0  Adam Sandler nació el 9 de septiembre de 1966 ...   Reparto
# 1  Maya Rudolph nació el 27 de julio de 1972 en G...   Reparto
# 2  Andrew Bachelor nació el 26 de junio de 1988 e...   Reparto
#
#                                            known_for  \
# 0  El aguador\n6,1\nBobby Boucher\n1998\nLittle N...
# 1  La boda de mi mejor amiga\n6,8\nLillian\n2011\...
# 2  The Babysitter\n6,3\nJohn\n2017\nLa primera ve...
#
#                                             creditos
# 0  Reparto86\nProducción62\nGuion28\nBanda sonora...
# 1  Reparto116\nProducción11\nGuion2\nBanda sonora...
# 2  Reparto93\nDirección7\nGuion4\nProducción7\nMú...

# %%
actors_df = df.copy()
actors_df
# Out:
#               name                                              image  \
# 0     Adam Sandler  https://m.media-amazon.com/images/M/MV5BMjQyNz...
# 1     Maya Rudolph  https://m.media-amazon.com/images/M/MV5BMTMzOT...
# 2  Andrew Bachelor  https://m.media-amazon.com/images/M/MV5BOTUyMT...
#
#                                          description positions  \
# 0  Adam Sandler nació el 9 de septiembre de 1966 ...   Reparto
# 1  Maya Rudolph nació el 27 de julio de 1972 en G...   Reparto
# 2  Andrew Bachelor nació el 26 de junio de 1988 e...   Reparto
#
#                                            known_for  \
# 0  El aguador\n6,1\nBobby Boucher\n1998\nLittle N...
# 1  La boda de mi mejor amiga\n6,8\nLillian\n2011\...
# 2  The Babysitter\n6,3\nJohn\n2017\nLa primera ve...
#
#                                             creditos
# 0  Reparto86\nProducción62\nGuion28\nBanda sonora...
# 1  Reparto116\nProducción11\nGuion2\nBanda sonora...
# 2  Reparto93\nDirección7\nGuion4\nProducción7\nMú...

# %% [markdown]
# ## Limpieza

# %%
actors_df = pd.read_csv("data/actores.csv")
actors_df
# Out:
#    Unnamed: 0                name  \
# 0           0        Adam Sandler
# 1           1        Maya Rudolph
# 2           2     Andrew Bachelor
# 3           3  Keegan-Michael Key
# 4           4        Robbie Amell
# 5           5        Jacki Weaver
# 6           6       Rob Schneider
# 7           7       Nick Swardson
# 8           8   Lakeith Stanfield
# 9           9      Zachary Quinto
#
#                                                image  \
# 0  https://m.media-amazon.com/images/M/MV5BMjQyNz...
# 1  https://m.media-amazon.com/images/M/MV5BMTMzOT...
# 2  https://m.media-amazon.com/images/M/MV5BOTUyMT...
# 3  https://m.media-amazon.com/images/M/MV5BZmI1MD...
# 4  https://m.media-amazon.com/images/M/MV5BMjE2OT...
# 5  https://m.media-amazon.com/images/M/MV5BNDYyOT...
# 6  https://m.media-amazon.com/images/M/MV5BMTg0MD...
# 7  https://m.media-amazon.com/images/M/MV5BMjQ5ND...
# 8  https://m.media-amazon.com/images/M/MV5BMTU3NT...
# 9  https://m.media-amazon.com/images/M/MV5BMjQ4ND...
#
#                                          description  \
# 0  Adam Richard Sandler was born September 9, 196...
# 1  Maya Rudolph was born on July 27, 1972 in Gain...
# 2  Over the last few years, Andrew Bachelor, bett...
# 3  Keegan-Michael Key was born in Southfield, Mic...
# 4  Along with his sister, Robbie Amell started ac...
# 5  Jacqueline Ruth Weaver is an Australian theatr...
# 6  Robert Michael "Rob" Schneider (born October 3...
# 7  Nick Swardson was born on October 9, 1976 in M...
# 8  LaKeith Lee Stanfield is an actor and rapper f...
# 9  Zachary Quinto was born in Pittsburgh, Pennsyl...
#
#                            positions  \
# 0         Reparto\nProducción\nGuion
# 1         Reparto\nProducción\nGuion
# 2          Reparto\nDirección\nGuion
# 3         Reparto\nGuion\nProducción
# 4                Reparto\nProducción
# 5              Reparto\nBanda sonora
# 6         Reparto\nGuion\nProducción
# 7         Reparto\nGuion\nProducción
# 8  Reparto\nProducción\nBanda sonora
# 9         Reparto\nProducción\nGuion
#
#                                            known_for  \
# 0  El aguador\n6,1\nBobby Boucher\n1998\nEl chico...
# 1  La boda de mi mejor amiga\n6,8\nLillian\n2011\...
# 2  The Babysitter\n6,3\nJohn\n2017\nLa primera ve...
# 3  Keanu\n6,2\nClarence GoobrilSmoke Dresden\n201...
# 4  Upload\n7,9\nSerie de TV\nNathan Brown\n2020–2...
# 5  El lado bueno de las cosas\n7,7\nDolores Solit...
# 6  Gigoló\n5,7\nDeuce Bigalow\n1999\n¡Este cuerpo...
# 7  Play Boy: el rey del mando\n6,9\nJeff\n2006\nL...
# 8  Perdona que te moleste\n6,9\nCassius Green(as ...
# 9  Star Trek\n7,9\nSpock\n2009\nMargin Call\n7,1\...
#
#                                             creditos
# 0  Banda sonora34\nGuion y continuidad7\nComposic...
# 1  Banda sonora29\nMúsica1\nComo sí mismos120\nAg...
# 2  Producción7\nMúsica1\nBanda sonora1\nComo sí m...
# 3  Banda sonora9\nComo sí mismos146\nAgradecimien...
# 4  Como sí mismos27\nAgradecimientos1\nmetraje de...
# 5  Como sí mismos55\nAgradecimientos1\nmetraje de...
# 6  Dirección6\nBanda sonora6\nEquipos adicionales...
# 7  Guion y continuidad1\nEquipos adicionales1\nBa...
# 8  Como sí mismos30\nAgradecimientos1\nmetraje de...
# 9  Banda sonora1\nComo sí mismos142\nAgradecimien...

# %%
actors_df['positions'].unique()
# Out:
# array(['Reparto\nProducción\nGuion', 'Reparto\nDirección\nGuion',
#        'Reparto\nGuion\nProducción', 'Reparto\nProducción',
#        'Reparto\nBanda sonora', 'Reparto\nProducción\nBanda sonora'],
#       dtype=object)

# %%
actors_df['positions'] = actors_df['positions'].str.split('\n')
actors_df
# Out:
#    Unnamed: 0                name  \
# 0           0        Adam Sandler
# 1           1        Maya Rudolph
# 2           2     Andrew Bachelor
# 3           3  Keegan-Michael Key
# 4           4        Robbie Amell
# 5           5        Jacki Weaver
# 6           6       Rob Schneider
# 7           7       Nick Swardson
# 8           8   Lakeith Stanfield
# 9           9      Zachary Quinto
#
#                                                image  \
# 0  https://m.media-amazon.com/images/M/MV5BMjQyNz...
# 1  https://m.media-amazon.com/images/M/MV5BMTMzOT...
# 2  https://m.media-amazon.com/images/M/MV5BOTUyMT...
# 3  https://m.media-amazon.com/images/M/MV5BZmI1MD...
# 4  https://m.media-amazon.com/images/M/MV5BMjE2OT...
# 5  https://m.media-amazon.com/images/M/MV5BNDYyOT...
# 6  https://m.media-amazon.com/images/M/MV5BMTg0MD...
# 7  https://m.media-amazon.com/images/M/MV5BMjQ5ND...
# 8  https://m.media-amazon.com/images/M/MV5BMTU3NT...
# 9  https://m.media-amazon.com/images/M/MV5BMjQ4ND...
#
#                                          description  \
# 0  Adam Richard Sandler was born September 9, 196...
# 1  Maya Rudolph was born on July 27, 1972 in Gain...
# 2  Over the last few years, Andrew Bachelor, bett...
# 3  Keegan-Michael Key was born in Southfield, Mic...
# 4  Along with his sister, Robbie Amell started ac...
# 5  Jacqueline Ruth Weaver is an Australian theatr...
# 6  Robert Michael "Rob" Schneider (born October 3...
# 7  Nick Swardson was born on October 9, 1976 in M...
# 8  LaKeith Lee Stanfield is an actor and rapper f...
# 9  Zachary Quinto was born in Pittsburgh, Pennsyl...
#
#                              positions  \
# 0         [Reparto, Producción, Guion]
# 1         [Reparto, Producción, Guion]
# 2          [Reparto, Dirección, Guion]
# 3         [Reparto, Guion, Producción]
# 4                [Reparto, Producción]
# 5              [Reparto, Banda sonora]
# 6         [Reparto, Guion, Producción]
# 7         [Reparto, Guion, Producción]
# 8  [Reparto, Producción, Banda sonora]
# 9         [Reparto, Producción, Guion]
#
#                                            known_for  \
# 0  El aguador\n6,1\nBobby Boucher\n1998\nEl chico...
# 1  La boda de mi mejor amiga\n6,8\nLillian\n2011\...
# 2  The Babysitter\n6,3\nJohn\n2017\nLa primera ve...
# 3  Keanu\n6,2\nClarence GoobrilSmoke Dresden\n201...
# 4  Upload\n7,9\nSerie de TV\nNathan Brown\n2020–2...
# 5  El lado bueno de las cosas\n7,7\nDolores Solit...
# 6  Gigoló\n5,7\nDeuce Bigalow\n1999\n¡Este cuerpo...
# 7  Play Boy: el rey del mando\n6,9\nJeff\n2006\nL...
# 8  Perdona que te moleste\n6,9\nCassius Green(as ...
# 9  Star Trek\n7,9\nSpock\n2009\nMargin Call\n7,1\...
#
#                                             creditos
# 0  Banda sonora34\nGuion y continuidad7\nComposic...
# 1  Banda sonora29\nMúsica1\nComo sí mismos120\nAg...
# 2  Producción7\nMúsica1\nBanda sonora1\nComo sí m...
# 3  Banda sonora9\nComo sí mismos146\nAgradecimien...
# 4  Como sí mismos27\nAgradecimientos1\nmetraje de...
# 5  Como sí mismos55\nAgradecimientos1\nmetraje de...
# 6  Dirección6\nBanda sonora6\nEquipos adicionales...
# 7  Guion y continuidad1\nEquipos adicionales1\nBa...
# 8  Como sí mismos30\nAgradecimientos1\nmetraje de...
# 9  Banda sonora1\nComo sí mismos142\nAgradecimien...

# %% [markdown]
# ## limpieza de creditos

# %%
actors_df['creditos'][0]
# Out:
# 'Banda sonora34\nGuion y continuidad7\nComposición3\nsonido de archivo2\nMúsica1\nComo sí mismos256\nAgradecimientos10\nmetraje de archivo80'

# %%
actors_df['creditos'] = actors_df['creditos'].str.split('\n')
actors_df.head(1)
# eliminamos la primera columna 
actors_df.drop(columns = "Unnamed: 0", inplace = True)

# %%
actors_df['creditos'][0]
# Out:
# ['Banda sonora34',
#  'Guion y continuidad7',
#  'Composición3',
#  'sonido de archivo2',
#  'Música1',
#  'Como sí mismos256',
#  'Agradecimientos10',
#  'metraje de archivo80']

# %%
actors_df.head(1)
# Out:
#            name                                              image  \
# 0  Adam Sandler  https://m.media-amazon.com/images/M/MV5BMjQyNz...
#
#                                          description  \
# 0  Adam Richard Sandler was born September 9, 196...
#
#                       positions  \
# 0  [Reparto, Producción, Guion]
#
#                                            known_for  \
# 0  El aguador\n6,1\nBobby Boucher\n1998\nEl chico...
#
#                                             creditos
# 0  [Banda sonora34, Guion y continuidad7, Composi...

# %%
for indice, fila in actors_df.iterrows():
    for credito in fila["creditos"]:
        nombre_col = re.findall("[^0-9]+", credito)[0]

        # creacion de columnas vacias 
        if nombre_col not in actors_df.columns:
            actors_df[nombre_col] = np.nan
        else:
            pass

        # rellenado de datos 
        try:
            actors_df.loc[indice, nombre_col] = re.findall("[0-9]+", credito)[0]
        except:
            pass
        


actors_df.head(3)
# Out:
#               name                                              image  \
# 0     Adam Sandler  https://m.media-amazon.com/images/M/MV5BMjQyNz...
# 1     Maya Rudolph  https://m.media-amazon.com/images/M/MV5BMTMzOT...
# 2  Andrew Bachelor  https://m.media-amazon.com/images/M/MV5BOTUyMT...
#
#                                          description  \
# 0  Adam Richard Sandler was born September 9, 196...
# 1  Maya Rudolph was born on July 27, 1972 in Gain...
# 2  Over the last few years, Andrew Bachelor, bett...
#
#                       positions  \
# 0  [Reparto, Producción, Guion]
# 1  [Reparto, Producción, Guion]
# 2   [Reparto, Dirección, Guion]
#
#                                            known_for  \
# 0  El aguador\n6,1\nBobby Boucher\n1998\nEl chico...
# 1  La boda de mi mejor amiga\n6,8\nLillian\n2011\...
# 2  The Babysitter\n6,3\nJohn\n2017\nLa primera ve...
#
#                                             creditos Banda sonora  \
# 0  [Banda sonora34, Guion y continuidad7, Composi...           34
# 1  [Banda sonora29, Música1, Como sí mismos120, A...           29
# 2  [Producción7, Música1, Banda sonora1, Como sí ...            1
#
#   Guion y continuidad Composición sonido de archivo Música Como sí mismos  \
# 0                   7           3                 2      1            256
# 1                 NaN         NaN               NaN      1            120
# 2                 NaN         NaN               NaN      1             35
#
#   Agradecimientos metraje de archivo Producción Dirección Equipos adicionales
# 0              10                 80        NaN       NaN                 NaN
# 1               7                 35        NaN       NaN                 NaN
# 2             NaN                NaN          7       NaN                 NaN

# %%
actors_df.drop(columns = "creditos", inplace = True)

# %%
actors_df.head(1)
# Out:
#            name                                              image  \
# 0  Adam Sandler  https://m.media-amazon.com/images/M/MV5BMjQyNz...
#
#                                          description  \
# 0  Adam Richard Sandler was born September 9, 196...
#
#                       positions  \
# 0  [Reparto, Producción, Guion]
#
#                                            known_for Banda sonora  \
# 0  El aguador\n6,1\nBobby Boucher\n1998\nEl chico...           34
#
#   Guion y continuidad Composición sonido de archivo Música Como sí mismos  \
# 0                   7           3                 2      1            256
#
#   Agradecimientos metraje de archivo Producción Dirección Equipos adicionales
# 0              10                 80        NaN       NaN                 NaN

# %% [markdown]
# ## limpieza de known_for

# %%
actors_df["known_for"][0]
# Out:
# 'El aguador\n6,1\nBobby Boucher\n1998\nEl chico ideal\n6,9\nRobbie Hart\n1998\nUn papá genial\n6,4\nSonny Koufax\n1999\nLittle Nicky\n5,3\nNicky\n2000'

# %%
actors_df["known_for"] =actors_df["known_for"].str.split("\n")
actors_df["known_for"]
# Out:
# 0    [El aguador, 6,1, Bobby Boucher, 1998, El chic...
# 1    [La boda de mi mejor amiga, 6,8, Lillian, 2011...
# 2    [The Babysitter, 6,3, John, 2017, La primera v...
# 3    [Keanu, 6,2, Clarence GoobrilSmoke Dresden, 20...
# 4    [Upload, 7,9, Serie de TV, Nathan Brown, 2020–...
# 5    [El lado bueno de las cosas, 7,7, Dolores Soli...
# 6    [Gigoló, 5,7, Deuce Bigalow, 1999, ¡Este cuerp...
# 7    [Play Boy: el rey del mando, 6,9, Jeff, 2006, ...
# 8    [Perdona que te moleste, 6,9, Cassius Green(as...
# 9    [Star Trek, 7,9, Spock, 2009, Margin Call, 7,1...
# Name: known_for, dtype: object

# %%
actors_df["known_for"][5]
# Out:
# ['El lado bueno de las cosas',
#  '7,7',
#  'Dolores Solitano',
#  '2012',
#  'Animal Kingdom',
#  '7,3',
#  "Janine 'Smurf' Cody",
#  '2010',
#  'Stoker',
#  '6,8',
#  'Gwendolyn Stoker',
#  '2013',
#  'The Disaster Artist',
#  '7,3',
#  "Carolyn'Claudette'",
#  '2017']

# %%
actors_df["known_for"][5][::4]
# Out:
# ['El lado bueno de las cosas',
#  'Animal Kingdom',
#  'Stoker',
#  'The Disaster Artist']

# %%
actors_df["known_for"] = actors_df["known_for"].apply(lambda x: x[::4])
actors_df
# Out:
#                  name                                              image  \
# 0        Adam Sandler  https://m.media-amazon.com/images/M/MV5BMjQyNz...
# 1        Maya Rudolph  https://m.media-amazon.com/images/M/MV5BMTMzOT...
# 2     Andrew Bachelor  https://m.media-amazon.com/images/M/MV5BOTUyMT...
# 3  Keegan-Michael Key  https://m.media-amazon.com/images/M/MV5BZmI1MD...
# 4        Robbie Amell  https://m.media-amazon.com/images/M/MV5BMjE2OT...
# 5        Jacki Weaver  https://m.media-amazon.com/images/M/MV5BNDYyOT...
# 6       Rob Schneider  https://m.media-amazon.com/images/M/MV5BMTg0MD...
# 7       Nick Swardson  https://m.media-amazon.com/images/M/MV5BMjQ5ND...
# 8   Lakeith Stanfield  https://m.media-amazon.com/images/M/MV5BMTU3NT...
# 9      Zachary Quinto  https://m.media-amazon.com/images/M/MV5BMjQ4ND...
#
#                                          description  \
# 0  Adam Richard Sandler was born September 9, 196...
# 1  Maya Rudolph was born on July 27, 1972 in Gain...
# 2  Over the last few years, Andrew Bachelor, bett...
# 3  Keegan-Michael Key was born in Southfield, Mic...
# 4  Along with his sister, Robbie Amell started ac...
# 5  Jacqueline Ruth Weaver is an Australian theatr...
# 6  Robert Michael "Rob" Schneider (born October 3...
# 7  Nick Swardson was born on October 9, 1976 in M...
# 8  LaKeith Lee Stanfield is an actor and rapper f...
# 9  Zachary Quinto was born in Pittsburgh, Pennsyl...
#
#                              positions  \
# 0         [Reparto, Producción, Guion]
# 1         [Reparto, Producción, Guion]
# 2          [Reparto, Dirección, Guion]
# 3         [Reparto, Guion, Producción]
# 4                [Reparto, Producción]
# 5              [Reparto, Banda sonora]
# 6         [Reparto, Guion, Producción]
# 7         [Reparto, Guion, Producción]
# 8  [Reparto, Producción, Banda sonora]
# 9         [Reparto, Producción, Guion]
#
#                                            known_for Banda sonora  \
# 0  [El aguador, El chico ideal, Un papá genial, L...           34
# 1  [La boda de mi mejor amiga, Un lugar donde que...           29
# 2  [The Babysitter, La primera vez que nos vimos,...            1
# 3  [Keanu, Vamos de polis, Tomorrowland: El mundo...            9
# 4  [Upload, 2020–2022 • 17 episodios, 2015, Steph...          NaN
# 5  [El lado bueno de las cosas, Animal Kingdom, S...          NaN
# 6  [Gigoló, ¡Este cuerpo no es el mío!, Estoy hec...            6
# 7  [Play Boy: el rey del mando, Los calientabanqu...            1
# 8  [Perdona que te moleste, Puñales por la espald...          NaN
# 9  [Star Trek, Margin Call, Star Trek: Más allá, ...            1
#
#   Guion y continuidad Composición sonido de archivo Música Como sí mismos  \
# 0                   7           3                 2      1            256
# 1                 NaN         NaN               NaN      1            120
# 2                 NaN         NaN               NaN      1             35
# 3                 NaN         NaN               NaN    NaN            146
# 4                 NaN         NaN               NaN    NaN             27
# 5                 NaN         NaN               NaN    NaN             55
# 6                 NaN         NaN                 1    NaN            152
# 7                   1         NaN               NaN    NaN             70
# 8                 NaN         NaN               NaN    NaN             30
# 9                 NaN         NaN               NaN    NaN            142
#
#   Agradecimientos metraje de archivo Producción Dirección Equipos adicionales  \
# 0              10                 80        NaN       NaN                 NaN
# 1               7                 35        NaN       NaN                 NaN
# 2             NaN                NaN          7       NaN                 NaN
# 3               1                  9        NaN       NaN                 NaN
# 4               1                  2        NaN       NaN                 NaN
# 5               1                  5        NaN       NaN                 NaN
# 6               3                 27        NaN         6                   2
# 7               1                  2        NaN       NaN                   1
# 8               1                  2        NaN       NaN                 NaN
# 9               9                  9        NaN       NaN                 NaN
#
#                                       known_for_test
# 0  [El aguador, 6,1, Bobby Boucher, 1998, El chic...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  [Upload, 7,9, Serie de TV, Nathan Brown, 2020–...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  [Perdona que te moleste, 6,9, Cassius Green(as...
# 9                                                NaN

# %%
actors_df = actors_df.explode("known_for")
actors_df
# Out:
#                  name                                              image  \
# 0        Adam Sandler  https://m.media-amazon.com/images/M/MV5BMjQyNz...
# 0        Adam Sandler  https://m.media-amazon.com/images/M/MV5BMjQyNz...
# 0        Adam Sandler  https://m.media-amazon.com/images/M/MV5BMjQyNz...
# 0        Adam Sandler  https://m.media-amazon.com/images/M/MV5BMjQyNz...
# 1        Maya Rudolph  https://m.media-amazon.com/images/M/MV5BMTMzOT...
# 1        Maya Rudolph  https://m.media-amazon.com/images/M/MV5BMTMzOT...
# 1        Maya Rudolph  https://m.media-amazon.com/images/M/MV5BMTMzOT...
# 1        Maya Rudolph  https://m.media-amazon.com/images/M/MV5BMTMzOT...
# 2     Andrew Bachelor  https://m.media-amazon.com/images/M/MV5BOTUyMT...
# 2     Andrew Bachelor  https://m.media-amazon.com/images/M/MV5BOTUyMT...
# 2     Andrew Bachelor  https://m.media-amazon.com/images/M/MV5BOTUyMT...
# 2     Andrew Bachelor  https://m.media-amazon.com/images/M/MV5BOTUyMT...
# 3  Keegan-Michael Key  https://m.media-amazon.com/images/M/MV5BZmI1MD...
# 3  Keegan-Michael Key  https://m.media-amazon.com/images/M/MV5BZmI1MD...
# 3  Keegan-Michael Key  https://m.media-amazon.com/images/M/MV5BZmI1MD...
# 3  Keegan-Michael Key  https://m.media-amazon.com/images/M/MV5BZmI1MD...
# 3  Keegan-Michael Key  https://m.media-amazon.com/images/M/MV5BZmI1MD...
# 4        Robbie Amell  https://m.media-amazon.com/images/M/MV5BMjE2OT...
# 4        Robbie Amell  https://m.media-amazon.com/images/M/MV5BMjE2OT...
# 4        Robbie Amell  https://m.media-amazon.com/images/M/MV5BMjE2OT...
# 4        Robbie Amell  https://m.media-amazon.com/images/M/MV5BMjE2OT...
# 4        Robbie Amell  https://m.media-amazon.com/images/M/MV5BMjE2OT...
# 5        Jacki Weaver  https://m.media-amazon.com/images/M/MV5BNDYyOT...
# 5        Jacki Weaver  https://m.media-amazon.com/images/M/MV5BNDYyOT...
# 5        Jacki Weaver  https://m.media-amazon.com/images/M/MV5BNDYyOT...
# 5        Jacki Weaver  https://m.media-amazon.com/images/M/MV5BNDYyOT...
# 6       Rob Schneider  https://m.media-amazon.com/images/M/MV5BMTg0MD...
# 6       Rob Schneider  https://m.media-amazon.com/images/M/MV5BMTg0MD...
# 6       Rob Schneider  https://m.media-amazon.com/images/M/MV5BMTg0MD...
# 6       Rob Schneider  https://m.media-amazon.com/images/M/MV5BMTg0MD...
# 7       Nick Swardson  https://m.media-amazon.com/images/M/MV5BMjQ5ND...
# 7       Nick Swardson  https://m.media-amazon.com/images/M/MV5BMjQ5ND...
# 7       Nick Swardson  https://m.media-amazon.com/images/M/MV5BMjQ5ND...
# 7       Nick Swardson  https://m.media-amazon.com/images/M/MV5BMjQ5ND...
# 8   Lakeith Stanfield  https://m.media-amazon.com/images/M/MV5BMTU3NT...
# 8   Lakeith Stanfield  https://m.media-amazon.com/images/M/MV5BMTU3NT...
# 8   Lakeith Stanfield  https://m.media-amazon.com/images/M/MV5BMTU3NT...
# 8   Lakeith Stanfield  https://m.media-amazon.com/images/M/MV5BMTU3NT...
# 9      Zachary Quinto  https://m.media-amazon.com/images/M/MV5BMjQ4ND...
# 9      Zachary Quinto  https://m.media-amazon.com/images/M/MV5BMjQ4ND...
# 9      Zachary Quinto  https://m.media-amazon.com/images/M/MV5BMjQ4ND...
# 9      Zachary Quinto  https://m.media-amazon.com/images/M/MV5BMjQ4ND...
#
#                                          description  \
# 0  Adam Richard Sandler was born September 9, 196...
# 0  Adam Richard Sandler was born September 9, 196...
# 0  Adam Richard Sandler was born September 9, 196...
# 0  Adam Richard Sandler was born September 9, 196...
# 1  Maya Rudolph was born on July 27, 1972 in Gain...
# 1  Maya Rudolph was born on July 27, 1972 in Gain...
# 1  Maya Rudolph was born on July 27, 1972 in Gain...
# 1  Maya Rudolph was born on July 27, 1972 in Gain...
# 2  Over the last few years, Andrew Bachelor, bett...
# 2  Over the last few years, Andrew Bachelor, bett...
# 2  Over the last few years, Andrew Bachelor, bett...
# 2  Over the last few years, Andrew Bachelor, bett...
# 3  Keegan-Michael Key was born in Southfield, Mic...
# 3  Keegan-Michael Key was born in Southfield, Mic...
# 3  Keegan-Michael Key was born in Southfield, Mic...
# 3  Keegan-Michael Key was born in Southfield, Mic...
# 3  Keegan-Michael Key was born in Southfield, Mic...
# 4  Along with his sister, Robbie Amell started ac...
# 4  Along with his sister, Robbie Amell started ac...
# 4  Along with his sister, Robbie Amell started ac...
# 4  Along with his sister, Robbie Amell started ac...
# 4  Along with his sister, Robbie Amell started ac...
# 5  Jacqueline Ruth Weaver is an Australian theatr...
# 5  Jacqueline Ruth Weaver is an Australian theatr...
# 5  Jacqueline Ruth Weaver is an Australian theatr...
# 5  Jacqueline Ruth Weaver is an Australian theatr...
# 6  Robert Michael "Rob" Schneider (born October 3...
# 6  Robert Michael "Rob" Schneider (born October 3...
# 6  Robert Michael "Rob" Schneider (born October 3...
# 6  Robert Michael "Rob" Schneider (born October 3...
# 7  Nick Swardson was born on October 9, 1976 in M...
# 7  Nick Swardson was born on October 9, 1976 in M...
# 7  Nick Swardson was born on October 9, 1976 in M...
# 7  Nick Swardson was born on October 9, 1976 in M...
# 8  LaKeith Lee Stanfield is an actor and rapper f...
# 8  LaKeith Lee Stanfield is an actor and rapper f...
# 8  LaKeith Lee Stanfield is an actor and rapper f...
# 8  LaKeith Lee Stanfield is an actor and rapper f...
# 9  Zachary Quinto was born in Pittsburgh, Pennsyl...
# 9  Zachary Quinto was born in Pittsburgh, Pennsyl...
# 9  Zachary Quinto was born in Pittsburgh, Pennsyl...
# 9  Zachary Quinto was born in Pittsburgh, Pennsyl...
#
#                              positions  \
# 0         [Reparto, Producción, Guion]
# 0         [Reparto, Producción, Guion]
# 0         [Reparto, Producción, Guion]
# 0         [Reparto, Producción, Guion]
# 1         [Reparto, Producción, Guion]
# 1         [Reparto, Producción, Guion]
# 1         [Reparto, Producción, Guion]
# 1         [Reparto, Producción, Guion]
# 2          [Reparto, Dirección, Guion]
# 2          [Reparto, Dirección, Guion]
# 2          [Reparto, Dirección, Guion]
# 2          [Reparto, Dirección, Guion]
# 3         [Reparto, Guion, Producción]
# 3         [Reparto, Guion, Producción]
# 3         [Reparto, Guion, Producción]
# 3         [Reparto, Guion, Producción]
# 3         [Reparto, Guion, Producción]
# 4                [Reparto, Producción]
# 4                [Reparto, Producción]
# 4                [Reparto, Producción]
# 4                [Reparto, Producción]
# 4                [Reparto, Producción]
# 5              [Reparto, Banda sonora]
# 5              [Reparto, Banda sonora]
# 5              [Reparto, Banda sonora]
# 5              [Reparto, Banda sonora]
# 6         [Reparto, Guion, Producción]
# 6         [Reparto, Guion, Producción]
# 6         [Reparto, Guion, Producción]
# 6         [Reparto, Guion, Producción]
# 7         [Reparto, Guion, Producción]
# 7         [Reparto, Guion, Producción]
# 7         [Reparto, Guion, Producción]
# 7         [Reparto, Guion, Producción]
# 8  [Reparto, Producción, Banda sonora]
# 8  [Reparto, Producción, Banda sonora]
# 8  [Reparto, Producción, Banda sonora]
# 8  [Reparto, Producción, Banda sonora]
# 9         [Reparto, Producción, Guion]
# 9         [Reparto, Producción, Guion]
# 9         [Reparto, Producción, Guion]
# 9         [Reparto, Producción, Guion]
#
#                                   known_for Banda sonora Guion y continuidad  \
# 0                                El aguador           34                   7
# 0                            El chico ideal           34                   7
# 0                            Un papá genial           34                   7
# 0                              Little Nicky           34                   7
# 1                 La boda de mi mejor amiga           29                 NaN
# 1                   Un lugar donde quedarse           29                 NaN
# 1                       El camino de vuelta           29                 NaN
# 1                                Puro vicio           29                 NaN
# 2                            The Babysitter            1                 NaN
# 2              La primera vez que nos vimos            1                 NaN
# 2                        Amor de calendario            1                 NaN
# 2  A todos los chicos de los que me enamoré            1                 NaN
# 3                                     Keanu            9                 NaN
# 3                            Vamos de polis            9                 NaN
# 3         Tomorrowland: El mundo del mañana            9                 NaN
# 3                             Key and Peele            9                 NaN
# 3                  2012–2015 • 54 episodios            9                 NaN
# 4                                    Upload          NaN                 NaN
# 4                  2020–2022 • 17 episodios          NaN                 NaN
# 4                                      2015          NaN                 NaN
# 4                           Stephen Jameson          NaN                 NaN
# 4                                    Renton          NaN                 NaN
# 5                El lado bueno de las cosas          NaN                 NaN
# 5                            Animal Kingdom          NaN                 NaN
# 5                                    Stoker          NaN                 NaN
# 5                       The Disaster Artist          NaN                 NaN
# 6                                    Gigoló            6                 NaN
# 6                ¡Este cuerpo no es el mío!            6                 NaN
# 6                     Estoy hecho un animal            6                 NaN
# 6             Deuce Bigalow: Gigoló europeo            6                 NaN
# 7                Play Boy: el rey del mando            1                   1
# 7                    Los calientabanquillos            1                   1
# 7                          Sígueme el rollo            1                   1
# 7                          Jack y su gemela            1                   1
# 8                    Perdona que te moleste          NaN                 NaN
# 8                    Puñales por la espalda          NaN                 NaN
# 8                        Las vidas de Grace          NaN                 NaN
# 8                                     Selma          NaN                 NaN
# 9                                 Star Trek            1                 NaN
# 9                               Margin Call            1                 NaN
# 9                       Star Trek: Más allá            1                 NaN
# 9                Star Trek: En la oscuridad            1                 NaN
#
#   Composición sonido de archivo Música Como sí mismos Agradecimientos  \
# 0           3                 2      1            256              10
# 0           3                 2      1            256              10
# 0           3                 2      1            256              10
# 0           3                 2      1            256              10
# 1         NaN               NaN      1            120               7
# 1         NaN               NaN      1            120               7
# 1         NaN               NaN      1            120               7
# 1         NaN               NaN      1            120               7
# 2         NaN               NaN      1             35             NaN
# 2         NaN               NaN      1             35             NaN
# 2         NaN               NaN      1             35             NaN
# 2         NaN               NaN      1             35             NaN
# 3         NaN               NaN    NaN            146               1
# 3         NaN               NaN    NaN            146               1
# 3         NaN               NaN    NaN            146               1
# 3         NaN               NaN    NaN            146               1
# 3         NaN               NaN    NaN            146               1
# 4         NaN               NaN    NaN             27               1
# 4         NaN               NaN    NaN             27               1
# 4         NaN               NaN    NaN             27               1
# 4         NaN               NaN    NaN             27               1
# 4         NaN               NaN    NaN             27               1
# 5         NaN               NaN    NaN             55               1
# 5         NaN               NaN    NaN             55               1
# 5         NaN               NaN    NaN             55               1
# 5         NaN               NaN    NaN             55               1
# 6         NaN                 1    NaN            152               3
# 6         NaN                 1    NaN            152               3
# 6         NaN                 1    NaN            152               3
# 6         NaN                 1    NaN            152               3
# 7         NaN               NaN    NaN             70               1
# 7         NaN               NaN    NaN             70               1
# 7         NaN               NaN    NaN             70               1
# 7         NaN               NaN    NaN             70               1
# 8         NaN               NaN    NaN             30               1
# 8         NaN               NaN    NaN             30               1
# 8         NaN               NaN    NaN             30               1
# 8         NaN               NaN    NaN             30               1
# 9         NaN               NaN    NaN            142               9
# 9         NaN               NaN    NaN            142               9
# 9         NaN               NaN    NaN            142               9
# 9         NaN               NaN    NaN            142               9
#
#   metraje de archivo Producción Dirección Equipos adicionales  \
# 0                 80        NaN       NaN                 NaN
# 0                 80        NaN       NaN                 NaN
# 0                 80        NaN       NaN                 NaN
# 0                 80        NaN       NaN                 NaN
# 1                 35        NaN       NaN                 NaN
# 1                 35        NaN       NaN                 NaN
# 1                 35        NaN       NaN                 NaN
# 1                 35        NaN       NaN                 NaN
# 2                NaN          7       NaN                 NaN
# 2                NaN          7       NaN                 NaN
# 2                NaN          7       NaN                 NaN
# 2                NaN          7       NaN                 NaN
# 3                  9        NaN       NaN                 NaN
# 3                  9        NaN       NaN                 NaN
# 3                  9        NaN       NaN                 NaN
# 3                  9        NaN       NaN                 NaN
# 3                  9        NaN       NaN                 NaN
# 4                  2        NaN       NaN                 NaN
# 4                  2        NaN       NaN                 NaN
# 4                  2        NaN       NaN                 NaN
# 4                  2        NaN       NaN                 NaN
# 4                  2        NaN       NaN                 NaN
# 5                  5        NaN       NaN                 NaN
# 5                  5        NaN       NaN                 NaN
# 5                  5        NaN       NaN                 NaN
# 5                  5        NaN       NaN                 NaN
# 6                 27        NaN         6                   2
# 6                 27        NaN         6                   2
# 6                 27        NaN         6                   2
# 6                 27        NaN         6                   2
# 7                  2        NaN       NaN                   1
# 7                  2        NaN       NaN                   1
# 7                  2        NaN       NaN                   1
# 7                  2        NaN       NaN                   1
# 8                  2        NaN       NaN                 NaN
# 8                  2        NaN       NaN                 NaN
# 8                  2        NaN       NaN                 NaN
# 8                  2        NaN       NaN                 NaN
# 9                  9        NaN       NaN                 NaN
# 9                  9        NaN       NaN                 NaN
# 9                  9        NaN       NaN                 NaN
# 9                  9        NaN       NaN                 NaN
#
#                                       known_for_test
# 0  [El aguador, 6,1, Bobby Boucher, 1998, El chic...
# 0  [El aguador, 6,1, Bobby Boucher, 1998, El chic...
# 0  [El aguador, 6,1, Bobby Boucher, 1998, El chic...
# 0  [El aguador, 6,1, Bobby Boucher, 1998, El chic...
# 1                                                NaN
# 1                                                NaN
# 1                                                NaN
# 1                                                NaN
# 2                                                NaN
# 2                                                NaN
# 2                                                NaN
# 2                                                NaN
# 3                                                NaN
# 3                                                NaN
# 3                                                NaN
# 3                                                NaN
# 3                                                NaN
# 4  [Upload, 7,9, Serie de TV, Nathan Brown, 2020–...
# 4  [Upload, 7,9, Serie de TV, Nathan Brown, 2020–...
# 4  [Upload, 7,9, Serie de TV, Nathan Brown, 2020–...
# 4  [Upload, 7,9, Serie de TV, Nathan Brown, 2020–...
# 4  [Upload, 7,9, Serie de TV, Nathan Brown, 2020–...
# 5                                                NaN
# 5                                                NaN
# 5                                                NaN
# 5                                                NaN
# 6                                                NaN
# 6                                                NaN
# 6                                                NaN
# 6                                                NaN
# 7                                                NaN
# 7                                                NaN
# 7                                                NaN
# 7                                                NaN
# 8  [Perdona que te moleste, 6,9, Cassius Green(as...
# 8  [Perdona que te moleste, 6,9, Cassius Green(as...
# 8  [Perdona que te moleste, 6,9, Cassius Green(as...
# 8  [Perdona que te moleste, 6,9, Cassius Green(as...
# 9                                                NaN
# 9                                                NaN
# 9                                                NaN
# 9                                                NaN

# %%
actors_df.to_csv("data/top10_actors.csv", index = False, sep = ";")

# %% [markdown]
# # Directors

# %%
# open the top10 directors pickle file
with open('data/top_ten_director.pkl', 'rb') as dir:
    directors = pickle.load(dir)
directors
# Out:
# ['McG',
#  'Blair Simmons',
#  'John Schultz',
#  'Noah Baumbach',
#  'Karan Johar',
#  'Dibakar Banerjee',
#  'Julien Leclercq',
#  'Amy Poehler',
#  'Kyle Newacheck',
#  'Peter Sullivan']

# %%
directors_df = pd.read_csv("data/directores.csv")
directors_df
# Out:
#    Unnamed: 0              name  \
# 0           0               McG
# 1           1     Blair Simmons
# 2           2      John Schultz
# 3           3     Noah Baumbach
# 4           4       Karan Johar
# 5           5  Dibakar Banerjee
# 6           6   Julien Leclercq
# 7           7       Amy Poehler
# 8           8    Kyle Newacheck
# 9           9    Peter Sullivan
#
#                                                image  \
# 0  https://m.media-amazon.com/images/M/MV5BMTI1MT...
# 1                                                NaN
# 2  https://m.media-amazon.com/images/M/MV5BMTY5MD...
# 3  https://m.media-amazon.com/images/M/MV5BMjA3NT...
# 4  https://m.media-amazon.com/images/M/MV5BMTM5Nj...
# 5  https://m.media-amazon.com/images/M/MV5BYzJkZG...
# 6                                                NaN
# 7  https://m.media-amazon.com/images/M/MV5BYjIzMD...
# 8  https://m.media-amazon.com/images/M/MV5BMTA5MD...
# 9  https://m.media-amazon.com/images/M/MV5BOWI1ZD...
#
#                                          description  \
# 0  McG was born on August 9, 1968 in Kalamazoo, M...
# 1                                                NaN
# 2  Schultz was an original member of the Charlott...
# 3  Born in Brooklyn in 1969 Noah Baumbach is the ...
# 4  A close friend of Shahrukh Khan, he assisted Y...
# 5  Dibakar Banerjee was born on June 21, 1969 in ...
# 6                                                NaN
# 7  Amy Meredith Poehler was born in Newton, Massa...
# 8  Kyle Newacheck was born on January 23, 1984 in...
# 9                                                NaN
#
#                                     positions  \
# 0  Producción\nEquipos adicionales\nDirección
# 1                  Dirección\nAnimación\nArte
# 2                Dirección\nGuion\nProducción
# 3                Guion\nDirección\nProducción
# 4                  Producción\nReparto\nGuion
# 5                    Dirección\nGuion\nMúsica
# 6                Guion\nDirección\nProducción
# 7                  Reparto\nProducción\nGuion
# 8                Producción\nGuion\nDirección
# 9                         Reparto\nProducción
#
#                                            known_for
# 0  Los ángeles de Charlie: Al límite\n4,9\nDirecc...
# 1  Blaze y los Monster Machines\n5,7\nSerie de TV...
# 2  Bandwagon\n7,1\nDirección\n1996\nUna pandilla ...
# 3  Historia de un matrimonio\n7,9\nGuion\n2019\nU...
# 4  Algo sucede en mi corazón\n7,6\nGuion\n1998\nN...
# 5  Detective Byomkesh Bakshy!\n7,6\nDirección\n20...
# 6  Atracadores: La serie\n7,0\nSerie de TV\nGuion...
# 7  Del revés (Inside Out)\n8,2\nJoy(voz)\n2015\nM...
# 8  ¡Game Over, tío!\n5,4\nProducción\n2018\nWorka...
# 9  La vuelta al mundo en 80 días\n7,2\nSerie de T...

# %%
df  = scraping_imbd(directors[0])
directors_df = df.copy()
directors_df["creditos"] = directors_df["creditos"].str.split("\n")

for indice, fila in directors_df.iterrows():
    for credito in fila["creditos"]:
        nombre_col = re.findall("[^0-9]+", credito)[0]

        # generamos todas las posibles columnas de creditos que podemos generar en base a los actores que tenemos
        if nombre_col not in directors_df.columns:
            directors_df[nombre_col] = np.nan # si no existe la columna la creamos y le asignamos un valor nan
        else:
            pass 

        # rellenamos las columnas con los datos que teníamos del scrapeo
        try:
            directors_df.loc[indice, nombre_col] = re.findall("[0-9]+", credito)[0]
        except:
            pass
# eliminamos la columna creditos 
directors_df.drop(["creditos"], axis = 1, inplace = True)
directors_df["known_for"] = directors_df["known_for"].str.split("\n")
directors_df["known_for"] = directors_df["known_for"].apply(lambda x: x[::4])
directors_df = directors_df.explode("known_for")
directors_df.head(2)
# Out:
#   0%|          | 0/3 [00:46<?, ?it/s]
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 df  = scraping_imbd(directors[0])
#       2 directors_df = df.copy()
#       3 directors_df["creditos"] = directors_df["creditos"].str.split("\n")
#
# Cell In[35], line 52, in scraping_imbd(listado)
#      48     dicc["known_for"].append(np.nan)
#      51 # entramos en la biografía
# ---> 52 driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[1]/div/div[2]/ul/li[1]/a').click()
#      53 driver.implicitly_wait(30)
#      54 time.sleep(random.randint(1, 2))
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/apis/lib/python3.11/site-packages/selenium/webdriver/remote/webelement.py:94, in WebElement.click(self)
#      92 def click(self) -> None:
#      93     """Clicks the element."""
# ---> 94     self._execute(Command.CLICK_ELEMENT)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/apis/lib/python3.11/site-packages/selenium/webdriver/remote/webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/apis/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:346, in WebDriver.execute(self, driver_command, params)
#     344 response = self.command_executor.execute(driver_command, params)
#     345 if response:
# --> 346     self.error_handler.check_response(response)
#     347     response["value"] = self._unwrap_value(response.get("value", None))
#     348     return response
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/apis/lib/python3.11/site-packages/selenium/webdriver/remote/errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=114.0.5735.133)
# Stacktrace:
# 0   chromedriver                        0x0000000102fc7f48 chromedriver + 4226888
# 1   chromedriver                        0x0000000102fc04f4 chromedriver + 4195572
# 2   chromedriver                        0x0000000102c04be8 chromedriver + 281576
# 3   chromedriver                        0x0000000102c41674 chromedriver + 530036
# 4   chromedriver                        0x0000000102c35eec chromedriver + 483052
# 5   chromedriver                        0x0000000102c35734 chromedriver + 481076
# 6   chromedriver                        0x0000000102c76c58 chromedriver + 748632
# 7   chromedriver                        0x0000000102c33f1c chromedriver + 474908
# 8   chromedriver                        0x0000000102c34ef4 chromedriver + 478964
# 9   chromedriver                        0x0000000102f8959c chromedriver + 3970460
# 10  chromedriver                        0x0000000102f8d6f0 chromedriver + 3987184
# 11  chromedriver                        0x0000000102f935b4 chromedriver + 4011444
# 12  chromedriver                        0x0000000102f8e2fc chromedriver + 3990268
# 13  chromedriver                        0x0000000102f661c0 chromedriver + 3826112
# 14  chromedriver                        0x0000000102faa088 chromedriver + 4104328
# 15  chromedriver                        0x0000000102faa1e0 chromedriver + 4104672
# 16  chromedriver                        0x0000000102fb9f28 chromedriver + 4169512
# 17  libsystem_pthread.dylib             0x000000019489bfa8 _pthread_start + 148
# 18  libsystem_pthread.dylib             0x0000000194896da0 thread_start + 8

# %%
directors_df.to_csv("data/top10_directors.csv", index=False, sep= ";")
